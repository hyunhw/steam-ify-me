# %% [markdown]
# # Scraping Steam Downloadable Content (DLC) data
#
# 1. In order to scrape DLC reviews, I first scraped information on all DLCs (i.e. app ids) on Steam.
#     - To scrape, I used an open source scraper written by [Andre Perunicic](https://github.com/prncc/steam-scraper)
#         - Detailed documentation of how the scraper works is provided by the author [here](https://blog.scrapinghub.com/2017/07/07/scraping-the-steam-game-store-with-scrapy/).
# 2. I had to make some modifications to the scraper code because I was interested in scraping DLC reviews from the [steam store](http://store.steampowered.com/app/684630/American_Truck_Simulator__New_Mexico/), rather than the game reviews from the [community review page](http://steamcommunity.com/app/270880/reviews/) (The original scraper was only set up to do the latter)

# %% [markdown]
# ### Handling AJAX response
#
# <div style="text-align: left; display:inline-block"><img src="images/ajax_ex.png" style="width: 700px"/></div><br/><br/>
# <h4>Because the Steam store dynamically loads user reviews, I tracked the AJAX request url using the chrome developer tool (shown below)</h4><br/><br/>
# <div style="text-align: left; display:inline-block"><img src="images/chrome_dev.png" style="width: 700px"/></div><br/>

# %% [markdown]
# <h4>Then, I inspected the html elements to scrape certain info from the reviews (shown below)</h4><br/><br/>
# <div style="text-align: left; display:inline-block"><img src="images/parse_html.png" style="width: 700px"/></div><br/><br/>

# %% [markdown]
# ### Modifying the original code

# %% [markdown]
# - In order to scrape fields not already coded in the original code, I made modifications to **steam/items.py**, where the loaders are instantiated
# ```python
# class ReviewItem(scrapy.Item()):
#     # fields already set up in the original code
#     # ...
#     # ...
#
#     # my custom fields
#     user_url = scrapy.Field()
#     date = scrapy.Field()
#     num_reviews = scrapy.Field(
#         output_processor=Compose(TakeFirst(), str_to_int)
#     )
# ```

# %% [markdown]
# - Using BeautifulSoup, I grabbed all the html elements I wanted to scrape by modifying the **steam/spiders/review_spider.py** code
#
# ```python
# class ReviewSpider(scrapy.Spider):
#     name = 'reviews'
#
#     # original code
#     # ...
#     # ...
#
#     # function to parse page
#     def parse(self, response):
#         product_id = get_product_id(response)
#
#         parsed_json = json.loads(response.body)
#         parsed_html = BeautifulSoup(parsed_json['html'])
#
#         # load all reviews from current AJAX request
#         reviews = parsed_html.findAll('div', attrs={'class': 'review_box'})
#
#         # if found, load each review and scrape data
#         if reviews:
#             for i, review in enumerate(reviews):
#                 yield load_review(review, product_id)
#
#         # if there are more reviews waiting to be loaded
#         form = parsed_html.findAll('div', attrs={"id": "LoadMoreReviewsrecent"})
#         if form:
#             offset = re.findall("start_offset=(\d+)", response.url)[0]
#             yield self.request_next_page(response.url, offset)
# ```

# %% [markdown]
# - Because the AJAX response returns at maximum 20 reviews at a time before making another call to load the next 20, I wrote a custom function that grabs the next 20 reviews until I have scraped all the reviews (this custom function is called above inside the `if form:` block)
# ```python
# def request_next_page(self, url, offset):
#     new_offset = str(int(offset) + 20)
#     request_url = url.replace(f"start_offset={offset}", f"start_offset={new_offset}")
#
#     return Request(url=request_url, method="GET", callback=self.parse)
# ```

# %% [markdown]
# ```python
# def load_review(review, product_id):
#     # original code
#     # ...
#     # ...
#
#     # my code
#     from bs4 import BeautifulSoup
#     import json
#
#     # user_id
#     try:
#         user_id = re.findall("profiles/(\d+)/", review.select(".avatar > a")[0]['href'])
#         if user_id:
#             loader.add_value('user_id', user_id[0])
#     except:
#         pass
#
#     # more ...
# ```

# %% [markdown]
# ### Scraping

# %% [markdown]
# After all the modifications made, I simply ran the scrapy spiders to do all the heavy lifting for me!
# ```
# $ scrapy crawl <spider name> -o <output.file>
# ```

# %% [markdown]
# # Cleaning scraped DLC data

# %%
import pandas as pd
import numpy as np
import re

# %%
# load dlc data
dlcs_raw = pd.read_json('raw_data/dlcs_all.json')
dlcs_raw = dlcs_raw.drop(columns=['metascore','early_access'])
print(dlcs_raw.shape[0], dlcs_raw.shape[1])
dlcs_raw.head(100)
# Out:
# 12841 17
#                                              app_name  \
# 0                    Stellar Interface - Murum Charta
# 1   SUPER ARMY OF TENTACLES 3, Winter Outfit Pack ...
# 2   X-Plane 11 - Add-on: Aerosoft - Airport Wilmin...
# 3     Train Simulator: RhB Enhancement Pack 02 Add-On
# 4     Waiting For the Loop Official Soundtrack and EP
# 5   Banyu Lintar Angin - Little Storm - Deluxe Edi...
# 6                          A Raven Monologue Fan Pack
# 7                        Truth: Disorder - Soundtrack
# 8              FURIDASHI - PREMIUM CAR: 2015 STRONGER
# 9                FURIDASHI - PREMIUM CAR: 1986 AE-86S
# 10                 FURIDASHI - PREMIUM CAR: 1988 NS13
# 11               FURIDASHI - PREMIUM CAR: 2013 AE-86S
# 12                FURIDASHI - PREMIUM CAR: 2008 DRX-8
# 13                StarBallMadNess - Christmas Special
# 14  Pixel Puzzles Ultimate - Puzzle Pack: Variety ...
# 15  FSX Steam Edition: Farm Strips Vol 4: North En...
# 16  The Disappearing of Gensokyo: Sakuya, Koishi, ...
# 17                   F-15C: The Georgian War Campaign
# 18                               Lock Parsing - Steel
# 19                                Lock Parsing - Gold
# 20                              Lock Parsing - Chrome
# 21                           Lock Parsing - Aluminium
# 22                     East India Company: Pirate Bay
# 23  RACE 07: Andy Priaulx Crowne Plaza Raceway (Fr...
# 24           GTR Evolution Expansion Pack for RACE 07
# 25     STCC - The Game 1 - Expansion Pack for RACE 07
# 26                              Euro Fishing: Waldsee
# 27  X-Plane 11 - Add-on: Skyline Simulations - KSN...
# 28                    Hello Neighbor's Favorite Songs
# 29     RPG Maker VX Ace - Time Fantasy: Farm and Fort
# ..                                                ...
# 70  Worms Reloaded: The "Pre-order Forts and Hats"...
# 71             WTCC 2010 – Expansion Pack for RACE 07
# 72         Just Cause 2: Black Market Aerial Pack DLC
# 73                   Cities in Motion: Design Marvels
# 74                                       APOX: Legend
# 75             Just Cause 2: Bull's Eye Assault Rifle
# 76      Total War: SHOGUN 2 - The Ikko Ikki Clan Pack
# 77  Warhammer 40,000: Dawn of War II - Retribution...
# 78                                  Beat Hazard Ultra
# 79                         Frozen Synapse: Soundtrack
# 80          Men of War: Assault Squad - Skirmish Pack
# 81                           A.R.E.S.: Berzerker Suit
# 82                         Aaaaa! - Brutal Concussion
# 83                Delve Deeper: Treasures and Tunnels
# 84                 The Kings' Crusade: Arabian Nights
# 85                   Cities in Motion: Metro Stations
# 86      Total War: SHOGUN 2 - Sengoku Jidai Unit Pack
# 87              Train Simulator: Class 455 EMU Add-On
# 88                                SpaceChem: 63 Corvi
# 89  Super Street Fighter IV: Arcade Edition - Comp...
# 90  Call of Duty®: Black Ops Annihilation Content ...
# 91  Super Street Fighter IV: Arcade Edition - Comp...
# 92  Super Street Fighter IV: Arcade Edition - Comp...
# 93                       Sanctum: Official Soundtrack
# 94                Orcs Must Die! - Artifacts of Power
# 95  Call of Duty®: Black Ops - Rezurrection Conten...
# 96      Train Simulator: Horseshoe Curve Route Add-On
# 97  Total War: SHOGUN 2 - Rise of the Samurai Camp...
# 98                 Fallout New Vegas: Courier's Stash
# 99          Fallout New Vegas®: Gun Runners’ Arsenal™
#
#                                           description  \
# 0   [, About This Content, ►, Murum Charta, Commun...
# 1   [, About This Content, Unlocks three new ultra...
# 2   [, About This Content, The Wilmington Internat...
# 3   [, About This Content, Get ready for another h...
# 4   [, About This Content, With its three dark ele...
# 5   [, About This Content, Banyu Lintar Angin is a...
# 6   [, About This Content, A Raven Monologue is a ...
# 7   [, About This Content, Disorderia (Soundtracks...
# 8   [, About This Content, DLC with full upgraded ...
# 9   [, About This Content, DLC with full upgraded ...
# 10  [, About This Content, DLC with full upgraded ...
# 11  [, About This Content, DLC with full upgraded ...
# 12  [, About This Content, DLC with full upgraded ...
# 13  [, About This Content, StarBallMadNess  Christ...
# 14  [, About This Content, Pixel Puzzles Ultimate,...
# 15  [, About This Content, Return to grassroots fl...
# 16  [, About This Content, , This Pack will add Sa...
# 17  [, About This Content, "The Georgian War" is a...
# 18  [, About This Content, Do you want to feel spe...
# 19  [, About This Content, Do you want to feel spe...
# 20  [, About This Content, Do you want to feel spe...
# 21  [, About This Content, Do you want to feel spe...
# 22  [, About This Content, Want to concentrate on ...
# 23  [, About This Content, Blue skies and white be...
# 24  [, About This Content, 49 unique cars in 12 cl...
# 25  [, About This Content, STCC The Game is the of...
# 26  [, About This Content, Waldsee (Forest Lake) i...
# 27  [, About This Content, John Wayne Internationa...
# 28  [, About This Content, "Neighbor's favorite so...
# 29  [, About This Content, A graphics expansion wi...
# ..                                                ...
# 70  [, About This Content, For Worms™ Reloaded pla...
# 71  [, About This Content, Four detailed and authe...
# 72  [, About This Content, With the Black Market A...
# 73  [, About This Content, Design Marvels adds fiv...
# 74  [, About This Content, , "The world ended beca...
# 75  [, About This Content, More powerful than the ...
# 76  [, About This Content, The Ikko Ikki Clan Pack...
# 77  [, About This Content, Revamp your heroes and ...
# 78  [, About This Content, , Beat Hazard Ultra DLC...
# 79  [, About This Content, A fusion of lo-fi elect...
# 80  [, About This Content, Receive a full set of 5...
# 81  [, About This Content, , Due to over exposure ...
# 82  [, About This Content, , Dejobaan Games loves ...
# 83  [, About This Content, , "Treasures and Tunnel...
# 84  [, About This Content, , Welcome to the magica...
# 85  [, About This Content, Some of the world’s fav...
# 86  [, About This Content, The Total War: SHOGUN 2...
# 87  [, About This Content, The Class 455 EMU is ty...
# 88  [, About This Content, Explore the past with S...
# 89  [, About This Content, All alternate costumes ...
# 90  [, About This Content, Obliterate the competit...
# 91  [, About This Content, All alternate costumes ...
# 92  [, About This Content, All alternate costumes ...
# 93  [, About This Content, Ever wanted to enjoy th...
# 94  [, About This Content, Expand your, Orcs Must ...
# 95  [, About This Content, Lift off into the lates...
# 96  [, Classics Range, , The Classics Range featur...
# 97  [, About This Content, , Rise of The Samurai, ...
# 98  [, About This Content, Wake up in the Mojave W...
# 99  [, About This Content, The famous weapons manu...
#
#                                             developer  discount_price  \
# 0                                 ImaginationOverflow             NaN
# 1                      Stegalosaurus Game Development             NaN
# 2                                  Drawbridge Designs             NaN
# 3                                 Thomson Interactive             NaN
# 4                                         Bryan Minus             NaN
# 5                                      Mojiken Studio             NaN
# 6                                      Mojiken Studio             NaN
# 7                                             JustE A             NaN
# 8                                  Drift Physics Crew            1.88
# 9                                  Drift Physics Crew            1.88
# 10                                 Drift Physics Crew            1.88
# 11                                 Drift Physics Crew            1.88
# 12                                 Drift Physics Crew             NaN
# 13                                      GreenGasGames             NaN
# 14                                       DL Softworks            8.39
# 15                                         Neil Birch             NaN
# 16                                       MyACG Studio             NaN
# 17                                      Baltic Dragon             NaN
# 18                                           MechEvol          119.99
# 19                                           MechEvol          119.99
# 20                                           MechEvol          119.99
# 21                                           MechEvol          119.99
# 22                                        Nitro Games             NaN
# 23                                             SimBin             NaN
# 24                                             SimBin             NaN
# 25                                             SimBin             NaN
# 26                                     Dovetail Games             NaN
# 27                                                NaN             NaN
# 28                       Dynamic Pixels,Rockit Gaming            6.29
# 29                                           KADOKAWA            7.64
# ..                                                ...             ...
# 70                                 Team17 Digital Ltd             NaN
# 71                                             SimBin             NaN
# 72                                  Avalanche Studios             NaN
# 73                                Colossal Order Ltd.             NaN
# 74                              BlueGiant Interactive             NaN
# 75                                  Avalanche Studios             NaN
# 76  The Creative Assembly,Feral Interactive (Mac),...             NaN
# 77  Relic Entertainment,Feral Interactive (Mac/Linux)             NaN
# 78                                    Cold Beam Games             NaN
# 79                                             Mode 7             NaN
# 80                                    Digitalmindsoft             NaN
# 81                                      Extend Studio             NaN
# 82                                Dejobaan Games, LLC             NaN
# 83                                        Lunar Giant             NaN
# 84                                       NeoCoreGames             NaN
# 85                                Colossal Order Ltd.             NaN
# 86  The Creative Assembly,Feral Interactive (Mac),...             NaN
# 87                                Thomson Interactive             NaN
# 88                                        Zachtronics             NaN
# 89                                             Capcom             NaN
# 90                                           Treyarch             NaN
# 91                                             Capcom             NaN
# 92                                             Capcom             NaN
# 93                               Coffee Stain Studios             NaN
# 94                                Robot Entertainment             NaN
# 95                                           Treyarch             NaN
# 96                                     Dovetail Games             NaN
# 97  The Creative Assembly,Feral Interactive (Mac),...             NaN
# 98                             Obsidian Entertainment             NaN
# 99                             Obsidian Entertainment             NaN
#
#                                                genres      id  \
# 0                             [Action, Casual, Indie]  777450
# 1                             [Adventure, Indie, RPG]  694780
# 2                                        [Simulation]  623613
# 3                                        [Simulation]  642803
# 4                          [Adventure, Casual, Indie]  722550
# 5                                     [Casual, Indie]  760610
# 6                                     [Casual, Indie]  763280
# 7                                             [Indie]  783750
# 8                        [Racing, Simulation, Sports]  756720
# 9                        [Racing, Simulation, Sports]  756729
# 10                       [Racing, Simulation, Sports]  756731
# 11                       [Racing, Simulation, Sports]  756730
# 12                       [Racing, Simulation, Sports]  756728
# 13                                           [Casual]  740800
# 14  [Casual, Free to Play, Indie, Simulation, Spor...  734862
# 15                                       [Simulation]  643686
# 16                    [Action, Adventure, Indie, RPG]  779280
# 17                                       [Simulation]  728300
# 18                                [Indie, Simulation]  776710
# 19                                [Indie, Simulation]  776700
# 20                                [Indie, Simulation]  776711
# 21                                [Indie, Simulation]  776701
# 22                                         [Strategy]   25940
# 23                                           [Racing]    8650
# 24                                           [Racing]    8660
# 25                                           [Racing]    8690
# 26                                       [Simulation]  321473
# 27                                       [Simulation]  675358
# 28                       [Adventure, Indie, Strategy]  767890
# 29        [Design &amp; Illustration, Web Publishing]  755744
# ..                                                ...     ...
# 70                                                NaN   22630
# 71                                           [Racing]   44670
# 72                                [Action, Adventure]   35101
# 73                                       [Simulation]   73013
# 74                          [Action, Strategy, Indie]   80010
# 75                                [Action, Adventure]   35080
# 76                                                NaN   34348
# 77                                         [Strategy]   56484
# 78                            [Action, Casual, Indie]   49604
# 79                                  [Strategy, Indie]   98210
# 80                                         [Strategy]   64013
# 81                                    [Action, Indie]   92302
# 82                                    [Action, Indie]   15522
# 83                  [Adventure, Strategy, RPG, Indie]   63802
# 84                                         [Strategy]   42926
# 85                                       [Simulation]   73183
# 86                                                NaN   34342
# 87                                       [Simulation]   65229
# 88                                    [Casual, Indie]   92803
# 89                                           [Action]   45790
# 90                                           [Action]   42722
# 91                                           [Action]   45791
# 92                                           [Action]   45794
# 93                                            [Indie]   91604
# 94                          [Action, Indie, Strategy]  102622
# 95                                           [Action]   42719
# 96                                       [Simulation]   65233
# 97                                         [Strategy]   34343
# 98                                      [Action, RPG]   22470
# 99                                      [Action, RPG]   72840
#
#                                           parent_game  \
# 0                                   Stellar Interface
# 1   Super Army of Tentacles 3: The Search for Army...
# 2                                          X-Plane 11
# 3                                     Train Simulator
# 4                                Waiting for the Loop
# 5                 Banyu Lintar Angin - Little Storm -
# 6                                   A Raven Monologue
# 7                                     Truth: Disorder
# 8                        FURIDASHI: Drift Cyber Sport
# 9                        FURIDASHI: Drift Cyber Sport
# 10                       FURIDASHI: Drift Cyber Sport
# 11                       FURIDASHI: Drift Cyber Sport
# 12                       FURIDASHI: Drift Cyber Sport
# 13                                    StarBallMadNess
# 14                             Pixel Puzzles Ultimate
# 15        Microsoft Flight Simulator X: Steam Edition
# 16            永遠消失的幻想鄉 ～ The Disappearing of Gensokyo
# 17                                          DCS World
# 18                                       Lock Parsing
# 19                                       Lock Parsing
# 20                                       Lock Parsing
# 21                                       Lock Parsing
# 22                                                NaN
# 23                                            RACE 07
# 24                                            RACE 07
# 25                                            RACE 07
# 26                                       Euro Fishing
# 27                                         X-Plane 11
# 28                                     Hello Neighbor
# 29                                   RPG Maker VX Ace
# ..                                                ...
# 70                                     Worms Reloaded
# 71                                            RACE 07
# 72                                       Just Cause 2
# 73                                   Cities in Motion
# 74                                               APOX
# 75                                       Just Cause 2
# 76                                Total War: SHOGUN 2
# 77      Warhammer 40,000: Dawn of War II: Retribution
# 78                                        Beat Hazard
# 79                                     Frozen Synapse
# 80                          Men of War: Assault Squad
# 81                        A.R.E.S.: Extinction Agenda
# 82       AaAaAA!!! - A Reckless Disregard for Gravity
# 83                                       Delve Deeper
# 84                                 The Kings' Crusade
# 85                                   Cities in Motion
# 86                                Total War: SHOGUN 2
# 87                                    Train Simulator
# 88                                          SpaceChem
# 89                           Ultra Street Fighter® IV
# 90                           Call of Duty®: Black Ops
# 91                           Ultra Street Fighter® IV
# 92                           Ultra Street Fighter® IV
# 93                                            Sanctum
# 94                                     Orcs Must Die!
# 95                           Call of Duty®: Black Ops
# 96                                    Train Simulator
# 97                                Total War: SHOGUN 2
# 98                                 Fallout: New Vegas
# 99                                 Fallout: New Vegas
#
#                               parent_game_url   price  \
# 0   http://store.steampowered.com/app/517330/    Free
# 1   http://store.steampowered.com/app/592200/    0.99
# 2   http://store.steampowered.com/app/269950/   19.99
# 3    http://store.steampowered.com/app/24010/   19.99
# 4   http://store.steampowered.com/app/717830/    1.99
# 5   http://store.steampowered.com/app/744800/    2.99
# 6   http://store.steampowered.com/app/744810/    2.99
# 7   http://store.steampowered.com/app/755350/    0.99
# 8   http://store.steampowered.com/app/658570/    2.99
# 9   http://store.steampowered.com/app/658570/    2.99
# 10  http://store.steampowered.com/app/658570/    2.99
# 11  http://store.steampowered.com/app/658570/    2.99
# 12  http://store.steampowered.com/app/658570/    2.99
# 13  http://store.steampowered.com/app/673050/    Free
# 14  http://store.steampowered.com/app/351030/   11.99
# 15  http://store.steampowered.com/app/314160/    9.99
# 16  http://store.steampowered.com/app/776490/    2.99
# 17  http://store.steampowered.com/app/223750/    9.99
# 18  http://store.steampowered.com/app/775330/  199.99
# 19  http://store.steampowered.com/app/775330/  199.99
# 20  http://store.steampowered.com/app/775330/  199.99
# 21  http://store.steampowered.com/app/775330/  199.99
# 22                                        NaN    4.99
# 23    http://store.steampowered.com/app/8600/   39.99
# 24    http://store.steampowered.com/app/8600/    7.99
# 25    http://store.steampowered.com/app/8600/    2.99
# 26  http://store.steampowered.com/app/314520/   10.99
# 27  http://store.steampowered.com/app/269950/   24.99
# 28  http://store.steampowered.com/app/521890/    6.99
# 29  http://store.steampowered.com/app/220700/    8.99
# ..                                        ...     ...
# 70   http://store.steampowered.com/app/22600/    1.99
# 71    http://store.steampowered.com/app/8600/    3.99
# 72    http://store.steampowered.com/app/8190/    1.99
# 73   http://store.steampowered.com/app/73010/    3.99
# 74   http://store.steampowered.com/app/80000/    4.99
# 75    http://store.steampowered.com/app/8190/    0.99
# 76  http://store.steampowered.com/app/201270/    4.99
# 77   http://store.steampowered.com/app/56437/    2.99
# 78   http://store.steampowered.com/app/49600/    4.99
# 79   http://store.steampowered.com/app/98200/    5.99
# 80   http://store.steampowered.com/app/64000/    1.99
# 81   http://store.steampowered.com/app/92300/    0.99
# 82   http://store.steampowered.com/app/15520/    1.99
# 83   http://store.steampowered.com/app/63800/    0.99
# 84   http://store.steampowered.com/app/42920/    3.99
# 85   http://store.steampowered.com/app/73010/    2.99
# 86  http://store.steampowered.com/app/201270/    2.99
# 87   http://store.steampowered.com/app/24010/   19.99
# 88   http://store.steampowered.com/app/92800/    1.99
# 89   http://store.steampowered.com/app/45760/    5.99
# 90   http://store.steampowered.com/app/42700/   14.99
# 91   http://store.steampowered.com/app/45760/    5.99
# 92   http://store.steampowered.com/app/45760/    5.99
# 93   http://store.steampowered.com/app/91600/    9.99
# 94  http://store.steampowered.com/app/102600/    1.99
# 95   http://store.steampowered.com/app/42700/   14.99
# 96   http://store.steampowered.com/app/24010/   19.99
# 97  http://store.steampowered.com/app/201270/    9.99
# 98   http://store.steampowered.com/app/22380/    0.99
# 99   http://store.steampowered.com/app/22380/    1.99
#
#                                             publisher release_date  \
# 0                                                 NaN   2017-12-30
# 1                                                 NaN   2018-01-11
# 2                                       Aerosoft GmbH   2018-01-11
# 3                             Dovetail Games - Trains   2018-01-11
# 4                                   Minus Equals Plus   2018-01-11
# 5                                    Toge Productions   2017-03-03
# 6                                    Toge Productions   2018-01-11
# 7                                    JustE Publishing   2018-01-11
# 8                                  Drift Physics Crew   2018-01-11
# 9                                  Drift Physics Crew   2018-01-11
# 10                                 Drift Physics Crew   2018-01-11
# 11                                 Drift Physics Crew   2018-01-11
# 12                                 Drift Physics Crew   2018-01-11
# 13                                                NaN   2018-01-12
# 14                                           KISS ltd   2018-01-12
# 15                            Dovetail Games - Flight   2018-01-12
# 16                                       MyACG Studio   2018-01-11
# 17                                  Eagle Dynamics SA   2018-01-12
# 18                                           MechEvol   2018-01-08
# 19                                           MechEvol   2018-01-08
# 20                                           MechEvol   2018-01-08
# 21                                           MechEvol   2018-01-08
# 22                                        Nitro Games   2009-07-31
# 23                                             SimBin   2008-06-19
# 24                                             SimBin   2008-09-01
# 25                                             SimBin   2008-10-22
# 26                                     Dovetail Games   2018-01-09
# 27                                Skyline Simulations   2018-01-09
# 28                                          tinyBuild   2018-01-09
# 29                                             Degica   2018-01-09
# ..                                                ...          ...
# 70                                 Team17 Digital Ltd   2011-05-17
# 71                                             SimBin   2011-05-20
# 72                                        Square Enix   2010-04-29
# 73                                Paradox Interactive   2011-05-20
# 74                              BlueGiant Interactive   2011-05-16
# 75                                        Square Enix   2010-06-22
# 76  SEGA, Feral Interactive (Mac), Feral Interacti...   2011-05-26
# 77                SEGA, Feral Interactive (Mac/Linux)   2011-05-26
# 78                                    Cold Beam Games   2011-06-16
# 79                                             Mode 7   2011-06-16
# 80                            1C Company, 1C-SoftClub   2011-07-21
# 81                                        ORiGO GAMES   2011-07-22
# 82                                Dejobaan Games, LLC   2011-07-22
# 83                                Lunar Giant Studios   2011-07-22
# 84                                Paradox Interactive   2011-07-26
# 85                                Paradox Interactive   2011-07-22
# 86  SEGA, Feral Interactive (Mac), Feral Interacti...   2011-07-28
# 87                            Dovetail Games - Trains   2011-07-28
# 88                                        Zachtronics   2011-07-22
# 89                                             Capcom   2011-07-29
# 90                                         Activision   2011-07-28
# 91                                             Capcom   2011-07-29
# 92                                             Capcom   2011-07-29
# 93                            Coffee Stain Publishing   2011-08-12
# 94                                Robot Entertainment   2011-10-25
# 95                                         Activision   2011-09-22
# 96                            Dovetail Games - Trains   2011-09-23
# 97  SEGA, Feral Interactive (Mac), Feral Interacti...   2011-09-27
# 98                                 Bethesda Softworks   2011-09-27
# 99                                 Bethesda Softworks   2011-09-27
#
#                                           reviews_url        sentiment  \
# 0   http://steamcommunity.com/app/777450/reviews/?...              NaN
# 1   http://steamcommunity.com/app/694780/reviews/?...              NaN
# 2   http://steamcommunity.com/app/623613/reviews/?...              NaN
# 3   http://steamcommunity.com/app/642803/reviews/?...   5 user reviews
# 4   http://steamcommunity.com/app/722550/reviews/?...              NaN
# 5   http://steamcommunity.com/app/760610/reviews/?...   2 user reviews
# 6   http://steamcommunity.com/app/763280/reviews/?...   1 user reviews
# 7   http://steamcommunity.com/app/783750/reviews/?...              NaN
# 8   http://steamcommunity.com/app/756720/reviews/?...              NaN
# 9   http://steamcommunity.com/app/756729/reviews/?...              NaN
# 10  http://steamcommunity.com/app/756731/reviews/?...              NaN
# 11  http://steamcommunity.com/app/756730/reviews/?...              NaN
# 12  http://steamcommunity.com/app/756728/reviews/?...              NaN
# 13  http://steamcommunity.com/app/740800/reviews/?...              NaN
# 14  http://steamcommunity.com/app/734862/reviews/?...              NaN
# 15  http://steamcommunity.com/app/643686/reviews/?...              NaN
# 16  http://steamcommunity.com/app/779280/reviews/?...         Positive
# 17  http://steamcommunity.com/app/728300/reviews/?...              NaN
# 18  http://steamcommunity.com/app/776710/reviews/?...              NaN
# 19  http://steamcommunity.com/app/776700/reviews/?...              NaN
# 20  http://steamcommunity.com/app/776711/reviews/?...              NaN
# 21  http://steamcommunity.com/app/776701/reviews/?...              NaN
# 22  http://steamcommunity.com/app/25940/reviews/?b...   1 user reviews
# 23  http://steamcommunity.com/app/8650/reviews/?br...            Mixed
# 24  http://steamcommunity.com/app/8660/reviews/?br...         Positive
# 25  http://steamcommunity.com/app/8690/reviews/?br...         Positive
# 26  http://steamcommunity.com/app/321473/reviews/?...   1 user reviews
# 27  http://steamcommunity.com/app/675358/reviews/?...              NaN
# 28  http://steamcommunity.com/app/767890/reviews/?...   3 user reviews
# 29  http://steamcommunity.com/app/755744/reviews/?...              NaN
# ..                                                ...              ...
# 70  http://steamcommunity.com/app/22630/reviews/?b...   7 user reviews
# 71  http://steamcommunity.com/app/44670/reviews/?b...  Mostly Positive
# 72  http://steamcommunity.com/app/35101/reviews/?b...    Very Positive
# 73  http://steamcommunity.com/app/73013/reviews/?b...   1 user reviews
# 74  http://steamcommunity.com/app/80010/reviews/?b...              NaN
# 75  http://steamcommunity.com/app/35080/reviews/?b...            Mixed
# 76  http://steamcommunity.com/app/34348/reviews/?b...   3 user reviews
# 77  http://steamcommunity.com/app/56484/reviews/?b...              NaN
# 78  http://steamcommunity.com/app/49604/reviews/?b...    Very Positive
# 79  http://steamcommunity.com/app/98210/reviews/?b...              NaN
# 80  http://steamcommunity.com/app/64013/reviews/?b...            Mixed
# 81  http://steamcommunity.com/app/92302/reviews/?b...   7 user reviews
# 82  http://steamcommunity.com/app/15522/reviews/?b...   3 user reviews
# 83  http://steamcommunity.com/app/63802/reviews/?b...   1 user reviews
# 84  http://steamcommunity.com/app/42926/reviews/?b...              NaN
# 85  http://steamcommunity.com/app/73183/reviews/?b...   6 user reviews
# 86  http://steamcommunity.com/app/34342/reviews/?b...   4 user reviews
# 87  http://steamcommunity.com/app/65229/reviews/?b...  Mostly Positive
# 88  http://steamcommunity.com/app/92803/reviews/?b...         Positive
# 89  http://steamcommunity.com/app/45790/reviews/?b...   2 user reviews
# 90  http://steamcommunity.com/app/42722/reviews/?b...  Mostly Positive
# 91  http://steamcommunity.com/app/45791/reviews/?b...   1 user reviews
# 92  http://steamcommunity.com/app/45794/reviews/?b...   1 user reviews
# 93  http://steamcommunity.com/app/91604/reviews/?b...   5 user reviews
# 94  http://steamcommunity.com/app/102622/reviews/?...         Positive
# 95  http://steamcommunity.com/app/42719/reviews/?b...    Very Positive
# 96  http://steamcommunity.com/app/65233/reviews/?b...  Mostly Positive
# 97  http://steamcommunity.com/app/34343/reviews/?b...   1 user reviews
# 98  http://steamcommunity.com/app/22470/reviews/?b...    Very Positive
# 99  http://steamcommunity.com/app/72840/reviews/?b...    Very Positive
#
#                                                 specs  \
# 0   [Single-player, Downloadable Content, Steam Ac...
# 1   [Single-player, Downloadable Content, Steam Ac...
# 2   [Single-player, Online Multi-Player, Local Mul...
# 3   [Single-player, Downloadable Content, Steam Ac...
# 4               [Single-player, Downloadable Content]
# 5               [Single-player, Downloadable Content]
# 6               [Single-player, Downloadable Content]
# 7   [Single-player, Downloadable Content, Steam Ac...
# 8   [Single-player, Multi-player, Online Multi-Pla...
# 9   [Single-player, Multi-player, Online Multi-Pla...
# 10  [Single-player, Multi-player, Online Multi-Pla...
# 11  [Single-player, Multi-player, Online Multi-Pla...
# 12  [Single-player, Multi-player, Online Multi-Pla...
# 13              [Single-player, Downloadable Content]
# 14  [Single-player, Downloadable Content, Steam Ac...
# 15  [Single-player, Multi-player, Downloadable Con...
# 16  [Single-player, Downloadable Content, Steam Ac...
# 17  [Single-player, Downloadable Content, Captions...
# 18  [Single-player, Downloadable Content, Partial ...
# 19  [Single-player, Downloadable Content, Partial ...
# 20  [Single-player, Downloadable Content, Partial ...
# 21  [Single-player, Downloadable Content, Partial ...
# 22  [Single-player, Multi-player, Downloadable Con...
# 23                             [Downloadable Content]
# 24  [Single-player, Multi-player, Downloadable Con...
# 25  [Single-player, Multi-player, Downloadable Con...
# 26  [Single-player, Online Multi-Player, Downloada...
# 27  [Single-player, Online Multi-Player, Local Mul...
# 28              [Single-player, Downloadable Content]
# 29  [Downloadable Content, Steam Trading Cards, St...
# ..                                                ...
# 70                             [Downloadable Content]
# 71  [Single-player, Multi-player, Downloadable Con...
# 72    [Downloadable Content, Full controller support]
# 73  [Single-player, Downloadable Content, Steam Ac...
# 74              [Single-player, Downloadable Content]
# 75    [Downloadable Content, Full controller support]
# 76                             [Downloadable Content]
# 77                      [Co-op, Downloadable Content]
# 78  [Single-player, Multi-player, Co-op, Shared/Sp...
# 79                             [Downloadable Content]
# 80  [Single-player, Co-op, Downloadable Content, S...
# 81  [Single-player, Downloadable Content, Partial ...
# 82              [Single-player, Downloadable Content]
# 83  [Single-player, Multi-player, Downloadable Con...
# 84  [Single-player, Multi-player, Downloadable Con...
# 85              [Single-player, Downloadable Content]
# 86                             [Downloadable Content]
# 87  [Single-player, Downloadable Content, Steam Ac...
# 88  [Single-player, Downloadable Content, Steam Ac...
# 89  [Single-player, Multi-player, Downloadable Con...
# 90  [Multi-player, Co-op, Downloadable Content, Pa...
# 91  [Single-player, Multi-player, Downloadable Con...
# 92  [Single-player, Multi-player, Downloadable Con...
# 93                             [Downloadable Content]
# 94  [Single-player, Downloadable Content, Steam Ac...
# 95  [Single-player, Multi-player, Co-op, Downloada...
# 96  [Single-player, Downloadable Content, Steam Ac...
# 97  [Single-player, Multi-player, Co-op, Downloada...
# 98  [Single-player, Downloadable Content, Steam Ac...
# 99  [Single-player, Downloadable Content, Steam Ac...
#
#                                                  tags  \
# 0                             [Action, Indie, Casual]
# 1                             [Adventure, RPG, Indie]
# 2                                        [Simulation]
# 3                                        [Simulation]
# 4                          [Adventure, Indie, Casual]
# 5                                     [Indie, Casual]
# 6                                     [Indie, Casual]
# 7                                             [Indie]
# 8                        [Simulation, Racing, Sports]
# 9                        [Simulation, Racing, Sports]
# 10                       [Simulation, Racing, Sports]
# 11                       [Simulation, Racing, Sports]
# 12                       [Simulation, Racing, Sports]
# 13                                           [Casual]
# 14  [Strategy, Free to Play, Indie, Casual, Simula...
# 15                                       [Simulation]
# 16                    [Action, Adventure, RPG, Indie]
# 17                                       [Simulation]
# 18                                [Indie, Simulation]
# 19                                [Indie, Simulation]
# 20                                [Indie, Simulation]
# 21                                [Indie, Simulation]
# 22                                         [Strategy]
# 23                               [Racing, Simulation]
# 24  [Racing, Simulation, Driving, Multiplayer, Sin...
# 25                               [Racing, Simulation]
# 26                                       [Simulation]
# 27                                       [Simulation]
# 28                       [Strategy, Adventure, Indie]
# 29            [Design & Illustration, Web Publishing]
# ..                                                ...
# 70                                                NaN
# 71                               [Racing, Simulation]
# 72                                [Adventure, Action]
# 73                                       [Simulation]
# 74                          [Strategy, Action, Indie]
# 75                                [Adventure, Action]
# 76                                                NaN
# 77                                         [Strategy]
# 78                     [Action, Indie, Casual, Music]
# 79                                  [Strategy, Indie]
# 80                                         [Strategy]
# 81                                    [Action, Indie]
# 82                                    [Action, Indie]
# 83                  [Strategy, Adventure, RPG, Indie]
# 84                                         [Strategy]
# 85                                       [Simulation]
# 86                                                NaN
# 87                                       [Simulation]
# 88                            [Indie, Casual, Puzzle]
# 89                                           [Action]
# 90                                  [Action, Zombies]
# 91                                 [Action, Fighting]
# 92                                           [Action]
# 93                                [Indie, Soundtrack]
# 94                          [Strategy, Action, Indie]
# 95                   [Action, Zombies, FPS, Survival]
# 96  [Simulation, Trains, Atmospheric, Realistic, S...
# 97                        [Strategy, Historical, RTS]
# 98                                      [Action, RPG]
# 99                                      [RPG, Action]
#
#                                                 title  \
# 0                    Stellar Interface - Murum Charta
# 1   SUPER ARMY OF TENTACLES 3, Winter Outfit Pack ...
# 2   X-Plane 11 - Add-on: Aerosoft - Airport Wilmin...
# 3     Train Simulator: RhB Enhancement Pack 02 Add-On
# 4     Waiting For the Loop Official Soundtrack and EP
# 5   Banyu Lintar Angin - Little Storm - Deluxe Edi...
# 6                          A Raven Monologue Fan Pack
# 7                        Truth: Disorder - Soundtrack
# 8              FURIDASHI - PREMIUM CAR: 2015 STRONGER
# 9                FURIDASHI - PREMIUM CAR: 1986 AE-86S
# 10                 FURIDASHI - PREMIUM CAR: 1988 NS13
# 11               FURIDASHI - PREMIUM CAR: 2013 AE-86S
# 12                FURIDASHI - PREMIUM CAR: 2008 DRX-8
# 13                StarBallMadNess - Christmas Special
# 14  Pixel Puzzles Ultimate - Puzzle Pack: Variety ...
# 15  FSX Steam Edition: Farm Strips Vol 4: North En...
# 16  The Disappearing of Gensokyo: Sakuya, Koishi, ...
# 17                   F-15C: The Georgian War Campaign
# 18                               Lock Parsing - Steel
# 19                                Lock Parsing - Gold
# 20                              Lock Parsing - Chrome
# 21                           Lock Parsing - Aluminium
# 22                     East India Company: Pirate Bay
# 23  RACE 07: Andy Priaulx Crowne Plaza Raceway (Fr...
# 24           GTR Evolution Expansion Pack for RACE 07
# 25     STCC - The Game 1 - Expansion Pack for RACE 07
# 26                              Euro Fishing: Waldsee
# 27  X-Plane 11 - Add-on: Skyline Simulations - KSN...
# 28                    Hello Neighbor's Favorite Songs
# 29     RPG Maker VX Ace - Time Fantasy: Farm and Fort
# ..                                                ...
# 70  Worms Reloaded: The "Pre-order Forts and Hats"...
# 71             WTCC 2010 – Expansion Pack for RACE 07
# 72         Just Cause 2: Black Market Aerial Pack DLC
# 73                   Cities in Motion: Design Marvels
# 74                                       APOX: Legend
# 75             Just Cause 2: Bull's Eye Assault Rifle
# 76      Total War: SHOGUN 2 - The Ikko Ikki Clan Pack
# 77  Warhammer 40,000: Dawn of War II - Retribution...
# 78                                  Beat Hazard Ultra
# 79                         Frozen Synapse: Soundtrack
# 80          Men of War: Assault Squad - Skirmish Pack
# 81                           A.R.E.S.: Berzerker Suit
# 82                         Aaaaa! - Brutal Concussion
# 83                Delve Deeper: Treasures and Tunnels
# 84                 The Kings' Crusade: Arabian Nights
# 85                   Cities in Motion: Metro Stations
# 86      Total War: SHOGUN 2 - Sengoku Jidai Unit Pack
# 87              Train Simulator: Class 455 EMU Add-On
# 88                                SpaceChem: 63 Corvi
# 89  Super Street Fighter IV: Arcade Edition - Comp...
# 90  Call of Duty®: Black Ops Annihilation Content ...
# 91  Super Street Fighter IV: Arcade Edition - Comp...
# 92  Super Street Fighter IV: Arcade Edition - Comp...
# 93                       Sanctum: Official Soundtrack
# 94                Orcs Must Die! - Artifacts of Power
# 95  Call of Duty®: Black Ops - Rezurrection Conten...
# 96      Train Simulator: Horseshoe Curve Route Add-On
# 97  Total War: SHOGUN 2 - Rise of the Samurai Camp...
# 98                 Fallout New Vegas: Courier's Stash
# 99          Fallout New Vegas®: Gun Runners’ Arsenal™
#
#                                                   url
# 0   http://store.steampowered.com/app/777450/Stell...
# 1   http://store.steampowered.com/app/694780/SUPER...
# 2   http://store.steampowered.com/app/623613/XPlan...
# 3   http://store.steampowered.com/app/642803/Train...
# 4   http://store.steampowered.com/app/722550/Waiti...
# 5   http://store.steampowered.com/app/760610/Banyu...
# 6   http://store.steampowered.com/app/763280/A_Rav...
# 7   http://store.steampowered.com/app/783750/Truth...
# 8   http://store.steampowered.com/app/756720/FURID...
# 9   http://store.steampowered.com/app/756729/FURID...
# 10  http://store.steampowered.com/app/756731/FURID...
# 11  http://store.steampowered.com/app/756730/FURID...
# 12  http://store.steampowered.com/app/756728/FURID...
# 13  http://store.steampowered.com/app/740800/StarB...
# 14  http://store.steampowered.com/app/734862/Pixel...
# 15  http://store.steampowered.com/app/643686/FSX_S...
# 16  http://store.steampowered.com/app/779280/The_D...
# 17  http://store.steampowered.com/app/728300/F15C_...
# 18  http://store.steampowered.com/app/776710/Lock_...
# 19  http://store.steampowered.com/app/776700/Lock_...
# 20  http://store.steampowered.com/app/776711/Lock_...
# 21  http://store.steampowered.com/app/776701/Lock_...
# 22  http://store.steampowered.com/app/25940/East_I...
# 23  http://store.steampowered.com/app/8650/RACE_07...
# 24  http://store.steampowered.com/app/8660/GTR_Evo...
# 25  http://store.steampowered.com/app/8690/STCC__T...
# 26  http://store.steampowered.com/app/321473/Euro_...
# 27  http://store.steampowered.com/app/675358/XPlan...
# 28  http://store.steampowered.com/app/767890/Hello...
# 29  http://store.steampowered.com/app/755744/RPG_M...
# ..                                                ...
# 70  http://store.steampowered.com/app/22630/Worms_...
# 71  http://store.steampowered.com/app/44670/WTCC_2...
# 72           http://store.steampowered.com/app/35101/
# 73  http://store.steampowered.com/app/73013/Cities...
# 74  http://store.steampowered.com/app/80010/APOX_L...
# 75           http://store.steampowered.com/app/35080/
# 76  http://store.steampowered.com/app/34348/Total_...
# 77  http://store.steampowered.com/app/56484/Warham...
# 78  http://store.steampowered.com/app/49604/Beat_H...
# 79  http://store.steampowered.com/app/98210/Frozen...
# 80  http://store.steampowered.com/app/64013/Men_of...
# 81  http://store.steampowered.com/app/92302/ARES_B...
# 82  http://store.steampowered.com/app/15522/Aaaaa_...
# 83  http://store.steampowered.com/app/63802/Delve_...
# 84  http://store.steampowered.com/app/42926/The_Ki...
# 85  http://store.steampowered.com/app/73183/Cities...
# 86  http://store.steampowered.com/app/34342/Total_...
# 87  http://store.steampowered.com/app/65229/Train_...
# 88  http://store.steampowered.com/app/92803/SpaceC...
# 89  http://store.steampowered.com/app/45790/Super_...
# 90  http://store.steampowered.com/app/42722/Call_o...
# 91  http://store.steampowered.com/app/45791/Super_...
# 92  http://store.steampowered.com/app/45794/Super_...
# 93  http://store.steampowered.com/app/91604/Sanctu...
# 94  http://store.steampowered.com/app/102622/Orcs_...
# 95  http://store.steampowered.com/app/42719/Call_o...
# 96  http://store.steampowered.com/app/65233/Train_...
# 97  http://store.steampowered.com/app/34343/Total_...
# 98  http://store.steampowered.com/app/22470/Fallou...
# 99  http://store.steampowered.com/app/72840/Fallou...
#
# [100 rows x 17 columns]

# %%
len(dlcs_raw['developer'].unique())
# Out:
# 2933

# %%
cleaned_dlcs = dlcs_raw

# %% [markdown]
# #### Drop rows with missing pub + dev + parent game info

# %%
# inspect missing publisher / developer

# Create variable with TRUE if publisher is missing
missing_pub = pd.isnull(cleaned_dlcs['publisher']) == True
# Create variable with TRUE if developer is missing
missing_dev = pd.isnull(cleaned_dlcs['developer']) == True
# Create variable with TRUE if parent game is missing
missing_parent = pd.isnull(cleaned_dlcs['parent_game_url']) == True

# Drop rows where all three fields are missing
no_pub_dev_parent = cleaned_dlcs[missing_pub & missing_dev & missing_parent]
print(len(no_pub_dev_parent))
cleaned_dlcs.drop(no_pub_dev_parent.index, inplace=True)

# Drop rows where parent game info is missing
no_parent = cleaned_dlcs[missing_parent]
print(len(no_parent))
cleaned_dlcs.drop(no_parent.index, inplace=True)
# Out:
# 14
# 144
# /Users/hyunjoohwang/anaconda3/envs/insight/lib/python3.6/site-packages/ipykernel_launcher.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()

# %% [markdown]
# #### Drop rows with missing tags or specs (missing genres won't be dropped; it could be inferred from parent game)

# %%
# inspect missing specs, tags, and genres

# Create variable with TRUE if specs is missing
missing_specs = pd.isnull(cleaned_dlcs['specs']) == True
# Create variable with TRUE if tags is missing
missing_tags = pd.isnull(cleaned_dlcs['tags']) == True
# Create variable with TRUE if genres is missing
missing_genres = pd.isnull(cleaned_dlcs['genres']) == True

# Select all cases where all three fields are missing
no_spec_tag_genre = cleaned_dlcs[missing_specs & missing_tags & missing_genres]
no_specs = cleaned_dlcs[missing_specs]
no_tags = cleaned_dlcs[missing_tags]
no_genres = cleaned_dlcs[missing_genres]
#print(no_tags)
print('missing all 3: '+ str(len(no_spec_tag_genre)))
print('missing specs: '+ str(len(no_specs)))
print('missing tags: '+ str(len(no_tags)))
print('missing genres: '+ str(len(no_genres)))

cleaned_dlcs.drop(no_tags.index, inplace=True)
# Out:
# missing all 3: 0
# missing specs: 0
# missing tags: 111
# missing genres: 145

# %% [markdown]
# #### Extract genres, tags, and specs

# %%
dlc_genres = {}
dlc_genres_count = {}
#unpack dlc genre and put it in dictionary
def unpack_genre(row):
    """This function unpacks the list of genres and stores it into a dictionary"""
    genres = row['genres']
    print(genres)
    try:
        for i in range(len(genres)):
            if genres[i] not in dlc_genres:
                dlc_genres[genres[i]] = 0
                dlc_genres_count[genres[i]] = 0
            else:
                dlc_genres_count[genres[i]] += 1
    except:
        pass

dlcs_raw.apply(unpack_genre, axis=1)
# Out:
# ['Action', 'Casual', 'Indie']
# ['Adventure', 'Indie', 'RPG']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'Casual', 'Indie']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Indie']
# ['Racing', 'Simulation', 'Sports']
# ['Racing', 'Simulation', 'Sports']
# ['Racing', 'Simulation', 'Sports']
# ['Racing', 'Simulation', 'Sports']
# ['Racing', 'Simulation', 'Sports']
# ['Casual']
# ['Casual', 'Free to Play', 'Indie', 'Simulation', 'Sports', 'Strategy']
# ['Simulation']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Simulation']
# ['Indie', 'Simulation']
# ['Indie', 'Simulation']
# ['Indie', 'Simulation']
# ['Indie', 'Simulation']
# ['Racing']
# ['Racing']
# ['Racing']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'Indie', 'Strategy']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Casual', 'Simulation']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Strategy', 'Indie', 'Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Adventure']
# ['Simulation']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Simulation', 'Strategy']
# ['Adventure', 'Indie', 'RPG']
# ['Action', 'Adventure']
# ['Action']
# ['Action', 'RPG']
# ['Strategy']
# ['Strategy']
# ['RPG']
# ['Action', 'Adventure']
# ['Action', 'RPG']
# ['Racing']
# ['Action', 'Adventure']
# ['Simulation']
# ['Action', 'Strategy', 'Indie']
# ['Action', 'Adventure']
# ['Strategy']
# ['Action', 'Casual', 'Indie']
# ['Strategy', 'Indie']
# ['Strategy']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Adventure', 'Strategy', 'RPG', 'Indie']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Casual', 'Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Indie']
# ['Action', 'Indie', 'Strategy']
# ['Action']
# ['Simulation']
# ['Strategy']
# ['Action', 'RPG']
# ['Action', 'RPG']
# ['Simulation']
# ['Action', 'Racing']
# ['Strategy', 'Indie', 'Casual', 'Simulation']
# ['Strategy', 'Indie', 'Casual', 'Simulation']
# ['Strategy', 'Indie', 'Casual', 'Simulation']
# ['Action']
# ['Strategy']
# ['Adventure', 'Indie', 'Casual']
# ['Action', 'Indie']
# ['Simulation', 'Strategy']
# ['Action', 'RPG']
# ['Racing']
# ['Racing']
# ['Action', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Action']
# ['Simulation']
# ['Casual', 'Indie', 'RPG']
# ['Action']
# ['Action', 'RPG']
# ['Casual', 'Simulation']
# ['Action']
# ['Action', 'Indie']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Action']
# ['Simulation']
# ['Adventure', 'Strategy', 'Indie']
# ['Action']
# ['Action']
# ['Action', 'Adventure']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Simulation']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Action', 'Adventure']
# ['Simulation']
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG']
# ['Simulation']
# ['Action']
# ['Action', 'Adventure']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Strategy', 'RPG', 'Indie']
# ['Simulation', 'Strategy']
# ['Strategy', 'RPG', 'Indie']
# ['Simulation']
# ['Action']
# ['Simulation']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Action']
# ['Strategy']
# ['Simulation']
# ['Action', 'Indie', 'Strategy']
# ['Simulation']
# ['Adventure', 'Casual', 'Indie']
# ['Strategy']
# ['Racing']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['RPG', 'Simulation', 'Strategy']
# ['Action', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Strategy']
# ['Strategy', 'RPG', 'Indie']
# ['Action']
# ['Racing']
# ['Casual', 'Indie', 'Strategy']
# ['Casual', 'Indie', 'Strategy']
# ['Simulation']
# ['Casual', 'Indie', 'Strategy']
# ['Action']
# ['RPG']
# ['Action']
# ['Action', 'Adventure', 'RPG', 'Indie']
# ['Strategy', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Indie']
# ['Action', 'Adventure']
# ['Simulation']
# ['Strategy', 'Indie']
# ['Strategy']
# ['Simulation']
# ['Action', 'RPG']
# ['Racing']
# ['Simulation']
# ['Action', 'Adventure', 'Strategy', 'RPG', 'Indie']
# ['Action']
# ['RPG', 'Simulation', 'Strategy']
# ['Strategy', 'Simulation']
# ['Indie', 'Casual']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['RPG', 'Strategy']
# ['Action', 'RPG']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'RPG']
# ['Action', 'RPG']
# ['Action', 'RPG']
# ['Action', 'RPG']
# ['Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Simulation']
# ['Casual', 'Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Indie']
# ['Adventure']
# ['Strategy']
# ['Action']
# ['Simulation']
# ['Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Casual', 'Strategy']
# ['Adventure', 'Casual', 'Strategy']
# ['Strategy', 'RPG', 'Indie']
# ['Indie']
# ['Action', 'Strategy']
# ['Action']
# ['Adventure', 'Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Indie', 'Strategy']
# ['Indie']
# ['Strategy']
# ['Action', 'Simulation']
# nan
# ['Action', 'RPG']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Indie', 'RPG']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action', 'Strategy']
# ['Action']
# ['Action', 'Adventure', 'Casual', 'Indie', 'RPG']
# ['Action']
# ['Action', 'Adventure', 'Casual', 'Indie', 'RPG']
# ['RPG', 'Strategy']
# ['Action', 'Indie']
# ['Strategy']
# ['RPG', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'RPG']
# ['Action', 'Racing']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Adventure']
# ['Action', 'Indie', 'Strategy']
# ['Adventure', 'Indie', 'RPG']
# ['Simulation']
# ['Action', 'Free to Play', 'Massively Multiplayer']
# ['Strategy']
# ['Strategy']
# ['Action', 'Simulation']
# ['Action', 'Simulation']
# ['Action', 'Simulation']
# ['Racing']
# ['Racing']
# ['Strategy']
# ['Action']
# ['Racing']
# ['Action']
# ['Action']
# ['Simulation', 'Strategy']
# ['Action']
# ['Strategy']
# ['Action', 'Simulation', 'Strategy']
# ['Simulation']
# ['Racing']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action', 'Indie']
# ['Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Strategy']
# ['Adventure', 'Indie']
# ['Action']
# ['Strategy', 'Casual']
# ['Strategy', 'Casual']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure']
# ['Simulation']
# ['Action', 'Simulation', 'Strategy']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Action', 'Adventure', 'Indie']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'Strategy']
# ['Strategy']
# ['Simulation']
# ['Strategy']
# ['Indie', 'Strategy']
# ['Strategy', 'Indie', 'Simulation']
# ['Indie', 'Strategy']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'RPG']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Adventure']
# ['Action', 'Adventure', 'Strategy']
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Simulation']
# ['Simulation']
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Simulation']
# ['Action']
# ['Action', 'Indie', 'Strategy']
# ['Simulation']
# ['Action', 'Indie', 'Casual']
# ['Adventure']
# ['Action']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['RPG', 'Web Publishing']
# ['Action']
# ['Casual', 'Simulation']
# ['Action', 'Free to Play', 'Massively Multiplayer', 'RPG']
# ['Simulation']
# ['Action']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Simulation']
# ['Action', 'Strategy', 'Indie', 'Casual']
# ['Action', 'Strategy', 'Indie']
# ['Action']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation', 'Strategy']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Free to Play', 'Indie', 'RPG', 'Strategy']
# ['Free to Play', 'Indie', 'RPG', 'Strategy']
# ['Free to Play', 'Indie', 'RPG', 'Strategy']
# ['Free to Play', 'Indie', 'RPG', 'Strategy']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Action', 'Indie', 'Simulation']
# ['Action']
# ['Action', 'Strategy', 'Indie']
# ['Simulation']
# ['Racing', 'Sports']
# ['Racing', 'Sports']
# ['Racing', 'Sports']
# ['Racing', 'Sports']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Action', 'RPG']
# ['Action']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'Casual', 'Indie', 'Strategy']
# ['Strategy']
# ['Strategy']
# ['Free to Play', 'Massively Multiplayer', 'RPG']
# ['Action']
# ['Action']
# ['Adventure']
# ['Indie', 'Simulation', 'Sports', 'Strategy']
# ['Strategy']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Racing', 'Sports']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action']
# ['Strategy']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'Indie']
# ['Action', 'Indie', 'Strategy']
# ['Simulation', 'Strategy']
# ['Simulation', 'Strategy']
# ['Action', 'RPG']
# ['Simulation', 'Strategy']
# ['Strategy']
# ['Action', 'Adventure']
# ['RPG', 'Simulation', 'Strategy']
# ['RPG', 'Simulation', 'Strategy']
# ['Free to Play', 'Massively Multiplayer', 'Simulation']
# ['Simulation']
# ['Action', 'RPG']
# ['Indie']
# ['Simulation']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Action', 'Strategy']
# ['Action', 'Strategy']
# ['Action', 'Strategy']
# ['Action', 'Strategy']
# ['Action', 'Strategy']
# ['Action', 'Strategy']
# ['Action', 'Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'RPG']
# ['Indie', 'RPG', 'Strategy']
# ['Racing', 'Simulation', 'Sports']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Simulation', 'Strategy']
# ['Simulation', 'Strategy']
# ['Action']
# ['Simulation']
# ['Action', 'Adventure']
# ['Simulation']
# ['Action']
# ['Strategy']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action']
# ['Simulation']
# ['Action']
# ['Simulation', 'Strategy']
# ['Simulation']
# ['Indie', 'Simulation']
# ['Simulation']
# ['Action', 'Indie', 'Strategy']
# ['Indie']
# ['Action']
# ['Action', 'Indie', 'RPG']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Simulation']
# ['Action', 'RPG']
# ['Strategy']
# ['Simulation']
# ['Strategy']
# ['Simulation']
# ['Action', 'Free to Play', 'Massively Multiplayer', 'RPG', 'Strategy']
# ['Action', 'Indie', 'Racing']
# ['Indie', 'Simulation']
# ['Strategy']
# ['Racing', 'Sports']
# ['Action', 'Adventure']
# ['Adventure', 'Casual', 'Indie', 'RPG', 'Strategy']
# ['Adventure', 'Casual', 'Indie', 'RPG', 'Strategy']
# ['Racing', 'Sports']
# ['Casual', 'Simulation']
# ['Adventure', 'Indie', 'RPG']
# ['Strategy']
# ['Indie', 'Strategy']
# ['Strategy']
# ['RPG', 'Simulation', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['RPG', 'Simulation', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Action']
# ['Action']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Audio Production']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Free to Play', 'Simulation']
# ['Free to Play', 'Simulation']
# ['Action', 'RPG']
# ['Action', 'Adventure']
# ['Strategy']
# ['Casual', 'Simulation']
# ['Action', 'RPG']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation', 'Strategy']
# ['Casual', 'Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'RPG']
# ['Action', 'Indie']
# ['Indie']
# ['Simulation']
# ['Simulation']
# ['Animation &amp; Modeling', 'Education', 'Utilities', 'Web Publishing']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Adventure', 'Casual', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Indie', 'RPG', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Adventure', 'RPG', 'Strategy']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Simulation']
# ['Action', 'Adventure']
# ['Action', 'Indie', 'Simulation']
# ['Indie', 'Simulation', 'Strategy']
# ['Action']
# ['Adventure', 'Indie', 'RPG']
# ['Action', 'Adventure']
# ['Indie', 'RPG']
# ['Indie']
# ['Indie', 'Racing', 'Simulation', 'Sports']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Action', 'RPG']
# ['Action']
# ['Casual', 'Simulation']
# ['Simulation']
# ['RPG', 'Simulation', 'Strategy']
# ['RPG', 'Simulation', 'Strategy']
# ['Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Animation &amp; Modeling', 'Audio Production', 'Utilities']
# ['Adventure', 'Indie', 'RPG']
# ['Action', 'Indie']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Action', 'Adventure', 'RPG']
# ['Action', 'Adventure', 'RPG']
# ['Simulation']
# ['Simulation', 'Strategy']
# ['Action', 'Adventure', 'RPG']
# ['Simulation', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation', 'Strategy']
# ['Casual', 'Simulation']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Action']
# ['Casual', 'Indie', 'Strategy']
# ['Action', 'RPG']
# ['RPG', 'Simulation', 'Strategy']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Audio Production']
# ['Simulation']
# ['Action', 'Adventure', 'RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['RPG', 'Strategy']
# ['Action']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure', 'RPG']
# ['Action', 'Indie', 'RPG']
# ['Action', 'Adventure', 'RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Adventure', 'Indie', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Action', 'Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'RPG']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Adventure', 'Indie']
# ['Casual', 'Simulation']
# ['Action', 'Adventure', 'Indie']
# ['Casual', 'Simulation']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Racing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Casual', 'Simulation']
# ['Action', 'Indie', 'Strategy']
# ['Simulation']
# ['Adventure', 'RPG', 'Strategy']
# ['Action', 'Indie', 'Racing']
# ['Indie', 'Simulation', 'Strategy']
# ['Adventure', 'Indie']
# ['Strategy']
# ['Indie', 'RPG']
# ['Indie', 'RPG']
# ['Indie', 'RPG']
# ['Indie', 'RPG']
# ['Indie', 'RPG']
# ['Indie', 'RPG']
# ['Indie', 'Strategy']
# ['Action', 'Simulation', 'Strategy']
# ['Indie', 'Simulation']
# ['Indie', 'Simulation']
# ['Free to Play', 'Indie', 'Strategy']
# ['Indie', 'Simulation']
# ['Action', 'Indie', 'RPG']
# ['Free to Play', 'Indie', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Indie', 'RPG']
# ['Indie', 'RPG']
# ['Action', 'Indie', 'Strategy']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Indie', 'Strategy']
# ['Indie', 'RPG']
# ['Indie']
# ['Indie', 'RPG']
# ['Action', 'Indie']
# ['Action', 'Casual', 'Indie']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Free to Play', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Indie', 'RPG']
# ['Indie', 'RPG']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Action', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Action', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Indie', 'RPG']
# ['Action']
# ['Action', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Casual', 'Indie']
# ['Action', 'RPG']
# ['Indie', 'Simulation']
# ['Action', 'Adventure']
# ['Casual', 'Strategy']
# ['Simulation', 'Strategy']
# ['Action', 'Adventure', 'Casual', 'Free to Play', 'Indie']
# ['Adventure', 'Indie', 'RPG']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Strategy']
# ['Indie', 'Simulation']
# ['Adventure', 'Indie', 'RPG']
# ['Adventure', 'RPG', 'Strategy']
# ['Action', 'Indie']
# ['Indie', 'RPG']
# ['Indie', 'RPG']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'Indie', 'RPG']
# ['Indie', 'RPG']
# ['Strategy']
# ['Strategy']
# ['RPG', 'Simulation', 'Strategy']
# ['Simulation']
# ['Adventure', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Strategy']
# ['Action', 'Massively Multiplayer', 'RPG']
# ['Action', 'Massively Multiplayer', 'RPG']
# ['Adventure', 'Casual', 'Simulation']
# ['Action', 'Massively Multiplayer', 'RPG']
# ['Indie', 'RPG']
# ['Indie', 'RPG']
# ['Action', 'Adventure']
# ['Action', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Action']
# ['Adventure', 'Casual']
# ['Animation &amp; Modeling', 'Education', 'Utilities', 'Web Publishing']
# ['Action', 'Indie', 'RPG']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Education', 'Software Training', 'Utilities']
# ['Indie', 'RPG']
# ['Casual', 'Simulation', 'Sports']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Strategy']
# ['Free to Play', 'Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Indie']
# ['Action', 'Adventure']
# ['Indie', 'RPG']
# ['Action']
# ['Casual', 'Free to Play', 'Indie']
# ['Casual', 'Free to Play', 'Indie']
# ['Simulation']
# ['Action', 'Indie']
# ['Adventure', 'Indie']
# ['Action', 'RPG']
# ['Adventure', 'Indie']
# ['Casual', 'Simulation']
# ['Racing', 'Sports']
# ['Indie', 'RPG']
# ['Action', 'Indie', 'Racing']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Indie', 'RPG']
# ['Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Indie']
# ['RPG']
# ['Casual', 'Simulation']
# ['Racing', 'Sports']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# nan
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Web Publishing']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Web Publishing']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Web Publishing']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Free to Play', 'Massively Multiplayer', 'RPG']
# ['Action']
# ['Action']
# ['Free to Play']
# ['Action']
# ['RPG', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Adventure', 'Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Indie', 'RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Indie', 'RPG']
# ['Action', 'Indie']
# ['Action', 'Free to Play', 'Massively Multiplayer', 'RPG', 'Strategy']
# ['Simulation']
# ['Action', 'Indie', 'Simulation', 'Sports']
# ['Indie', 'RPG', 'Simulation', 'Strategy']
# ['Indie', 'RPG']
# ['Adventure', 'Indie']
# ['Simulation']
# nan
# ['Casual', 'Free to Play', 'Indie', 'Massively Multiplayer', 'Strategy']
# ['Casual', 'Free to Play', 'Indie', 'Massively Multiplayer', 'Strategy']
# ['Action', 'Indie']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Action']
# ['Action']
# ['Racing']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'Indie']
# ['Simulation']
# ['Action', 'Indie']
# ['Simulation']
# ['Adventure', 'Indie']
# ['Casual', 'Strategy']
# ['Simulation']
# ['Indie', 'Simulation']
# ['Indie', 'RPG']
# ['Indie', 'RPG']
# ['Indie', 'RPG']
# ['Free to Play', 'Simulation']
# ['Free to Play', 'Simulation']
# nan
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Indie', 'Strategy']
# ['Action', 'Adventure', 'Indie']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Simulation']
# ['Indie', 'Strategy']
# ['RPG', 'Simulation', 'Strategy']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Adventure']
# ['RPG']
# ['Casual', 'Indie']
# ['Audio Production', 'Utilities']
# ['Strategy']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action', 'Casual', 'Indie', 'Racing', 'Sports']
# ['Action', 'Casual', 'Indie', 'Racing', 'Sports']
# ['Action', 'Adventure']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Indie', 'Strategy']
# ['Strategy']
# ['Animation &amp; Modeling', 'Video Production']
# ['Action', 'Adventure', 'Free to Play', 'Simulation', 'Sports']
# ['Indie']
# ['Action', 'Adventure', 'Free to Play', 'Simulation', 'Sports']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Action', 'Adventure', 'Free to Play', 'Simulation', 'Sports']
# ['Adventure', 'Indie', 'RPG']
# ['Adventure', 'Indie', 'RPG', 'Strategy']
# ['Indie', 'Simulation']
# ['Action', 'Adventure']
# ['Action']
# ['Action', 'RPG']
# ['Casual', 'Simulation']
# ['Action', 'RPG']
# ['Casual', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Simulation']
# ['Indie', 'RPG']
# ['Action', 'Racing', 'Sports']
# ['Simulation']
# ['Action', 'Adventure', 'Indie']
# ['Indie', 'RPG', 'Strategy']
# ['Racing', 'Sports']
# ['Action', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Adventure', 'Indie', 'RPG']
# ['RPG', 'Simulation', 'Strategy']
# ['Adventure', 'Indie']
# ['Casual', 'Indie', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Education', 'Software Training', 'Utilities']
# ['Strategy']
# ['Adventure', 'Indie']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Action', 'RPG']
# ['Indie', 'RPG', 'Strategy']
# ['Action', 'Adventure', 'Indie']
# ['Strategy']
# ['Indie', 'RPG']
# ['Adventure', 'Indie', 'RPG']
# ['Adventure', 'Casual', 'Indie']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Indie', 'RPG', 'Strategy']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Action', 'Adventure']
# ['Simulation']
# ['Simulation', 'Strategy']
# ['Casual', 'Simulation']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Free to Play', 'Racing', 'Simulation', 'Sports']
# ['Simulation']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Adventure']
# ['Animation &amp; Modeling', 'Video Production']
# ['Action', 'Indie']
# ['Action', 'Massively Multiplayer', 'Racing']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Action']
# ['Action']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Indie', 'RPG', 'Strategy']
# ['Indie']
# ['Simulation']
# ['Action', 'Indie']
# ['Casual', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Simulation']
# ['Action', 'RPG', 'Simulation', 'Strategy']
# ['Simulation']
# ['Action']
# ['Simulation']
# ['Action']
# ['Indie', 'Simulation', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Free to Play', 'Massively Multiplayer', 'RPG']
# ['Casual', 'Simulation']
# ['Adventure', 'Casual', 'Indie']
# ['Casual', 'Simulation']
# ['Action', 'Adventure', 'Strategy']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Action', 'Adventure', 'Strategy']
# ['RPG', 'Strategy']
# ['RPG', 'Simulation', 'Strategy']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Indie', 'RPG', 'Strategy']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Casual', 'Indie']
# ['Simulation']
# ['Indie']
# ['Action']
# ['Action', 'Free to Play']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Education', 'Software Training', 'Utilities']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Adventure', 'Indie', 'Simulation', 'Strategy']
# ['Simulation']
# ['Simulation']
# ['Action', 'Adventure']
# ['Action', 'Indie', 'Strategy']
# ['RPG', 'Strategy']
# ['Simulation']
# ['Simulation']
# ['Action', 'RPG']
# ['Action', 'RPG']
# ['Simulation']
# ['Action', 'Casual', 'Free to Play']
# ['Indie']
# ['Action', 'Indie']
# ['Strategy']
# ['Adventure', 'Casual', 'Indie', 'RPG']
# ['Adventure', 'Casual', 'Indie', 'Simulation']
# ['Indie', 'RPG', 'Strategy']
# ['Simulation']
# ['Simulation']
# ['Adventure']
# ['Action', 'Strategy']
# ['Adventure', 'Indie', 'RPG']
# ['Indie', 'RPG']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Indie', 'Strategy']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Indie', 'Strategy']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Adventure', 'Indie', 'RPG', 'Strategy']
# ['Simulation']
# ['Racing', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'Indie', 'Simulation', 'Strategy']
# ['Adventure', 'Indie']
# ['Adventure', 'Indie']
# ['Action', 'Racing', 'Sports']
# ['Strategy']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Strategy']
# ['Adventure']
# ['Strategy']
# ['Action']
# ['Adventure', 'Free to Play', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'Indie']
# ['Indie', 'Simulation', 'Strategy']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['RPG', 'Strategy']
# ['Simulation']
# ['Simulation', 'Strategy']
# ['Simulation', 'Strategy']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'RPG']
# ['Adventure', 'RPG', 'Strategy']
# ['Adventure', 'Free to Play']
# ['Action']
# ['Action', 'Indie', 'RPG']
# ['Action', 'Indie', 'RPG']
# ['Adventure', 'Casual', 'Simulation']
# ['Action', 'RPG']
# ['Action', 'Indie', 'Strategy']
# ['Simulation']
# ['Action']
# ['Action', 'Adventure']
# ['Simulation', 'Strategy']
# ['Strategy']
# ['Adventure', 'RPG', 'Strategy']
# ['Simulation', 'Strategy']
# ['Action', 'Adventure']
# ['Action']
# ['Simulation']
# ['Action', 'Indie']
# ['Free to Play', 'Racing', 'Simulation', 'Sports']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Action', 'RPG']
# ['Action', 'Adventure']
# ['Simulation']
# ['Indie', 'Racing', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'Indie']
# ['Simulation', 'Strategy']
# ['Adventure', 'Indie']
# ['Adventure', 'Indie', 'RPG']
# ['Action', 'Casual', 'Free to Play', 'RPG', 'Simulation', 'Strategy']
# ['Indie', 'Simulation']
# ['Action', 'Adventure', 'Casual', 'Free to Play', 'Massively Multiplayer', 'RPG']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Education', 'Software Training', 'Utilities']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['RPG']
# ['RPG']
# ['Casual', 'Indie']
# ['Indie', 'RPG', 'Strategy']
# ['Simulation']
# ['Action', 'Adventure', 'Free to Play', 'Indie']
# ['Racing']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Adventure']
# ['Casual', 'Indie', 'Simulation']
# ['Indie', 'Strategy']
# ['Action', 'Casual', 'Free to Play', 'RPG', 'Simulation', 'Strategy']
# ['Simulation']
# ['Strategy']
# ['Action', 'Adventure', 'Indie', 'Simulation', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Adventure', 'Indie']
# ['Action']
# ['Action']
# ['Indie', 'RPG']
# ['Action', 'Free to Play', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Casual', 'Simulation']
# ['Action', 'Free to Play', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Action']
# ['Indie', 'RPG', 'Simulation', 'Strategy']
# ['Adventure', 'Indie']
# ['Simulation', 'Strategy']
# ['Adventure', 'Indie']
# ['RPG', 'Simulation', 'Strategy']
# ['Adventure', 'Indie', 'RPG', 'Strategy']
# ['Action', 'Casual', 'Indie', 'Sports']
# ['Action', 'Indie', 'Racing']
# ['Casual', 'Indie']
# ['Action', 'Adventure', 'Free to Play', 'Indie']
# ['Action', 'Indie', 'RPG']
# ['Simulation']
# ['Action', 'Casual']
# ['Action', 'Casual']
# ['Action']
# ['Action', 'Casual', 'Free to Play', 'RPG', 'Simulation', 'Strategy']
# ['Action']
# ['Action', 'Indie', 'RPG']
# ['Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Indie', 'Massively Multiplayer', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Free to Play']
# ['Action', 'Free to Play']
# ['Action', 'Free to Play']
# ['Action', 'Adventure', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Utilities', 'Web Publishing']
# ['Indie', 'RPG', 'Strategy']
# ['Action', 'Adventure', 'Indie', 'Simulation']
# ['Action', 'Indie', 'Sports']
# ['Action', 'Indie']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG']
# ['Action', 'RPG']
# ['Adventure', 'Casual', 'Indie', 'RPG']
# ['Action', 'Casual', 'Free to Play', 'Indie']
# ['Action', 'Free to Play', 'RPG', 'Strategy']
# ['Casual', 'Indie']
# ['Adventure', 'Casual', 'Indie', 'RPG']
# ['Action', 'Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Indie', 'RPG', 'Strategy']
# ['Action', 'Casual', 'Indie']
# ['Action']
# ['Action', 'Adventure', 'Free to Play', 'Sports', 'Strategy']
# ['Action']
# ['Action', 'Adventure', 'Free to Play', 'Sports', 'Strategy']
# ['Casual', 'Simulation']
# ['Indie', 'Massively Multiplayer', 'RPG']
# ['Action', 'Indie']
# ['Simulation']
# ['Action', 'Casual', 'Indie']
# ['RPG', 'Strategy']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Action']
# ['Adventure', 'Casual', 'Indie', 'RPG']
# ['Action', 'Indie', 'RPG']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Strategy']
# ['Action', 'Strategy']
# ['Action', 'Indie', 'Simulation']
# ['Adventure', 'Casual', 'Indie']
# ['RPG']
# ['RPG']
# ['RPG']
# ['Action', 'Indie']
# ['Action', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['RPG']
# ['Simulation']
# ['Casual', 'Strategy']
# ['Adventure', 'Indie', 'RPG']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Simulation']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Utilities']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Utilities']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Utilities']
# ['Action', 'Adventure', 'Free to Play', 'Sports', 'Strategy']
# ['Casual', 'Indie', 'Simulation', 'Strategy']
# ['RPG']
# ['Adventure', 'Casual', 'Indie']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Action', 'Casual', 'Indie', 'Strategy']
# ['Action', 'Casual', 'Indie']
# ['Action', 'Adventure', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Indie', 'Sports', 'Strategy']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Utilities']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure', 'Indie', 'Strategy']
# ['Action', 'Casual', 'Free to Play', 'RPG', 'Simulation', 'Strategy']
# ['Indie', 'RPG']
# ['Action', 'Casual', 'Indie', 'Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Simulation']
# ['Adventure', 'Indie']
# ['Simulation']
# ['Action']
# ['Adventure', 'Casual', 'Indie', 'RPG', 'Simulation']
# ['Action', 'Casual', 'Free to Play', 'RPG', 'Simulation', 'Strategy']
# ['Simulation']
# ['Indie', 'RPG', 'Strategy']
# ['Audio Production']
# ['Action', 'Casual', 'Free to Play', 'RPG', 'Simulation', 'Strategy']
# ['Action']
# ['Action']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Racing', 'Simulation', 'Sports']
# ['Racing', 'Simulation', 'Sports']
# ['Action', 'Casual', 'Free to Play', 'RPG', 'Simulation', 'Strategy']
# ['Simulation']
# ['Simulation']
# ['Free to Play', 'Indie', 'Strategy']
# ['Simulation']
# ['Action', 'Casual', 'Free to Play', 'RPG', 'Simulation', 'Strategy']
# ['Simulation']
# ['Adventure', 'Casual', 'Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Indie']
# ['Action']
# ['Adventure', 'Indie']
# ['Animation &amp; Modeling', 'Utilities']
# ['Indie', 'Strategy']
# ['Racing', 'Simulation']
# ['Indie', 'Strategy']
# ['Simulation', 'Strategy']
# ['Simulation', 'Strategy']
# ['Indie']
# ['Action', 'Adventure', 'Casual', 'Free to Play', 'Massively Multiplayer', 'RPG']
# ['Adventure', 'Casual', 'Indie']
# ['Indie', 'Racing']
# ['Casual']
# ['Adventure', 'Casual', 'Indie', 'RPG']
# ['Action', 'Casual', 'Indie', 'Racing', 'Simulation', 'Sports']
# ['Action', 'Casual', 'Indie', 'Racing', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Adventure', 'Casual', 'Indie', 'Simulation', 'Sports']
# ['Action', 'Indie', 'RPG']
# ['Adventure', 'Indie', 'RPG']
# ['Simulation']
# ['Simulation']
# ['Action', 'Indie']
# ['Casual', 'Indie']
# ['Action', 'Casual', 'Indie']
# ['Action', 'Casual', 'Massively Multiplayer']
# ['Action', 'Casual', 'Massively Multiplayer']
# ['Simulation']
# ['Simulation']
# ['Racing', 'Simulation', 'Sports']
# ['Action']
# ['Action', 'Adventure', 'Indie']
# ['Racing', 'Simulation', 'Sports']
# ['Action']
# ['Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Adventure', 'Indie']
# ['Action', 'Adventure']
# ['Action', 'Indie', 'RPG']
# ['Action', 'Adventure']
# ['Adventure', 'Indie', 'RPG']
# ['Action', 'Adventure', 'Casual', 'Indie']
# ['Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Massively Multiplayer', 'Racing', 'RPG', 'Simulation']
# ['Adventure', 'Indie']
# ['Adventure', 'Casual', 'Indie']
# ['Adventure', 'Casual', 'Indie']
# ['Action', 'Massively Multiplayer', 'Racing', 'RPG', 'Simulation']
# ['Adventure', 'Casual', 'Indie', 'RPG']
# ['Adventure', 'Casual', 'Indie']
# ['Indie']
# ['Action', 'Adventure', 'Indie']
# ['Indie']
# ['Simulation']
# ['Simulation']
# ['Action', 'Indie']
# ['Adventure', 'Casual', 'Indie', 'RPG', 'Simulation']
# ['Indie', 'Strategy']
# ['Adventure', 'Indie']
# ['Action', 'Indie']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Massively Multiplayer', 'Simulation', 'Strategy']
# ['Indie', 'Massively Multiplayer', 'Simulation', 'Strategy']
# ['Casual', 'Simulation']
# ['RPG']
# ['Simulation']
# ['RPG']
# ['RPG']
# ['Simulation']
# ['RPG']
# ['Simulation']
# ['RPG', 'Simulation', 'Strategy']
# ['Adventure', 'Indie']
# ['RPG']
# ['Utilities']
# ['Action']
# ['Action', 'Indie']
# ['Indie', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Indie']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Indie', 'Strategy']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['RPG', 'Strategy']
# ['Simulation']
# ['Casual', 'Indie']
# ['Indie', 'Strategy']
# ['Casual', 'Indie']
# ['Indie']
# ['Adventure', 'Casual', 'Indie']
# ['Indie', 'RPG', 'Strategy']
# ['Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG']
# ['Action', 'Indie']
# ['Action', 'Casual', 'Indie', 'Strategy']
# ['Adventure', 'Indie', 'RPG']
# ['Action', 'Indie']
# ['Indie', 'RPG']
# ['Action', 'Strategy']
# ['Action', 'Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'Adventure', 'Indie', 'Strategy']
# ['Action']
# ['Racing', 'Simulation', 'Sports']
# ['Action', 'Strategy']
# ['Racing', 'Simulation', 'Sports']
# ['Racing', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['RPG', 'Simulation', 'Strategy']
# ['Action', 'RPG']
# ['Indie', 'Strategy']
# ['Action']
# ['Indie', 'Simulation', 'Strategy']
# ['Action']
# ['Action']
# ['Indie', 'RPG', 'Strategy']
# ['Indie']
# ['Indie', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Adventure', 'Indie']
# ['Casual', 'Simulation']
# ['Adventure', 'Free to Play', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'Indie']
# ['Action', 'Massively Multiplayer', 'RPG']
# ['Indie', 'Strategy']
# ['Adventure', 'Casual', 'Indie', 'RPG', 'Strategy']
# ['Racing', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'Indie']
# ['Action', 'Simulation', 'Strategy']
# ['Simulation']
# ['Casual', 'Indie', 'Massively Multiplayer', 'Simulation', 'Sports', 'Strategy']
# ['Casual', 'Indie', 'Massively Multiplayer', 'Simulation', 'Sports', 'Strategy']
# ['Casual', 'Indie', 'Simulation', 'Sports', 'Strategy']
# ['Casual', 'Indie', 'Massively Multiplayer', 'Simulation', 'Sports', 'Strategy']
# ['Indie']
# ['Casual', 'Indie', 'RPG', 'Simulation', 'Strategy']
# ['Casual', 'Indie', 'Massively Multiplayer', 'Simulation', 'Sports', 'Strategy']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Indie', 'Racing', 'Simulation', 'Sports']
# ['Action', 'Indie']
# ['Strategy']
# ['Indie', 'Racing']
# ['Simulation']
# ['Indie']
# ['Adventure', 'Indie', 'RPG', 'Simulation', 'Strategy']
# ['Indie', 'Simulation']
# ['Action', 'Adventure', 'Indie', 'Racing']
# ['Action', 'Adventure', 'Indie']
# ['Adventure', 'Casual', 'Free to Play', 'Indie']
# ['Adventure', 'Casual', 'Free to Play', 'Indie']
# ['Free to Play', 'Sports', 'Strategy']
# ['Indie', 'Strategy']
# ['Indie', 'RPG']
# ['Audio Production', 'Software Training', 'Utilities', 'Video Production', 'Web Publishing']
# ['Adventure', 'Casual', 'Free to Play', 'Indie']
# ['Action', 'Indie']
# ['Action']
# ['Adventure', 'Indie']
# ['RPG']
# ['RPG']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Action', 'Massively Multiplayer', 'RPG']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Simulation']
# ['Strategy']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Adventure', 'Casual', 'Indie']
# ['Simulation']
# ['RPG', 'Simulation', 'Strategy']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Indie', 'Strategy']
# ['Action', 'Indie', 'RPG']
# ['Free to Play', 'Massively Multiplayer']
# ['Indie', 'RPG', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Indie', 'Simulation', 'Sports', 'Strategy']
# ['Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG', 'Strategy']
# ['Casual', 'Indie', 'Simulation', 'Strategy']
# ['Animation &amp; Modeling', 'Video Production']
# ['Action', 'Simulation', 'Strategy']
# ['Simulation']
# ['Simulation']
# ['Casual', 'Simulation', 'Sports']
# ['Audio Production', 'Utilities', 'Video Production']
# ['Audio Production', 'Utilities']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Adventure', 'Casual', 'Indie', 'Simulation']
# ['Free to Play', 'Massively Multiplayer']
# ['Adventure', 'Casual', 'Indie']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Indie']
# ['Adventure', 'Indie', 'Simulation', 'Strategy']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['RPG']
# ['RPG']
# ['Animation &amp; Modeling', 'Video Production']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Racing', 'Simulation', 'Sports']
# ['Action', 'Adventure']
# ['Action', 'Indie']
# ['RPG', 'Simulation', 'Strategy']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Adventure', 'Indie']
# ['Adventure', 'Free to Play', 'Indie']
# ['Adventure', 'Indie']
# ['Utilities']
# ['Action', 'Casual', 'Free to Play', 'Massively Multiplayer']
# ['Indie', 'RPG', 'Strategy']
# ['Simulation']
# ['Adventure', 'RPG', 'Strategy']
# ['Adventure', 'RPG', 'Strategy']
# ['Adventure', 'RPG', 'Strategy']
# ['Adventure', 'RPG', 'Strategy']
# ['Adventure', 'RPG', 'Strategy']
# ['Adventure', 'RPG', 'Strategy']
# ['Adventure', 'RPG', 'Strategy']
# ['Adventure', 'RPG', 'Strategy']
# ['Simulation']
# ['Action', 'Adventure', 'Indie', 'Strategy']
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Strategy']
# ['Strategy']
# ['Action', 'Casual', 'Indie', 'Strategy']
# ['Action', 'Indie']
# ['Adventure', 'Indie']
# ['Action', 'Indie']
# ['Adventure', 'Indie']
# ['Simulation']
# ['Action', 'Indie']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Simulation']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Education', 'Software Training', 'Utilities']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Education', 'Software Training', 'Utilities']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Education', 'Software Training', 'Utilities']
# ['Action', 'Adventure', 'Free to Play', 'RPG', 'Simulation']
# ['Action', 'Indie']
# ['Indie', 'Sports', 'Strategy']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Education', 'Software Training', 'Utilities']
# ['RPG', 'Strategy']
# ['Action', 'Adventure', 'Indie', 'Strategy']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Action', 'Adventure']
# ['Simulation']
# ['Action', 'Casual', 'Indie', 'Strategy']
# ['Adventure', 'Casual', 'Indie', 'Massively Multiplayer', 'Strategy']
# ['Indie']
# ['Indie']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Adventure', 'Casual', 'Indie', 'RPG', 'Simulation']
# ['Simulation', 'Strategy']
# ['Casual', 'Indie', 'RPG', 'Strategy']
# ['Adventure', 'Indie']
# ['Adventure', 'Indie']
# ['Simulation']
# ['Adventure', 'Indie']
# ['Indie', 'RPG', 'Strategy']
# ['Action', 'Adventure', 'Indie', 'Simulation', 'Strategy']
# ['Action', 'Free to Play', 'Indie']
# ['RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Sports', 'Strategy']
# ['Sports', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Strategy']
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Strategy']
# nan
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Strategy']
# ['Action']
# ['Action']
# ['Design &amp; Illustration', 'Photo Editing', 'Utilities']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Simulation']
# ['Action', 'RPG', 'Simulation']
# ['Simulation', 'Strategy']
# ['Adventure', 'Indie']
# ['Indie', 'RPG', 'Strategy']
# ['Casual', 'Indie']
# ['Action', 'Adventure']
# ['Indie']
# ['Casual', 'Indie']
# ['Indie', 'Simulation']
# ['Indie']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Action', 'Indie', 'Simulation', 'Strategy']
# ['Action', 'Indie']
# ['Action', 'Adventure', 'Indie', 'Simulation']
# ['Action']
# ['Indie', 'Simulation']
# ['Action', 'Indie', 'Racing']
# ['Simulation']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Adventure', 'Casual', 'Indie', 'Strategy']
# ['Adventure', 'RPG']
# ['Action', 'Adventure', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Action', 'Adventure', 'Indie', 'Massively Multiplayer', 'RPG']
# ['Racing', 'Simulation', 'Sports']
# ['Action', 'Indie']
# ...
# ['Action', 'Indie']
# ['Strategy']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Action']
# ['Action']
# ['Simulation']
# ['Action', 'Adventure']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Simulation']
# ['Action', 'Simulation']
# ['Action', 'Simulation']
# ['Action', 'Simulation']
# ['Simulation']
# ['Simulation']
# ['Action', 'RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Free to Play', 'Indie', 'Strategy']
# ['Casual', 'Free to Play', 'Indie', 'Strategy']
# ['Casual', 'Free to Play', 'Indie', 'Strategy']
# ['Casual', 'Free to Play', 'Indie', 'Strategy']
# ['Action', 'Casual', 'Indie']
# ['Casual', 'Free to Play', 'Indie', 'Strategy']
# ['Simulation']
# ['Indie', 'Strategy']
# ['Simulation', 'Strategy']
# ['Strategy']
# ['Indie']
# ['Action', 'Adventure']
# ['Action', 'Adventure', 'Strategy', 'RPG', 'Indie']
# ['Action', 'Adventure']
# ['Action']
# ['Strategy', 'Indie', 'Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Free to Play', 'Indie', 'Strategy']
# ['Casual', 'Simulation']
# ['Racing']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Racing']
# ['Racing']
# ['Racing']
# ['Racing']
# ['Action']
# ['Racing']
# ['Action']
# ['Strategy']
# ['Action']
# ['Action']
# ['Indie']
# ['Action', 'RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Indie', 'Racing']
# ['Action']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Strategy', 'RPG', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'Indie']
# ['Casual', 'Simulation']
# ['Simulation', 'Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual']
# ['Action', 'Casual', 'Indie', 'Strategy']
# ['Simulation']
# ['Strategy']
# ['Action', 'RPG']
# ['Action']
# ['Action', 'Free to Play', 'Indie', 'Strategy']
# ['Strategy']
# ['Action']
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG']
# ['Action', 'Indie']
# ['Action', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Strategy']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Indie', 'Strategy']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Action', 'Indie', 'Strategy']
# ['Casual', 'Indie']
# ['Simulation']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'Casual', 'Indie', 'RPG']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Casual', 'Indie', 'Strategy']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Racing']
# ['Casual', 'Strategy']
# ['Action']
# ['Massively Multiplayer', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Strategy']
# ['Action']
# ['Action']
# ['RPG', 'Indie']
# ['Action', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Strategy']
# ['RPG', 'Strategy']
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'RPG', 'Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Indie']
# ['Adventure', 'Casual', 'Free to Play', 'Indie', 'RPG']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Strategy', 'RPG', 'Indie']
# ['Strategy']
# ['Action', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'RPG']
# ['Strategy', 'Simulation']
# ['Action', 'Indie']
# ['Action', 'Adventure']
# ['Indie', 'Strategy']
# ['Indie', 'Strategy']
# ['Action', 'Strategy', 'RPG', 'Indie']
# ['Strategy']
# ['Action', 'Adventure']
# ['Strategy']
# ['Action', 'Strategy', 'Indie', 'Casual']
# ['Strategy', 'RPG', 'Indie']
# ['Simulation']
# ['Action', 'RPG', 'Indie']
# ['Action', 'RPG']
# ['Action']
# ['Strategy', 'RPG', 'Indie']
# ['Action']
# ['Simulation']
# ['Casual', 'Strategy']
# ['Casual', 'Strategy']
# ['Strategy', 'RPG', 'Indie']
# ['Simulation', 'Strategy']
# ['Action', 'Indie']
# ['RPG', 'Simulation', 'Strategy']
# ['Action']
# ['RPG', 'Simulation', 'Strategy']
# ['RPG', 'Simulation', 'Strategy']
# ['Simulation']
# ['Action', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action', 'RPG', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Action', 'Indie']
# ['Action', 'RPG']
# ['Action']
# ['Action', 'RPG', 'Indie']
# ['Action', 'RPG', 'Indie']
# ['Strategy', 'RPG']
# ['Strategy']
# ['Casual', 'Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action', 'Simulation']
# ['Action', 'Casual', 'Indie', 'Strategy']
# ['Action']
# ['Action', 'RPG', 'Indie']
# ['Action', 'Indie']
# ['Action']
# ['Action']
# ['Casual', 'Strategy']
# ['Action', 'RPG', 'Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Indie', 'Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action', 'RPG', 'Indie']
# ['Strategy']
# ['Adventure', 'Strategy']
# ['Action', 'Indie', 'Strategy']
# ['Simulation', 'Strategy']
# ['Strategy']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action']
# ['Strategy', 'RPG', 'Indie']
# ['Action', 'Indie']
# ['Strategy']
# ['Action']
# ['Indie']
# ['Action']
# ['Adventure', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Simulation']
# ['Action', 'RPG', 'Indie']
# ['Action', 'RPG', 'Indie']
# ['Action', 'Adventure', 'RPG']
# ['Action']
# ['Strategy', 'Indie', 'Simulation']
# ['Simulation']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'RPG']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Action']
# ['Action', 'Strategy', 'Indie', 'Casual']
# ['Indie']
# ['Strategy']
# ['Simulation']
# ['Action', 'RPG']
# ['Strategy']
# ['Action', 'RPG']
# ['Action', 'Strategy', 'Indie', 'Casual']
# ['RPG']
# ['RPG']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'RPG']
# ['Action', 'RPG']
# ['Action', 'RPG']
# ['Strategy']
# ['Racing']
# ['Action', 'RPG']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'RPG']
# ['Action']
# ['Action']
# ['Action', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Strategy']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Adventure', 'Indie', 'RPG']
# ['Simulation']
# ['Simulation']
# ['Action', 'RPG']
# ['Action']
# ['Simulation']
# ['Strategy']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Simulation']
# ['Strategy', 'Simulation']
# ['Casual', 'Strategy']
# ['Action', 'RPG']
# ['Adventure', 'Indie', 'RPG']
# ['Strategy']
# ['Action']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Strategy']
# ['Racing']
# ['Strategy']
# ['Strategy', 'RPG']
# ['Action', 'RPG']
# ['Racing']
# ['Action', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Action', 'Adventure']
# ['Simulation']
# ['Strategy', 'Indie', 'Simulation']
# ['Indie', 'Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'RPG']
# ['Strategy']
# ['RPG']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Action']
# ['Strategy', 'Indie', 'Simulation']
# ['Action']
# ['Adventure', 'Indie', 'RPG']
# ['Strategy']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action', 'Simulation', 'Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Action']
# ['Strategy']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action']
# ['Action', 'RPG']
# ['Simulation']
# ['Action']
# ['Strategy']
# ['Indie', 'Strategy']
# ['Simulation', 'Strategy']
# ['Strategy']
# ['Strategy', 'Indie']
# ['Simulation']
# ['Action']
# ['Action']
# ['Strategy', 'RPG']
# ['Simulation', 'Strategy']
# ['RPG']
# ['RPG']
# ['RPG']
# ['RPG']
# ['RPG']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Indie']
# ['Indie']
# ['Indie']
# ['Indie']
# ['Action']
# ['Indie']
# ['Strategy', 'Indie', 'Simulation']
# ['Strategy']
# ['Strategy', 'Simulation']
# ['Action']
# ['Action', 'Adventure']
# ['Action', 'Indie', 'Casual']
# ['Strategy', 'Simulation']
# ['Strategy', 'Indie']
# ['Strategy', 'Indie']
# ['Strategy']
# ['Action']
# ['Strategy', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Strategy']
# ['Casual', 'Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'RPG']
# ['Indie']
# ['Action', 'RPG']
# ['Indie', 'Strategy']
# ['Indie']
# ['Strategy', 'Indie', 'Simulation']
# ['Strategy', 'RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Free to Play']
# ['Action']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Simulation']
# ['Action', 'Indie', 'Massively Multiplayer']
# ['Casual', 'Indie']
# nan
# ['Casual', 'Indie']
# ['Casual', 'Indie']
# ['Adventure', 'Indie']
# ['Action', 'Adventure', 'Casual', 'Indie']
# ['Action', 'Indie', 'Strategy']
# ['Action']
# ['Utilities']
# ['Utilities']
# ['Utilities']
# ['Utilities']
# ['Action', 'Adventure', 'Casual', 'Indie', 'RPG']
# ['Utilities']
# ['Action', 'Indie']
# ['Action', 'Free to Play']
# ['Action', 'Casual', 'Free to Play', 'Indie', 'Racing']
# ['Indie', 'Simulation']
# ['Action', 'Casual', 'Free to Play', 'Indie', 'Racing']
# ['Action', 'Casual', 'Free to Play', 'Indie', 'Racing']
# ['Casual', 'Indie', 'RPG', 'Simulation', 'Strategy']
# ['Adventure', 'Casual', 'Indie', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'RPG']
# ['Racing', 'Simulation']
# ['Adventure', 'Casual', 'Indie', 'Simulation', 'Strategy']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Racing', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Racing', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'Indie', 'RPG']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Indie', 'Massively Multiplayer']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Casual', 'Free to Play', 'Massively Multiplayer', 'Sports']
# ['Action', 'Casual', 'Free to Play', 'Massively Multiplayer', 'Sports']
# ['Action', 'Casual', 'Free to Play', 'Massively Multiplayer', 'Sports']
# ['Action', 'Adventure', 'Casual', 'Indie', 'Strategy']
# ['Action', 'Indie']
# ['Adventure', 'Casual', 'Indie', 'Simulation', 'Sports']
# ['Adventure', 'Casual', 'Indie', 'Simulation', 'Sports']
# ['Indie', 'Strategy']
# ['Action', 'Massively Multiplayer', 'Racing']
# ['Action', 'Adventure', 'Indie', 'RPG', 'Strategy']
# ['RPG']
# ['Massively Multiplayer', 'Racing', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'Casual', 'Indie']
# ['Indie']
# ['Adventure', 'Casual', 'Free to Play', 'Indie']
# ['Animation &amp; Modeling', 'Design &amp; Illustration', 'Utilities']
# ['Action', 'Casual', 'Free to Play', 'Indie', 'Racing']
# ['Adventure', 'Casual', 'Indie', 'Simulation', 'Sports']
# ['Action', 'Casual', 'Free to Play', 'Indie', 'Racing']
# ['Action', 'Free to Play']
# ['Action', 'Casual', 'Free to Play', 'Indie', 'Racing']
# ['Action', 'Casual', 'Free to Play', 'Indie', 'Racing']
# ['Action', 'Free to Play']
# ['Action', 'Free to Play']
# ['Adventure', 'Casual', 'Indie', 'RPG']
# ['Adventure', 'Casual', 'Indie', 'RPG', 'Simulation', 'Strategy']
# ['Action', 'Indie']
# ['Adventure', 'Indie', 'RPG']
# ['Utilities']
# ['Casual']
# ['Utilities']
# ['Casual', 'Strategy']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Strategy']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Indie']
# ['Action']
# ['Simulation']
# ['Casual']
# ['Action', 'Casual', 'Indie', 'Simulation']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Indie', 'RPG', 'Strategy']
# ['Free to Play', 'Massively Multiplayer', 'RPG']
# ['RPG']
# ['Adventure', 'Indie']
# ['Casual', 'Simulation']
# ['Adventure', 'Indie']
# ['Action', 'Adventure']
# ['Action', 'Adventure', 'Casual', 'Free to Play', 'Massively Multiplayer', 'RPG']
# ['Strategy']
# ['Action', 'Adventure', 'Casual', 'Free to Play', 'Massively Multiplayer', 'RPG']
# ['Design &amp; Illustration', 'Web Publishing']
# ['Casual', 'Indie', 'RPG', 'Simulation', 'Strategy']
# ['Animation &amp; Modeling']
# ['Simulation']
# ['Animation &amp; Modeling']
# ['Racing']
# ['Action']
# ['Casual', 'Indie', 'Simulation']
# ['Adventure', 'Indie']
# ['Racing', 'Simulation', 'Sports']
# ['Action', 'Indie']
# ['Action', 'Free to Play', 'Strategy']
# ['Action', 'Free to Play']
# ['Action']
# ['Simulation']
# ['Indie']
# ['Indie']
# ['Indie']
# ['Action', 'Free to Play', 'Indie', 'RPG']
# ['Action', 'Free to Play', 'Indie', 'RPG']
# ['Action', 'Free to Play', 'Indie', 'RPG']
# ['Adventure', 'Casual', 'Indie']
# ['Adventure', 'Indie']
# ['Simulation']
# ['Indie', 'Simulation']
# ['Free to Play', 'Massively Multiplayer', 'Simulation', 'Sports']
# ['Simulation']
# ['Action', 'Indie', 'RPG', 'Simulation']
# ['Action', 'Indie', 'Strategy']
# ['Simulation']
# ['Casual', 'Strategy']
# ['Simulation']
# ['Indie', 'RPG']
# ['Racing']
# ['Casual', 'Indie']
# ['RPG']
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# 30       None
#          ...
# 12811    None
# 12812    None
# 12813    None
# 12814    None
# 12815    None
# 12816    None
# 12817    None
# 12818    None
# 12819    None
# 12820    None
# 12821    None
# 12822    None
# 12823    None
# 12824    None
# 12825    None
# 12826    None
# 12827    None
# 12828    None
# 12829    None
# 12830    None
# 12831    None
# 12832    None
# 12833    None
# 12834    None
# 12835    None
# 12836    None
# 12837    None
# 12838    None
# 12839    None
# 12840    None
# Length: 12572, dtype: object

# %%
# save dictionaries as csv
(pd.DataFrame.from_dict(data=dlc_genres_count, orient='index').
to_csv('dlc_genres_count.csv', header=True))

(pd.DataFrame.from_dict(data=dlc_genres, orient='index').
to_csv('dlc_genres.csv', header=True))

# %%
dlc_specs = {}
dlc_specs_count = {}
#unpack dlc genre and put it in dictionary
def unpack_specs(row):
    """This function unpacks the list of specs and stores it into a dictionary"""
    specs = row['specs']
    print(specs)

    try:
        for i in range(len(specs)):
            if specs[i] not in dlc_specs:
                dlc_specs[specs[i]] = 0
                dlc_specs_count[specs[i]] = 0
            else:
                dlc_specs_count[specs[i]] += 1
    except:
        pass

dlcs_raw.apply(unpack_specs, axis=1)
# Out:
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud', 'Stats']
# ['Single-player', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Online Multi-Player', 'Local Multi-Player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Workshop']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Local Multi-Player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Local Multi-Player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Local Multi-Player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Local Multi-Player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Local Multi-Player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content', 'Captions available', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Partial Controller Support']
# ['Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Online Multi-Player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'In-App Purchases']
# ['Single-player', 'Online Multi-Player', 'Local Multi-Player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Downloadable Content', 'Steam Trading Cards', 'Steam Workshop']
# ['Downloadable Content', 'Steam Trading Cards', 'Partial Controller Support']
# ['Downloadable Content', 'Steam Trading Cards', 'Partial Controller Support']
# ['Downloadable Content', 'Steam Trading Cards', 'Partial Controller Support']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Downloadable Content', 'Steam Trading Cards', 'Steam Workshop']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Downloadable Content', 'Full controller support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Downloadable Content', 'Full controller support']
# ['Downloadable Content']
# ['Downloadable Content']
# ['Downloadable Content', 'Full controller support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards']
# ['Downloadable Content', 'Full controller support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Downloadable Content', 'Full controller support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Downloadable Content']
# ['Downloadable Content', 'Full controller support']
# ['Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Downloadable Content']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Full controller support']
# ['Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Full controller support']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Full controller support']
# ['Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Valve Anti-Cheat enabled']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements']
# ['Multi-player', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'MMO', 'Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Co-op', 'Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements']
# ['Multi-player', 'Downloadable Content']
# ['Multi-player', 'Downloadable Content']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Trading Cards', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Workshop', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards', 'Includes level editor']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Multi-player', 'Downloadable Content']
# ['Single-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Shared/Split Screen', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Steam Turn Notifications']
# ['Single-player', 'Multi-player', 'Shared/Split Screen', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Steam Turn Notifications']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Shared/Split Screen', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Steam Turn Notifications']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Stats']
# ['Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Downloadable Content']
# ['Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Stats', 'Steam Leaderboards']
# ['Downloadable Content']
# ['Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Captions available', 'Partial Controller Support', 'Includes level editor']
# ['Downloadable Content']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'MMO', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Valve Anti-Cheat enabled']
# ['Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Valve Anti-Cheat enabled']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Multi-player', 'MMO', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Valve Anti-Cheat enabled']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Valve Anti-Cheat enabled']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Downloadable Content']
# ['Multi-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Valve Anti-Cheat enabled']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Valve Anti-Cheat enabled', 'Stats', 'Includes level editor']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Local Multi-Player', 'Co-op', 'Online Co-op', 'Local Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Steam Cloud', 'Includes level editor']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Multi-player', 'Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Valve Anti-Cheat enabled', 'Stats', 'Includes level editor']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud']
# ['MMO', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Multi-player', 'MMO', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Valve Anti-Cheat enabled']
# ['Downloadable Content']
# ['Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Multi-player', 'MMO', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Valve Anti-Cheat enabled']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Multi-player', 'Cross-Platform Multiplayer', 'Downloadable Content']
# ['Multi-player', 'Cross-Platform Multiplayer', 'Downloadable Content']
# ['Multi-player', 'Cross-Platform Multiplayer', 'Downloadable Content']
# ['Multi-player', 'Cross-Platform Multiplayer', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Steam Leaderboards']
# ['Multi-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Valve Anti-Cheat enabled']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Cross-Platform Multiplayer', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Steam Workshop', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards', 'Includes level editor']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud']
# ['Single-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'MMO', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Valve Anti-Cheat enabled', 'Stats', 'Includes level editor']
# ['Single-player', 'Multi-player', 'Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Valve Anti-Cheat enabled', 'Stats', 'Includes level editor']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Steam Leaderboards']
# ...
# ['Single-player', 'Downloadable Content', 'Partial Controller Support']
# ['Downloadable Content', 'In-App Purchases', 'Partial Controller Support', 'Includes level editor']
# ['Downloadable Content', 'In-App Purchases', 'Partial Controller Support', 'Includes level editor']
# ['Downloadable Content', 'In-App Purchases', 'Partial Controller Support', 'Includes level editor']
# ['Downloadable Content', 'In-App Purchases', 'Partial Controller Support', 'Includes level editor']
# ['Single-player', 'Downloadable Content', 'Steam Achievements']
# ['Downloadable Content', 'In-App Purchases', 'Partial Controller Support', 'Includes level editor']
# ['Downloadable Content']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Trading Cards', 'In-App Purchases', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'In-App Purchases', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'In-App Purchases', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'In-App Purchases', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'In-App Purchases', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'In-App Purchases', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'In-App Purchases', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'In-App Purchases', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'In-App Purchases', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'In-App Purchases', 'Steam Cloud', 'Steam Leaderboards']
# ['Online Multi-Player', 'Downloadable Content', 'Steam Trading Cards', 'Partial Controller Support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support']
# ['Online Multi-Player', 'MMO', 'Online Co-op', 'Downloadable Content', 'Partial Controller Support']
# ['Online Multi-Player', 'MMO', 'Online Co-op', 'Downloadable Content', 'Steam Trading Cards', 'Partial Controller Support']
# ['Online Multi-Player', 'MMO', 'Online Co-op', 'Downloadable Content', 'Steam Trading Cards', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support', 'Steam Cloud', 'Stats']
# ['Single-player', 'Multi-player', 'Local Multi-Player', 'Co-op', 'Local Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Steam Cloud', 'Valve Anti-Cheat enabled', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Online Multi-Player', 'Online Co-op', 'Downloadable Content', 'Full controller support', 'In-App Purchases', 'Steam Cloud']
# ['Single-player', 'Downloadable Content', 'Commentary available']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Trading Cards', 'In-App Purchases', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Trading Cards', 'In-App Purchases', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content', 'Steam Trading Cards', 'In-App Purchases', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Co-op', 'Online Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Steam Workshop', 'Partial Controller Support', 'Stats', 'Steam Leaderboards', 'Includes level editor']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Co-op', 'Online Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content']
# ['Downloadable Content', 'In-App Purchases', 'Includes level editor']
# ['Single-player', 'Downloadable Content', 'In-App Purchases', 'Partial Controller Support']
# ['Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Stats']
# ['Single-player', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Downloadable Content', 'Steam Achievements']
# ['Single-player', 'Multi-player', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Local Multi-Player', 'Co-op', 'Local Co-op', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content']
# ['Multi-player', 'Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content']
# ['Multi-player', 'Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content']
# ['Online Multi-Player', 'MMO', 'Downloadable Content', 'Steam Trading Cards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Partial Controller Support']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content', 'Full controller support']
# ['Single-player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Partial Controller Support', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud']
# ['Single-player', 'Online Multi-Player', 'Online Co-op', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Valve Anti-Cheat enabled']
# ['Multi-player', 'MMO', 'Co-op', 'Downloadable Content', 'Steam Trading Cards', 'Steam Workshop', 'In-App Purchases']
# ['Single-player', 'Multi-player', 'Downloadable Content']
# ['Multi-player', 'MMO', 'Co-op', 'Downloadable Content', 'Steam Trading Cards', 'Steam Workshop', 'In-App Purchases']
# ['Downloadable Content', 'Steam Trading Cards', 'Partial Controller Support']
# ['Single-player', 'Multi-player', 'Co-op', 'Shared/Split Screen', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Includes level editor']
# ['Downloadable Content', 'Steam Workshop']
# ['Single-player', 'Online Multi-Player', 'Local Multi-Player', 'Downloadable Content']
# ['Downloadable Content', 'Steam Workshop']
# ['Single-player', 'Online Multi-Player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards']
# ['Single-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud']
# ['Single-player', 'Online Multi-Player', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Online Multi-Player', 'Downloadable Content', 'Full controller support', 'In-App Purchases']
# ['Multi-player', 'Online Multi-Player', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'In-App Purchases', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Full controller support', 'Includes level editor']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Downloadable Content']
# ['Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'In-App Purchases', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'In-App Purchases', 'Stats', 'Steam Leaderboards']
# ['Multi-player', 'Co-op', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'In-App Purchases', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Trading Cards', 'Steam Cloud']
# ['Downloadable Content']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Steam Workshop', 'Partial Controller Support', 'Includes level editor']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'MMO', 'Co-op', 'Online Co-op', 'Cross-Platform Multiplayer', 'Downloadable Content', 'Full controller support']
# ['Single-player', 'Online Multi-Player', 'Local Multi-Player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'MMO', 'Co-op', 'Downloadable Content']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Includes level editor']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Multi-player', 'Downloadable Content', 'Captions available', 'Partial Controller Support']
# ['Single-player', 'Downloadable Content']
# ['Single-player', 'Multi-player', 'Online Multi-Player', 'Shared/Split Screen', 'Downloadable Content', 'Steam Achievements', 'Full controller support', 'Steam Cloud']
# ['Single-player', 'Downloadable Content', 'Steam Achievements', 'Steam Trading Cards', 'Steam Cloud', 'Stats', 'Steam Leaderboards']
# ['Single-player', 'Downloadable Content', 'Steam Trading Cards']
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# 30       None
#          ...
# 12811    None
# 12812    None
# 12813    None
# 12814    None
# 12815    None
# 12816    None
# 12817    None
# 12818    None
# 12819    None
# 12820    None
# 12821    None
# 12822    None
# 12823    None
# 12824    None
# 12825    None
# 12826    None
# 12827    None
# 12828    None
# 12829    None
# 12830    None
# 12831    None
# 12832    None
# 12833    None
# 12834    None
# 12835    None
# 12836    None
# 12837    None
# 12838    None
# 12839    None
# 12840    None
# Length: 12572, dtype: object

# %%
# save dictionaries as csv
(pd.DataFrame.from_dict(data=dlc_specs_count, orient='index').
to_csv('dlc_specs_count.csv', header=True))

(pd.DataFrame.from_dict(data=dlc_specs, orient='index').
to_csv('dlc_specs.csv', header=True))

# %%
dlc_tags = {}
dlc_tags_count = {}
#unpack dlc tags and put it in dictionary
def unpack_tags(row):
    """This function unpacks the list of genres and stores it into a dictionary"""
    tags = row['tags']
    print(tags)
    try:
        for i in range(len(tags)):
            if tags[i] not in dlc_tags:
                dlc_tags[tags[i]] = 0
                dlc_tags_count[tags[i]] = 0
            else:
                dlc_tags_count[tags[i]] += 1
    except:
        pass

dlcs_raw.apply(unpack_tags, axis=1)
# Out:
# ['Action', 'Indie', 'Casual']
# ['Adventure', 'RPG', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'Indie', 'Casual']
# ['Indie', 'Casual']
# ['Indie', 'Casual']
# ['Indie']
# ['Simulation', 'Racing', 'Sports']
# ['Simulation', 'Racing', 'Sports']
# ['Simulation', 'Racing', 'Sports']
# ['Simulation', 'Racing', 'Sports']
# ['Simulation', 'Racing', 'Sports']
# ['Casual']
# ['Strategy', 'Free to Play', 'Indie', 'Casual', 'Simulation', 'Sports']
# ['Simulation']
# ['Action', 'Adventure', 'RPG', 'Indie']
# ['Simulation']
# ['Indie', 'Simulation']
# ['Indie', 'Simulation']
# ['Indie', 'Simulation']
# ['Indie', 'Simulation']
# ['Racing', 'Simulation']
# ['Racing', 'Simulation', 'Driving', 'Multiplayer', 'Singleplayer']
# ['Racing', 'Simulation']
# ['Simulation']
# ['Simulation']
# ['Strategy', 'Adventure', 'Indie']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Casual', 'Simulation']
# ['Design & Illustration', 'Web Publishing']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Historical']
# ['Strategy', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Strategy', 'Indie', 'Simulation']
# ['Action', 'FPS', 'Horror', 'Sci-fi', 'Dark', 'Atmospheric', 'Survival Horror', 'Shooter', 'Zombies', 'First-Person', 'Singleplayer']
# ['Action']
# ['Action', 'Open World']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Adventure']
# ['Simulation']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Simulation', 'Action', 'Strategy', 'FPS', 'Tactical', 'Realistic', 'Military', 'Sandbox']
# ['Adventure', 'RPG', 'Indie']
# ['Action', 'Adventure']
# ['Action']
# ['RPG', 'Action', 'FPS']
# ['Strategy']
# ['Strategy']
# ['RPG', 'Fantasy', 'Adventure']
# ['Action', 'Adventure']
# ['RPG', 'Action', 'Open World']
# ['Racing', 'Simulation']
# ['Adventure', 'Action']
# ['Simulation']
# ['Strategy', 'Action', 'Indie']
# ['Adventure', 'Action']
# ['Strategy']
# ['Action', 'Indie', 'Casual', 'Music']
# ['Strategy', 'Indie']
# ['Strategy']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Strategy', 'Adventure', 'RPG', 'Indie']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Indie', 'Casual', 'Puzzle']
# ['Action']
# ['Action', 'Zombies']
# ['Action', 'Fighting']
# ['Action']
# ['Indie', 'Soundtrack']
# ['Strategy', 'Action', 'Indie']
# ['Action', 'Zombies', 'FPS', 'Survival']
# ['Simulation', 'Trains', 'Atmospheric', 'Realistic', 'Singleplayer', 'Family Friendly', 'TrackIR', 'Casual', 'Level Editor', 'City Builder', 'Building', 'Driving', 'Moddable', 'Open World', 'Sandbox', 'Flight']
# ['Strategy', 'Historical', 'RTS']
# ['Action', 'RPG']
# ['RPG', 'Action']
# ['Simulation']
# ['Racing', 'Action']
# ['Strategy', 'Indie', 'Casual', 'Simulation']
# ['Strategy', 'Indie', 'Casual', 'Simulation']
# ['Strategy', 'Indie', 'Casual', 'Simulation']
# ['Action']
# ['Strategy']
# ['Indie', 'Casual', 'Adventure']
# ['Action', 'Indie']
# ['Strategy', 'Simulation']
# ['Action', 'RPG']
# ['Racing']
# ['Racing']
# ['RPG', 'Action']
# ['Strategy', 'Gore', 'Blood']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Action', 'Batman']
# ['Simulation', 'Trains', 'Realistic', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Family Friendly', 'TrackIR', 'Co-op']
# ['RPG', 'Indie', 'Casual', 'Rogue-like']
# ['Action']
# ['RPG', 'Action', 'Lovecraftian']
# ['Simulation', 'Casual']
# ['Action', 'Batman']
# ['Action', 'Indie']
# ['Strategy']
# ['Simulation', 'Casual', 'Trains', 'Building', 'Driving', 'Moddable', 'Open World', 'Sandbox', 'Atmospheric', 'Realistic', 'Singleplayer', 'City Builder', 'Family Friendly', 'TrackIR', 'Level Editor', 'Flight']
# ['Simulation']
# ['Action', 'Pinball']
# ['Action', 'Warhammer 40K']
# ['Simulation']
# ['Adventure', 'Strategy', 'Indie', 'Free to Play']
# ['Action']
# ['Action']
# ['Action', 'Adventure']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Simulation']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Action', 'Adventure']
# ['Simulation']
# ['RPG', 'Adventure', 'Action', 'Massively Multiplayer', 'Free to Play']
# ['Simulation']
# ['Action']
# ['Action', 'Adventure']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Strategy', 'RPG', 'Indie']
# ['Simulation', 'Strategy']
# ['Strategy', 'RPG', 'Indie']
# ['Simulation']
# ['Action']
# ['Simulation']
# ['Strategy', 'Action', 'Indie']
# ['Strategy', 'Action', 'Indie']
# ['Action']
# ['Strategy']
# ['Simulation']
# ['Strategy', 'Action', 'Indie']
# ['Simulation']
# ['Adventure', 'Casual', 'Indie', 'Point & Click', 'Atmospheric', 'Great Soundtrack', 'Exploration', '2D', 'Story Rich', 'Singleplayer', 'Episodic', 'Dark', 'Mature', 'Mystery', 'Drama', 'Interactive Fiction', 'Surreal', 'Psychological Horror', 'Horror', 'Third Person']
# ['Strategy']
# ['Racing']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Strategy', 'RPG', 'Simulation']
# ['Action', 'Indie']
# ['Simulation', 'Trains', 'Building', 'Driving', 'Casual', 'Moddable', 'Open World', 'Sandbox', 'Atmospheric', 'Realistic', 'Singleplayer', 'City Builder', 'Family Friendly', 'TrackIR', 'Level Editor', 'Flight']
# ['Simulation']
# ['Simulation']
# ['Strategy']
# ['RPG', 'Indie', 'Strategy']
# ['Action']
# ['Racing']
# ['Strategy', 'Indie', 'Casual']
# ['Strategy', 'Indie', 'Casual']
# ['Simulation']
# ['Strategy', 'Indie', 'Casual']
# ['Action', 'Soundtrack']
# ['RPG']
# ['Action', 'Soundtrack']
# ['Indie', 'Action', 'Adventure', 'Rogue-like', 'RPG', 'Difficult', 'Singleplayer', 'Procedural Generation', 'Great Soundtrack', 'Replay Value', '2D', 'Dungeon Crawler', 'Rogue-lite', 'Horror', 'Gore', 'Dark']
# ['Strategy', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Indie']
# ['Adventure', 'Action', 'Batman']
# ['Simulation']
# ['Strategy', 'Indie', 'Tower Defense']
# ['Strategy']
# ['Simulation']
# ['Action', 'RPG']
# ['Racing']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR', 'Co-op']
# ['Strategy', 'Action', 'Adventure', 'RPG', 'Indie']
# ['Action']
# ['Simulation', 'Strategy', 'RPG']
# ['Strategy', 'Simulation']
# ['Indie', 'Casual']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Turn-Based Strategy', 'Turn-Based', 'Multiplayer', '4X']
# ['Strategy', 'RPG']
# ['RPG', 'Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Open World']
# ['Action']
# ['Action', 'RPG']
# ['Action', 'RPG']
# ['Action', 'RPG']
# ['Action', 'RPG']
# ['Action']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation', 'Trains', 'Co-op', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Strategy', 'Action', 'Indie']
# ['Simulation']
# ['Strategy', 'Casual']
# ['Strategy', 'Action', 'Indie']
# ['Action', 'Indie', 'Soundtrack']
# ['Adventure']
# ['Strategy']
# ['Action']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Simulation', 'Trains', 'Singleplayer', 'Building', 'Driving', 'Moddable', 'Open World', 'Sandbox', 'Casual', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR', 'Level Editor', 'Flight', 'City Builder']
# ['Simulation']
# ['Strategy', 'Casual']
# ['Strategy', 'Adventure', 'Casual']
# ['Strategy', 'RPG', 'Indie']
# ['Indie', 'Soundtrack']
# ['Action', 'Strategy']
# ['Action']
# ['Adventure', 'Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy', 'Action', 'Indie']
# ['Indie', 'Music', 'Soundtrack']
# ['Strategy']
# ['Simulation', 'Action', 'Military', 'FPS']
# ['Soundtrack', 'Music', 'Great Soundtrack']
# ['Action', 'RPG', 'FPS', 'Multiplayer', 'Online Co-Op']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Strategy', 'Action', 'Indie']
# ['Strategy', 'Action', 'Indie']
# ['Strategy', 'Action', 'Indie']
# ['RPG', 'Indie', 'Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Strategy', 'Action']
# ['Action']
# ['Action', 'RPG', 'Indie', 'Casual', 'Adventure', 'Funny']
# ['Action', 'Zombies']
# ['Indie', 'Adventure', 'RPG', 'Casual', 'Action']
# ['RPG', 'Strategy', 'Turn-Based']
# ['Action', 'Indie']
# ['Strategy']
# ['Strategy', 'RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'RPG', 'Pirates', 'FPS']
# ['Racing', 'Action']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['RPG', 'Action']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action']
# ['Strategy', 'Action', 'Indie']
# ['Action', 'Adventure']
# ['Strategy', 'Action', 'Indie']
# ['Adventure', 'RPG', 'Indie']
# ['Simulation']
# ['Free to Play', 'Action', 'Massively Multiplayer']
# ['Strategy']
# ['Strategy']
# ['Action', 'Simulation']
# ['Action', 'Simulation']
# ['Action', 'Simulation']
# ['Racing']
# ['Racing']
# ['Strategy']
# ['Action']
# ['Racing']
# ['Action']
# ['Action']
# ['Strategy', 'Simulation']
# ['Action']
# ['Strategy', 'Grand Strategy']
# ['Simulation', 'Strategy', 'Action']
# ['Simulation']
# ['Racing']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action', 'Indie']
# ['Indie', 'Soundtrack']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'Turn-Based Strategy', 'Sci-fi']
# ['Action', 'Strategy', 'Indie', 'Level Editor', 'Sandbox', 'RTS']
# ['Strategy']
# ['Adventure', 'Indie']
# ['Action']
# ['Strategy', 'Casual']
# ['Strategy', 'Casual']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure']
# ['Simulation']
# ['Strategy', 'Action', 'Simulation']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Strategy']
# ['Strategy']
# ['Action', 'Adventure', 'Indie']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Action']
# ['Strategy']
# ['Simulation']
# ['Strategy']
# ['Strategy', 'Indie']
# ['Strategy', 'Indie', 'Simulation']
# ['Strategy', 'Indie']
# ['Action']
# ['Strategy', 'Medieval', 'Grand Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'RPG']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Fighting']
# ['Action', 'Adventure']
# ['Strategy', 'Action', 'Adventure']
# ['Massively Multiplayer', 'Free to Play', 'Action', 'Simulation']
# ['Simulation']
# ['Simulation', 'Action', 'Free to Play', 'Massively Multiplayer']
# ['Action', 'FPS', 'Multiplayer', 'Zombies']
# ['Strategy', 'Action', 'Indie']
# ['Simulation']
# ['Casual', 'Action', 'Indie', 'Platformer']
# ['Adventure']
# ['Action', 'FPS', 'Zombies', 'Multiplayer']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker', 'Fantasy', 'Game Development']
# ['RPG', 'Web Publishing', 'RPGMaker', 'Fantasy', 'Design & Illustration']
# ['Action']
# ['Casual', 'Simulation']
# ['Action', 'RPG', 'Massively Multiplayer', 'Free to Play']
# ['Simulation']
# ['Action']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Simulation']
# ['Strategy', 'Action', 'Indie', 'Casual']
# ['Action', 'Indie', 'Strategy', 'Dinosaurs']
# ['Action', 'Zombies', 'FPS', 'Co-op']
# ['Action', 'Adventure', 'Stealth', 'Steampunk', 'First-Person', 'Assassin']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'Grand Strategy']
# ['Strategy', 'Indie', 'RPG', 'Free to Play']
# ['Strategy', 'RPG', 'Indie', 'Free to Play']
# ['Strategy', 'RPG', 'Indie', 'Free to Play']
# ['RPG', 'Indie', 'Strategy', 'Free to Play']
# ['Simulation', 'Trains', 'Open World', 'Realistic', 'Atmospheric', 'Family Friendly', 'Sandbox', 'TrackIR', 'Singleplayer', 'Driving', 'Building', 'Casual', 'Co-op', 'Level Editor', 'Flight', 'City Builder', 'Physics', 'Moddable']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Action', 'Indie', 'Simulation']
# ['Action', 'Zombies', 'FPS', 'Multiplayer', 'Co-op']
# ['Action', 'Indie', 'Strategy', 'Dinosaurs']
# ['Simulation']
# ['Racing', 'Sports']
# ['Racing', 'Sports']
# ['Racing', 'Sports']
# ['Racing', 'Sports']
# ['Strategy']
# ['Strategy', 'Grand Strategy', 'Medieval']
# ['Strategy']
# ['Strategy']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker', 'Modern', 'Game Development', 'RPG']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'FPS']
# ['Action', 'RPG', 'Funny', 'FPS', 'Fantasy', 'Co-op']
# ['Action']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Action', 'Indie', 'Casual']
# ['Strategy']
# ['Strategy']
# ['Free to Play', 'RPG', 'Massively Multiplayer']
# ['Action']
# ['Action']
# ['Adventure', 'Zombies', 'Point & Click', 'Story Rich', 'Singleplayer', 'Horror', 'Post-apocalyptic', 'Choices Matter', 'Atmospheric', 'Survival']
# ['Strategy', 'Indie', 'Simulation', 'Sports']
# ['Strategy', 'Turn-Based', 'Turn-Based Strategy', '4X', 'Multiplayer', 'Singleplayer', 'Historical', 'Grand Strategy']
# ['Simulation', 'Building', 'Driving', 'Moddable', 'Open World', 'Sandbox', 'Atmospheric', 'Realistic', 'Singleplayer', 'City Builder', 'TrackIR', 'Level Editor', 'Casual', 'Flight']
# ['Simulation', 'Casual']
# ['Racing', 'Sports']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action']
# ['Strategy']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'Indie', 'Rogue-like']
# ['Action', 'Strategy', 'Indie', 'Tower Defense']
# ['Strategy', 'Simulation']
# ['Strategy', 'Simulation']
# ['Action', 'RPG', 'Great Soundtrack', 'Soundtrack', 'Music', 'Online Co-Op', 'FPS', 'Co-op']
# ['Strategy', 'Simulation']
# ['Strategy']
# ['Action', 'Adventure', 'Stealth', 'Steampunk']
# ['Strategy', 'RPG', 'Simulation']
# ['Strategy', 'RPG', 'Simulation']
# ['Free to Play', 'Simulation', 'Massively Multiplayer']
# ['Simulation']
# ['Action', 'RPG']
# ['Indie']
# ['Simulation', 'Flight']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Strategy', 'Action']
# ['Strategy', 'Action']
# ['Strategy', 'Action']
# ['Strategy', 'Action']
# ['Strategy', 'Action']
# ['Strategy', 'Action']
# ['Strategy', 'Action']
# ['Indie', 'Strategy', 'Action']
# ['RPG', 'Action', 'FPS', 'Co-op', 'Funny', 'Shooter', 'Loot']
# ['Strategy', 'RPG', 'Indie']
# ['Simulation', 'Racing', 'Sports']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Simulation']
# ['Strategy', 'Simulation']
# ['Action', 'Zombies', 'FPS', 'Multiplayer']
# ['Simulation']
# ['Action', 'Adventure', 'Stealth']
# ['Simulation']
# ['Action']
# ['Strategy']
# ['Action']
# ['Action']
# ['Strategy', 'Turn-Based Strategy']
# ['Action']
# ['Simulation']
# ['Action']
# ['Strategy', 'Simulation']
# ['Simulation']
# ['Simulation', 'Indie']
# ['Simulation']
# ['Strategy', 'Action', 'Indie']
# ['Indie']
# ['Action']
# ['Action', 'RPG', 'Indie']
# ['Indie', 'Casual']
# ['Indie', 'Casual']
# ['Indie', 'Action']
# ['Action', 'Indie']
# ['Simulation']
# ['Action', 'RPG']
# ['Strategy', 'Gore', 'Blood']
# ['Simulation']
# ['Strategy', 'RTS', 'Medieval', 'Multiplayer', 'Historical']
# ['Simulation']
# ['Strategy', 'Massively Multiplayer', 'Action', 'Free to Play', 'RPG', 'Simulation', 'RTS', 'War', 'Fast-Paced', 'PvP', 'Real Time Tactics', 'Multiplayer', 'Competitive', 'Atmospheric', 'Military', 'Realistic', 'Team-Based', 'Base Building', 'Historical']
# ['Action', 'Indie', 'Racing', 'Zombies']
# ['Indie', 'Simulation']
# ['Strategy', 'Turn-Based Strategy', 'Tactical', 'Sci-fi', 'Turn-Based', 'Aliens', 'Singleplayer', 'Base Building', 'Action', 'Difficult', 'RPG', 'Mechs', 'Multiplayer', 'Perma Death']
# ['Racing', 'Sports']
# ['Action', 'Adventure']
# ['Strategy', 'Adventure', 'RPG', 'Indie', 'Casual']
# ['Strategy', 'Adventure', 'RPG', 'Indie', 'Casual']
# ['Sports', 'Racing']
# ['Casual', 'Simulation']
# ['RPG', 'Indie', 'Adventure']
# ['Strategy', 'World War II']
# ['Strategy', 'Indie']
# ['Strategy']
# ['Strategy', 'RPG', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Strategy', 'RPG', 'Simulation', 'Grand Strategy', 'Medieval']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Action']
# ['Action']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker', 'Fantasy']
# ['Design & Illustration', 'Web Publishing', 'Music', 'RPGMaker']
# ['Audio Production']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker', 'Fantasy', 'Game Development']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker', 'Music']
# ['Simulation', 'Free to Play', 'Pinball']
# ['Simulation', 'Free to Play', 'Pinball']
# ['Action', 'RPG', 'Co-op', 'FPS', 'Heist', 'Online Co-Op', 'Gun Customization', 'Multiplayer', 'First-Person', 'Great Soundtrack', 'Shooter']
# ['Action', 'Adventure']
# ['Strategy', 'Historical', 'Rome', 'Turn-Based Strategy', 'Grand Strategy', 'RTS']
# ['Casual', 'Simulation']
# ['Action', 'RPG']
# ['Indie', 'Casual']
# ['Indie', 'Casual']
# ['Indie', 'Casual']
# ['Indie', 'Casual']
# ['Indie', 'Casual']
# ['Indie', 'Casual']
# ['Action', 'Adventure', 'Anime']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'Simulation']
# ['Indie', 'Casual']
# ['Casual', 'Simulation']
# ['Indie', 'Casual']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'RPG', 'FPS', 'Co-op', 'Multiplayer', 'Online Co-Op']
# ['Indie', 'Action']
# ['Indie']
# ['Simulation']
# ['Simulation', 'Flight', 'Military']
# ['Utilities', 'Animation & Modeling', 'Education', 'Web Publishing', 'Game Development']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Adventure', 'Indie', 'Casual']
# ['Simulation', 'Trains', 'Atmospheric', 'Realistic', 'Open World', 'Sandbox', 'Family Friendly', 'TrackIR', 'Physics']
# ['Simulation', 'Realistic', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Family Friendly', 'TrackIR']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker', 'Fantasy', 'RPG']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker', 'Music']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker', 'Music', 'Game Development']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'RPG', 'Indie', 'Casual', 'Soundtrack']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'RPG', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Action', 'Adventure']
# ['Action', 'Indie', 'Simulation']
# ['Simulation', 'Strategy', 'Indie', 'Politics']
# ['Action', 'Soundtrack']
# ['RPG', 'Adventure', 'Indie']
# ['Adventure', 'Action', 'LEGO']
# ['RPG', 'Indie']
# ['Indie']
# ['Racing', 'Sports', 'Simulation', 'Indie']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Adventure', 'Action', 'Open World', 'Third Person', 'Multiplayer', 'Pirates']
# ['Casual', 'Simulation']
# ['Action', 'RPG', 'FPS', 'Co-op', 'Shooter', 'Online Co-Op', 'Action RPG', 'Open World', 'Multiplayer', 'Post-apocalyptic', 'Comedy', 'Dark Humor', 'Loot', 'First-Person', 'Adventure', 'Funny']
# ['Action', 'Typing', 'Zombies', 'Comedy', 'Horror', 'FPS']
# ['Casual', 'Simulation']
# ['Simulation', 'Trains', 'Realistic', 'TrackIR', 'Family Friendly', 'Atmospheric', 'Physics', 'Open World', 'Sandbox']
# ['Strategy', 'RPG', 'Simulation', 'Grand Strategy']
# ['Strategy', 'RPG', 'Simulation', 'Grand Strategy']
# ['Strategy', 'Turn-Based Strategy', 'Rome', 'Historical']
# ['Casual', 'Simulation']
# ['Utilities', 'Animation & Modeling', 'Audio Production', 'Casual']
# ['RPG', 'Indie', 'Adventure']
# ['Action', 'Indie']
# ['Design & Illustration', 'Web Publishing', 'Music', 'RPGMaker']
# ['Design & Illustration', 'Web Publishing', 'RPGMaker', 'RPG']
# ['Web Publishing', 'Design & Illustration', 'Music', 'RPGMaker']
# ['Action', 'Adventure', 'RPG', 'Stealth']
# ['Action', 'Adventure', 'RPG', 'Stealth']
# ['Simulation', 'Zombies']
# ['Simulation', 'Strategy']
# ['Action', 'Adventure', 'RPG']
# ['Strategy', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'Indie', 'Simulation']
# ['Strategy', 'Indie', 'Simulation']
# ['Strategy', 'Indie', 'Simulation']
# ['Strategy', 'Indie', 'Simulation']
# ['Indie', 'Simulation', 'Strategy']
# ['Strategy', 'Indie', 'Simulation']
# ['Strategy', 'Indie', 'Simulation']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Simulation', 'Strategy']
# ['Action']
# ['Strategy', 'Indie', 'Casual']
# ['Action', 'RPG', 'FPS', 'Co-op', 'Free to Play', 'Multiplayer', 'Online Co-Op', 'Stealth']
# ['Strategy', 'RPG', 'Grand Strategy', 'Simulation', 'Historical', 'Medieval']
# ['Design & Illustration', 'Web Publishing']
# ['Audio Production']
# ['Simulation']
# ['Action', 'Adventure', 'RPG', 'Stealth']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['RPG', 'Strategy']
# ['Action']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['RPG', 'Action', 'Adventure', 'Comedy']
# ['Action', 'RPG', 'Indie']
# ['Adventure', 'RPG', 'Action', 'Comedy']
# ['Simulation', 'Casual']
# ['Casual', 'Simulation']
# ['Survival', 'Indie', 'Adventure', 'Crafting', 'Sandbox', 'Simulation', 'Singleplayer', 'Open World', 'Rogue-like', 'Difficult', 'Moddable', 'Multiplayer', 'Atmospheric', 'Horror', 'Perma Death', '2D']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Action', 'Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'RPG', 'FPS', 'Shooter', 'Co-op']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Adventure', 'Indie']
# ['Casual', 'Simulation']
# ['Adventure', 'Indie', 'Action']
# ['Casual', 'Simulation']
# ['Action', 'Adventure', 'Batman']
# ['Action', 'Adventure', 'Batman', 'Open World']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Simulation', 'Trains', 'Realistic', 'Atmospheric', 'Open World', 'Sandbox', 'Physics', 'Family Friendly', 'TrackIR']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Racing']
# ['Design & Illustration', 'Web Publishing']
# ['Casual', 'Simulation']
# ['Strategy', 'Action', 'Indie']
# ['Simulation']
# ['Strategy', 'Adventure', 'RPG']
# ['Action', 'Indie', 'Racing']
# ['Indie', 'Simulation', 'Strategy']
# ['Indie', 'Adventure']
# ['Strategy']
# ['RPG', 'Indie', 'Turn-Based', 'Strategy', 'Story Rich', 'Online Co-Op', 'Singleplayer', 'Adventure']
# ['RPG', 'Indie', 'Turn-Based', 'Story Rich', 'Online Co-Op', 'Lovecraftian', 'Party-Based RPG', 'Horror', 'Adventure', 'Investigation']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Story Rich', 'Online Co-Op']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Story Rich', 'Online Co-Op', 'Adventure', 'Party-Based RPG']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Story Rich', 'Sandbox', 'Online Co-Op', 'Strategy', 'Adventure', 'Party-Based RPG']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Story Rich', 'Online Co-Op']
# ['Strategy', 'Indie']
# ['Strategy', 'Action', 'Simulation']
# ['Indie', 'Simulation']
# ['Simulation', 'Indie']
# ['Strategy', 'Free to Play', 'Indie']
# ['Simulation', 'Indie']
# ['Action', 'RPG', 'Indie', 'Great Soundtrack', 'Soundtrack', 'Music', 'Female Protagonist']
# ['Strategy', 'Indie', 'Free to Play']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['RPG', 'Indie', 'Action']
# ['RPG', 'Indie']
# ['Indie', 'Strategy', 'Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action', 'Memes']
# ['Simulation']
# ['Indie', 'Strategy']
# ['RPG', 'Indie', 'Turn-Based', 'Strategy', 'Sandbox', 'Online Co-Op', 'Fantasy', 'Story Rich', 'Adventure', 'Party-Based RPG']
# ['Indie']
# ['RPG', 'Indie', 'Turn-Based', 'Story Rich', 'Sandbox', 'Online Co-Op', 'Fantasy', 'Adventure', 'Party-Based RPG']
# ['Action', 'Indie']
# ['Action', 'Indie', 'Casual']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation', 'Free to Play']
# ['Casual', 'Simulation']
# ['Simulation']
# ['RPG', 'Indie']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Story Rich', 'Strategy', 'Singleplayer', 'Adventure']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Massively Multiplayer', 'Indie', 'Action', 'RPG', 'Free to Play']
# ['RPG', 'Massively Multiplayer', 'Action', 'Free to Play', 'Indie']
# ['Action', 'Free to Play', 'RPG', 'Massively Multiplayer', 'Indie']
# ['RPG', 'Indie']
# ['Action']
# ['Action', 'Free to Play', 'RPG', 'Massively Multiplayer', 'Indie']
# ['Action']
# ['Simulation']
# ['Simulation']
# ['Action', 'FPS', 'Multiplayer', 'Singleplayer', 'First-Person', 'Adventure', 'RPG']
# ['Action']
# ['Action']
# ['Indie', 'Casual', 'Action', 'Sexual Content', 'Dark', 'Anime', 'Fighting']
# ['Action', 'RPG', 'FPS', 'Co-op', 'Shooter', 'Multiplayer', 'Adventure']
# ['Simulation', 'Indie']
# ['Action', 'Adventure', 'Hacking']
# ['Strategy', 'Casual']
# ['Strategy', 'Simulation']
# ['Free to Play', 'Survival', 'Zombies', 'Multiplayer', 'Open World', 'Adventure', 'Action', 'Crafting', 'Sandbox', 'Shooter', 'Co-op', 'FPS', 'Singleplayer', 'Post-apocalyptic', 'Indie', 'Casual', 'Funny', 'Massively Multiplayer', 'RPG', 'Horror']
# ['RPG', 'Indie', 'Adventure', 'Visual Novel']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Strategy']
# ['Indie', 'Simulation']
# ['Adventure', 'Indie', 'RPG']
# ['Strategy', 'Adventure', 'RPG']
# ['Action', 'Indie']
# ['RPG', 'Indie']
# ['RPG', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'RPG', 'Indie']
# ['RPG', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Simulation', 'RPG', 'Adventure']
# ['Simulation']
# ['Strategy', 'Adventure', 'RPG']
# ['Strategy', 'RPG', 'Indie']
# ['Strategy']
# ['Massively Multiplayer', 'Action', 'RPG']
# ['Action', 'RPG', 'Massively Multiplayer']
# ['Adventure', 'Casual', 'Simulation']
# ['Action', 'RPG', 'Massively Multiplayer']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Story Rich', 'Online Co-Op', 'Party-Based RPG']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Story Rich', 'Online Co-Op', 'Party-Based RPG']
# ['Action', 'Adventure']
# ['Action', 'Free to Play', 'Indie', 'RPG', 'Massively Multiplayer', 'Shooter']
# ['Action']
# ['Adventure', 'Casual']
# ['Utilities', 'Animation & Modeling', 'Education', 'Web Publishing']
# ['Action', 'RPG', 'Indie', 'Great Soundtrack']
# ['Design & Illustration', 'Utilities', 'Animation & Modeling', 'Education', 'Software Training', 'Game Development']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Sandbox', 'Online Co-Op']
# ['Casual', 'Simulation', 'Sports']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Fighting', 'Action', 'Arcade', '2D Fighter', 'Multiplayer', 'Adventure', "Beat 'em up"]
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Strategy']
# ['Simulation', 'Free to Play', 'World War II']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Indie', 'Great Soundtrack']
# ['Action', 'Adventure']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Story Rich', 'Online Co-Op', 'Strategy', 'Adventure', 'Party-Based RPG']
# ['Action']
# ['Indie', 'Casual', 'Free to Play']
# ['Indie', 'Casual', 'Free to Play']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Action', 'Indie']
# ['Adventure', 'Indie']
# ['RPG', 'Action', 'Adventure', 'Difficult', 'Dark Fantasy', 'Action RPG', 'Multiplayer', 'Third Person']
# ['Indie', 'Adventure']
# ['Casual', 'Simulation']
# ['Racing', 'Sports']
# ['RPG', 'Indie']
# ['Racing', 'Action', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'RPG', 'FPS', 'Online Co-Op', 'Co-op', 'Multiplayer', 'Shooter', 'Heist']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['RPG', 'Indie', 'Western', 'Turn-Based', 'Story Rich', 'Online Co-Op', 'Party-Based RPG']
# ['Strategy']
# ['Strategy', 'Action', 'Indie']
# ['Strategy', 'Action', 'Indie']
# ['Strategy', 'Action', 'Indie']
# ['Indie']
# ['RPG']
# ['Casual', 'Simulation']
# ['Racing', 'Sports']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Music', 'Soundtrack']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Animation & Modeling', 'Web Publishing']
# ['Design & Illustration', 'Animation & Modeling', 'Web Publishing']
# ['Design & Illustration', 'Animation & Modeling', 'Web Publishing']
# ['Action', 'Adventure', 'LEGO']
# ['Action', 'Adventure', 'LEGO']
# ['Action', 'Adventure', 'LEGO']
# ['Action', 'Adventure']
# ['RPG', 'Massively Multiplayer', 'Free to Play']
# ['Action', 'Soundtrack']
# ['Action', 'Soundtrack']
# ['Free to Play', 'Soundtrack']
# ['Action', 'Music', 'Soundtrack']
# ['Simulation', 'Strategy', 'RPG']
# ['Strategy', 'Indie', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Adventure', 'Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['RPG', 'Indie', 'Western', 'Turn-Based', 'Story Rich', 'Online Co-Op', 'Party-Based RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Story Rich', 'Online Co-Op', 'Party-Based RPG', 'Strategy', 'Adventure']
# ['Action', 'Indie']
# ['Free to Play', 'Massively Multiplayer', 'Strategy', 'Action', 'RPG', 'MOBA', 'PvP', 'Real Time Tactics', 'Multiplayer', 'Historical', 'Military', 'Realistic', 'Team-Based', 'Base Building', 'War', 'Atmospheric', 'Competitive', 'Fast-Paced', 'Simulation', 'RTS']
# ['Simulation', 'Trains', 'Driving', 'Singleplayer', 'City Builder', 'TrackIR', 'Level Editor', 'Family Friendly', 'Adventure', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic']
# ['Sports', 'Simulation', 'Action', 'Indie']
# ['Strategy', 'RPG', 'Indie', 'Simulation']
# ['RPG', 'Indie', 'Turn-Based', 'Story Rich', 'Sandbox', 'Online Co-Op', 'Party-Based RPG', 'Adventure', 'Horror', 'Kickstarter', 'Software']
# ['Adventure', 'Indie']
# ['Simulation', 'Flight']
# ['Music']
# ['Indie', 'Massively Multiplayer', 'Casual', 'Strategy', 'Free to Play']
# ['Massively Multiplayer', 'Indie', 'Casual', 'Strategy', 'Free to Play', 'MMORPG', 'Multiplayer']
# ['Indie', 'Action']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Action']
# ['Action', 'Horror']
# ['Racing']
# ['Action', 'Adventure', 'Anime']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'Indie']
# ['Simulation', 'Trains', 'Driving', 'Open World', 'Sandbox', 'Level Editor', 'Realistic', 'Singleplayer', 'Building', 'Casual', 'Relaxing', 'Moddable', 'City Builder', 'Family Friendly', 'TrackIR', 'Atmospheric', 'Sports']
# ['Indie', 'Action']
# ['Simulation', 'Trains', 'Driving', 'Open World', 'Sandbox', 'Realistic', 'Singleplayer', 'Casual', 'Level Editor', 'TrackIR', 'Family Friendly', 'Atmospheric', 'Relaxing', 'Moddable', 'Building', 'Sports', 'City Builder']
# ['Indie', 'Adventure']
# ['Casual', 'Strategy']
# ['Simulation']
# ['Simulation', 'Indie']
# ['RPG', 'Indie']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Sandbox', 'Online Co-Op', 'Party-Based RPG', 'Strategy']
# ['RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Sandbox', 'Online Co-Op', 'Strategy', 'Party-Based RPG']
# ['Simulation', 'Free to Play', 'Pinball']
# ['Simulation', 'Free to Play']
# ['Horror']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Indie', 'Strategy']
# ['Action', 'Adventure', 'Indie', 'Horror']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Simulation']
# ['Strategy', 'Indie', 'Anime', 'Board Game']
# ['Strategy', 'RPG', 'Simulation']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Adventure']
# ['RPG']
# ['Casual', 'Indie', 'Family Friendly', 'Horses', 'Horror']
# ['Utilities', 'Audio Production']
# ['Strategy']
# ['Simulation', 'Trains', 'Open World', 'Realistic', 'Sandbox', 'Physics', 'Atmospheric', 'Family Friendly', 'TrackIR', 'Co-op']
# ['Action', 'Zombies']
# ['Action']
# ['Sports', 'Action', 'Indie', 'Casual', 'Racing']
# ['Casual', 'Racing', 'Sports', 'Indie', 'Action']
# ['Action', 'Adventure']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'Adventure', 'Open World']
# ['Action', 'Adventure']
# ['Simulation', 'Casual']
# ['Casual', 'Simulation']
# ['Simulation', 'Casual']
# ['Simulation', 'Casual']
# ['Simulation', 'Casual']
# ['Strategy', 'Indie']
# ['Strategy']
# ['Video Production', 'Animation & Modeling']
# ['Simulation', 'Adventure', 'Action', 'Sports', 'Free to Play', 'Hunting']
# ['Indie']
# ['Simulation', 'Action', 'Adventure', 'Free to Play', 'Sports']
# ['Strategy', 'Indie', 'Simulation', 'Soundtrack', 'Retro', 'Singleplayer', 'Survival', 'Rogue-like', 'Great Soundtrack', 'Pixel Graphics']
# ['Strategy', 'Indie', 'Simulation']
# ['Action', 'Adventure', 'Simulation', 'Sports', 'Free to Play', 'Hunting']
# ['RPG', 'Indie', 'Adventure', 'Rogue-like', 'Turn-Based', 'Fantasy']
# ['Strategy', 'Adventure', 'RPG', 'Indie']
# ['Simulation', 'Indie']
# ['Action', 'Adventure']
# ['Action', 'Horror', 'Survival Horror']
# ['Action', 'RPG']
# ['Casual', 'Simulation']
# ['Action', 'RPG']
# ['Massively Multiplayer', 'Indie', 'Casual', 'RPG', 'Free to Play']
# ['Simulation']
# ['RPG', 'Indie']
# ['Action', 'Racing', 'Sports']
# ['Simulation', 'Trains', 'Realistic', 'Singleplayer', 'Driving', 'Building', 'Open World', 'Sandbox', 'Casual', 'Family Friendly', 'Level Editor', 'TrackIR', 'City Builder', 'Atmospheric', 'Relaxing', 'Moddable', 'Sports']
# ['Adventure', 'Indie', 'Action', 'Horror', 'Atmospheric', 'Singleplayer']
# ['Strategy', 'RPG', 'Indie', 'Anime']
# ['Racing', 'Sports', 'Free to Play']
# ['Action', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG', 'Shooter']
# ['Adventure', 'RPG', 'Indie']
# ['Strategy', 'Simulation', 'RPG']
# ['Adventure', 'Indie']
# ['Strategy', 'Indie', 'Casual']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Design & Illustration', 'Web Publishing']
# ['Utilities', 'Animation & Modeling', 'Education', 'Software Training', 'Design & Illustration', 'Game Development']
# ['Strategy']
# ['Adventure', 'Indie']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Action', 'Adventure', 'Indie']
# ['Local Co-Op', 'Local Multiplayer', 'Adventure', 'Action']
# ['Action', 'Adventure']
# ['RPG', 'Massively Multiplayer', 'Adventure', 'Indie', 'Action']
# ['Action', 'RPG', 'FPS', 'Co-op', 'Stealth']
# ['Strategy', 'RPG', 'Indie']
# ['Action', 'Adventure', 'Indie']
# ['Strategy']
# ['RPG', 'Indie']
# ['RPG', 'Indie', 'Adventure']
# ['Adventure', 'Indie', 'Casual', 'Atmospheric', 'Singleplayer', 'Great Soundtrack', 'Exploration', '2D', 'Story Rich', 'Interactive Fiction', 'Episodic', 'Dark', 'Mature', 'Mystery', 'Drama', 'Third Person', 'Surreal', 'Psychological Horror', 'Horror', 'Point & Click']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Strategy', 'RPG', 'Indie']
# ['Design & Illustration', 'Web Publishing']
# ['Strategy', 'World War II']
# ['Strategy', 'RPG', 'Indie']
# ['Adventure', 'Action', 'Open World', 'FPS', 'First-Person', 'Shooter']
# ['Simulation']
# ['Strategy', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Racing', 'Sports', 'Simulation', 'Free to Play']
# ['Simulation', 'Open World', 'Trains', 'Sandbox', 'Building', 'Driving', 'Realistic', 'Singleplayer', 'Casual', 'Level Editor', 'City Builder', 'Family Friendly', 'TrackIR', 'Relaxing', 'Moddable', 'Atmospheric', 'Sports']
# ['Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'Action', 'Indie']
# ['Action', 'Adventure']
# ['Animation & Modeling', 'Video Production', 'Female Protagonist', 'Memes', 'Illuminati']
# ['Action', 'Indie']
# ['Racing', 'Action', 'Massively Multiplayer', 'Open World']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Action']
# ['Action']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation', 'Singleplayer']
# ['Casual', 'Simulation']
# ['Strategy', 'RPG', 'Indie']
# ['Indie']
# ['Simulation', 'Multiplayer']
# ['Action', 'Indie']
# ['RPG', 'Massively Multiplayer', 'Indie', 'Casual', 'Free to Play']
# ['Action', 'Indie', 'Great Soundtrack', "Shoot 'Em Up"]
# ['Action', 'Indie', 'Great Soundtrack', "Shoot 'Em Up"]
# ['Action', 'Adventure', 'Indie', 'Puzzle', 'Sci-fi']
# ['Action', 'Adventure', 'Indie', 'Movie', 'Documentary']
# ['Action', 'Adventure', 'Indie', 'Soundtrack', 'Great Soundtrack']
# ['Simulation', 'Action', 'Space']
# ['RPG', 'Strategy', 'Action', 'Historical', 'Simulation', 'Naval', 'Sandbox', 'Open World', 'Medieval', 'Story Rich', 'Singleplayer', 'Adventure', 'Multiplayer', 'Indie', 'Third Person', 'First-Person', 'Action RPG', 'Moddable', 'War', 'Great Soundtrack']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Realistic', 'Co-op', 'Family Friendly', 'TrackIR', 'Physics', 'Atmospheric']
# ['Action']
# ['Simulation']
# ['Action']
# ['Strategy', 'Indie', 'Simulation']
# ['Simulation', 'Casual']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['RPG', 'Massively Multiplayer', 'Free to Play']
# ['Casual', 'Simulation']
# ['Adventure', 'Indie', 'Casual']
# ['Casual', 'Simulation']
# ['Strategy', 'Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Strategy']
# ['Strategy', 'Action', 'Adventure']
# ['Strategy', 'RPG']
# ['Strategy', 'Simulation', 'RPG']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['RPG', 'Strategy', 'Indie', 'Party-Based RPG', 'Sandbox', 'Fantasy', 'Turn-Based']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Simulation', 'Trains', 'Realistic', 'Family Friendly', 'TrackIR', 'Sandbox', 'Atmospheric', 'Open World', 'Physics', 'Co-op']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Indie', 'Casual']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Realistic', 'Family Friendly', 'TrackIR', 'Co-op', 'Physics', 'Atmospheric']
# ['Indie', 'Puzzle', 'Visual Novel', 'Anime', 'Puzzle-Platformer']
# ['Action']
# ['Action', 'Free to Play']
# ['Utilities', 'Design & Illustration', 'Education', 'Software Training', 'Animation & Modeling']
# ['Action', 'Adventure', 'Indie', 'Music', 'Soundtrack']
# ['Strategy', 'Action', 'Adventure', 'Indie', 'Simulation']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'Action', 'LEGO', 'Batman', 'Free to Play']
# ['Strategy', 'Indie', 'Action']
# ['Strategy', 'RPG']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Simulation']
# ['Action', 'RPG', 'FPS']
# ['Action', 'RPG']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Realistic', 'Co-op', 'Family Friendly', 'TrackIR', 'Physics', 'Atmospheric']
# ['Action', 'Casual', 'Free to Play']
# ['Indie', 'Visual Novel', 'Anime', 'Story Rich']
# ['Action', 'Indie']
# ['Strategy']
# ['Adventure', 'RPG', 'Indie', 'Casual', 'Music', 'Soundtrack']
# ['Adventure', 'Indie', 'Casual', 'Simulation']
# ['Strategy', 'RPG', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Adventure']
# ['Strategy', 'Action']
# ['Indie', 'Adventure', 'RPG']
# ['RPG', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Realistic', 'Family Friendly', 'TrackIR', 'Physics', 'Atmospheric']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Strategy', 'Indie']
# ['Design & Illustration', 'Web Publishing']
# ['Strategy', 'Indie']
# ['Design & Illustration', 'Web Publishing']
# ['Design & Illustration', 'Web Publishing']
# ['Strategy', 'Adventure', 'RPG', 'Indie']
# ['Simulation']
# ['Racing', 'Sports', 'Simulation']
# ['Strategy', 'Action', 'Adventure', 'Indie', 'Simulation']
# ['Adventure', 'Indie']
# ['Adventure', 'Indie']
# ['Racing', 'Action', 'Zombies', 'Sports', 'Shooter', 'Arena Shooter']
# ['Strategy', 'Historical', 'Rome', 'Turn-Based Strategy']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'Action']
# ['Adventure']
# ['Strategy']
# ['Action', 'Multiplayer']
# ['Adventure', 'Free to Play', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Adventure', 'Indie']
# ['Indie', 'Simulation', 'Strategy']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Strategy', 'RPG', 'Warhammer 40K']
# ['Simulation']
# ['Strategy', 'Simulation']
# ['Strategy', 'Simulation', 'Grand Strategy']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'RPG', 'FPS']
# ['Strategy', 'Adventure', 'RPG']
# ['Adventure', 'Free to Play']
# ['Action']
# ['Action', 'RPG', 'Indie']
# ['Action', 'RPG', 'Indie']
# ['Adventure', 'Casual', 'Simulation']
# ['RPG', 'Action']
# ['Indie', 'Strategy', 'Action', 'Soundtrack', 'Space']
# ['Simulation']
# ['Action']
# ['Action', 'Adventure']
# ['Strategy', 'Simulation']
# ['Strategy', 'Historical']
# ['Strategy', 'Adventure', 'RPG']
# ['Strategy', 'Simulation']
# ['Action', 'Adventure']
# ['Action', 'Horror', 'Survival Horror', 'Stealth', 'Female Protagonist', 'Gore', 'Atmospheric']
# ['Simulation']
# ['Indie', 'Action', 'Great Soundtrack']
# ['Racing', 'Sports', 'Simulation', 'Free to Play']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ['Action', 'RPG', 'Zombies', 'Parkour']
# ['Action', 'Adventure']
# ['Simulation']
# ['Simulation', 'Racing', 'Sports', 'Indie']
# ['Action', 'Adventure', 'Indie']
# ['Strategy', 'Simulation']
# ['Adventure', 'Indie']
# ['Adventure', 'RPG', 'Indie']
# ['Strategy', 'Action', 'RPG', 'Casual', 'Simulation', 'Free to Play']
# ['Simulation', 'Indie']
# ['Free to Play', 'Adventure', 'RPG', 'Massively Multiplayer', 'Casual', 'Action']
# ['Animation & Modeling', 'Education', 'Software Training', 'Design & Illustration', 'Utilities']
# ['Action', 'Adventure']
# ['Action', 'Adventure']
# ['Casual', 'Simulation']
# ['Action', 'Adventure', 'RPG', 'Indie']
# ['RPG']
# ['RPG']
# ['Indie', 'Casual']
# ['Strategy', 'RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Story Rich', 'Online Co-Op', 'Software', 'Party-Based RPG', 'Utilities']
# ['Simulation']
# ['Free to Play', 'Indie', 'Action', 'Adventure']
# ['Racing']
# ['Action', 'Adventure', 'Indie']
# ['Action', 'Adventure', 'LEGO', 'Batman']
# ['Indie', 'Casual', 'Simulation']
# ['Strategy', 'Indie']
# ['Strategy', 'Action', 'RPG', 'Casual', 'Simulation', 'Free to Play']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Realistic', 'Family Friendly', 'TrackIR', 'Physics', 'Atmospheric']
# ['Strategy']
# ['Simulation', 'Action', 'Adventure', 'Indie', 'Strategy']
# ['Strategy', 'Indie', 'RPG', 'Party-Based RPG', 'Software', 'Utilities', 'Story Rich', 'Fantasy', 'Turn-Based']
# ['Adventure', 'Indie']
# ['Action']
# ['Action']
# ['RPG', 'Indie']
# ['Action', 'Strategy', 'Free to Play']
# ['Strategy', 'RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Software', 'Party-Based RPG', 'Utilities']
# ['RPG', 'Indie', 'Strategy', 'Utilities', 'Software', 'Party-Based RPG', 'Turn-Based', 'Fantasy']
# ['Strategy', 'Indie', 'RPG', 'Utilities', 'Party-Based RPG', 'Software', 'Fantasy', 'Turn-Based']
# ['Strategy', 'Indie', 'RPG', 'Software', 'Fantasy', 'Turn-Based', 'Utilities']
# ['Strategy', 'RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Software', 'Party-Based RPG', 'Utilities']
# ['Strategy', 'RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Software', 'Party-Based RPG', 'Utilities']
# ['Strategy', 'Indie', 'RPG', 'Party-Based RPG', 'Software', 'Turn-Based', 'Utilities']
# ['Casual', 'Simulation']
# ['Strategy', 'Action', 'Free to Play']
# ['RPG', 'Indie', 'Strategy', 'Utilities', 'Turn-Based', 'Fantasy', 'Software', 'Party-Based RPG']
# ['Action']
# ['Strategy', 'RPG', 'Indie', 'Simulation']
# ['Adventure', 'Indie']
# ['Strategy', 'Simulation']
# ['Adventure', 'Indie']
# ['Strategy', 'Simulation', 'RPG']
# ['RPG', 'Strategy', 'Adventure', 'Indie']
# ['Action', 'Indie', 'Casual', 'Sports']
# ['Action', 'Indie', 'Racing']
# ['Indie', 'Casual']
# ['Action', 'Adventure', 'Free to Play', 'Indie']
# ['Action', 'RPG', 'Indie']
# ['Simulation']
# ['Action', 'Casual']
# ['Action', 'Casual']
# ['Action']
# ['Strategy', 'Action', 'RPG', 'Casual', 'Simulation', 'Free to Play']
# ['Action']
# ['Action', 'RPG', 'Indie']
# ['Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Strategy', 'RPG', 'Massively Multiplayer', 'Indie']
# ['Strategy', 'RPG', 'Indie']
# ['Adventure', 'Indie', 'Action', 'Great Soundtrack']
# ['Action', 'Free to Play']
# ['Action', 'Free to Play']
# ['Action', 'Free to Play']
# ['Action', 'RPG', 'Adventure', 'Indie', 'Massively Multiplayer']
# ['Design & Illustration', 'Utilities', 'Animation & Modeling', 'Web Publishing']
# ['Strategy', 'RPG', 'Indie']
# ['Indie', 'Simulation', 'Action', 'Adventure']
# ['Indie', 'Sports', 'Action']
# ['Action', 'Indie']
# ['Design & Illustration', 'Web Publishing']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Massively Multiplayer', 'Adventure', 'Free to Play', 'RPG', 'Action']
# ['Action', 'RPG', 'Music', 'Great Soundtrack']
# ['Adventure', 'RPG', 'Indie', 'Casual']
# ['Action', 'Indie', 'Casual', 'Free to Play']
# ['Strategy', 'Action', 'RPG', 'Free to Play']
# ['Indie', 'Casual']
# ['Adventure', 'RPG', 'Indie', 'Casual']
# ['Indie', 'Action', '4 Player Local', 'Local Co-Op', 'Multiplayer', 'Local Multiplayer', 'Platformer', 'Co-op', 'Adventure', 'Controller', '2D', '2D Fighter', 'Fighting']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Action', 'Indie']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Simulation']
# ...
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Action']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Racing']
# ['Strategy', 'Casual']
# ['Action']
# ['RPG', 'Massively Multiplayer']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Grand Strategy']
# ['Action']
# ['Strategy']
# ['Action']
# ['Action']
# ['RPG', 'Indie']
# ['Action', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'FPS', 'Cyberpunk']
# ['Strategy']
# ['Strategy', 'RPG']
# ['Adventure', 'Massively Multiplayer', 'Free to Play', 'RPG', 'Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'RPG', 'Indie']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Indie']
# ['Indie', 'Adventure', 'RPG', 'Free to Play', 'Casual', 'Rogue-like']
# ['Action', 'Sniper']
# ['Simulation', 'Trains', 'Sandbox', 'Realistic', 'Open World', 'Family Friendly', 'TrackIR', 'Physics', 'Atmospheric']
# ['Simulation']
# ['Strategy', 'RPG', 'Indie']
# ['Strategy']
# ['RPG', 'Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action', 'Historical', 'Multiplayer', 'RPG', 'First-Person', 'Third Person', 'War', 'Strategy', 'Tactical', 'Simulation', 'Singleplayer', 'Horses', 'Shooter', 'Great Soundtrack']
# ['Strategy', 'Simulation']
# ['Action', 'Indie']
# ['Action', 'Adventure']
# ['Strategy', 'Indie', 'Soundtrack']
# ['Strategy', 'Indie', 'Soundtrack']
# ['Strategy', 'Action', 'RPG', 'Indie']
# ['Strategy']
# ['Adventure', 'Action']
# ['Strategy']
# ['Action', 'Indie', 'Casual', 'Strategy']
# ['Strategy', 'RPG', 'Indie']
# ['Simulation']
# ['Action', 'RPG', 'Indie']
# ['RPG', 'Action']
# ['Action']
# ['Strategy', 'RPG', 'Indie']
# ['Action']
# ['Simulation', 'Flight']
# ['Strategy', 'Casual']
# ['Strategy', 'Casual']
# ['Strategy', 'RPG', 'Indie']
# ['Strategy', 'Simulation']
# ['Action', 'Indie']
# ['Strategy', 'RPG', 'Simulation']
# ['Action']
# ['Strategy', 'RPG', 'Simulation']
# ['Strategy', 'RPG', 'Simulation']
# ['Simulation']
# ['RPG', 'Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action', 'RPG', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie', 'Zombies']
# ['Action', 'Indie']
# ['Strategy']
# ['Strategy']
# ['Action', 'Indie']
# ['Action', 'RPG']
# ['Action']
# ['Action', 'RPG', 'Indie']
# ['Action', 'RPG', 'Indie']
# ['Strategy', 'RPG']
# ['Strategy', 'Grand Strategy']
# ['Indie', 'Casual']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Space', 'Simulation', 'Sandbox', 'Action', 'Sci-fi', 'Trading', 'Singleplayer', 'Moddable', 'Economy', 'Space Sim', 'Open World', 'Capitalism', 'Real-Time', 'Great Soundtrack', 'Strategy', 'Adventure', 'TrackIR']
# ['Indie', 'Strategy', 'Action', 'Casual']
# ['Action']
# ['Action', 'RPG', 'Indie']
# ['Action', 'Indie']
# ['Action']
# ['Action']
# ['Strategy', 'Casual']
# ['Indie', 'Action', 'RPG']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy', 'Indie', 'Tower Defense']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Simulation']
# ['Action']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action', 'RPG', 'Indie']
# ['Strategy']
# ['Adventure', 'Strategy', 'Detective', 'Open World', 'Noir', 'Singleplayer']
# ['Indie', 'Strategy', 'Action']
# ['Strategy', 'Simulation']
# ['Strategy']
# ['Action', 'Indie', 'Soundtrack']
# ['Action', 'Indie']
# ['Action']
# ['Strategy', 'RPG', 'Indie']
# ['Action', 'Indie']
# ['Strategy']
# ['Action']
# ['Indie']
# ['Action']
# ['Adventure', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Simulation']
# ['Action', 'RPG', 'Indie']
# ['Action', 'RPG', 'Indie']
# ['Action', 'Adventure', 'RPG']
# ['Action', 'FPS']
# ['Indie', 'Simulation', 'Strategy']
# ['Simulation', 'Horses', 'Cute', 'Funny']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['RPG', 'Action']
# ['Action']
# ['Action']
# ['Action']
# ['Action', 'Indie', 'Soundtrack', 'Music', 'Great Soundtrack']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Action']
# ['Strategy', 'Action', 'Indie', 'Casual']
# ['Indie']
# ['Strategy']
# ['Simulation']
# ['Action', 'RPG']
# ['Strategy']
# ['Action', 'RPG', 'Post-apocalyptic']
# ['Strategy', 'Action', 'Indie', 'Casual']
# ['RPG', 'Open World', 'Pirates']
# ['RPG']
# ['Action', 'Fighting']
# ['Action']
# ['Strategy']
# ['Action']
# ['Action']
# ['Action']
# ['Simulation']
# ['Action', 'Destruction']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['RPG', 'Action']
# ['Action', 'RPG']
# ['RPG', 'Action']
# ['Strategy']
# ['Racing', 'Simulation']
# ['Action', 'RPG']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'RPG']
# ['Action']
# ['Action']
# ['Action', 'RPG', 'Post-apocalyptic', 'Sci-fi', 'Comedy']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Strategy']
# ['Action']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Adventure', 'RPG', 'Indie']
# ['Simulation']
# ['Simulation']
# ['Action', 'RPG']
# ['Action', 'Zombies']
# ['Simulation']
# ['Strategy']
# ['Simulation']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'Simulation']
# ['Strategy', 'Simulation']
# ['Strategy', 'Casual']
# ['RPG', 'Action']
# ['Adventure', 'RPG', 'Indie']
# ['Strategy']
# ['Action', 'Zombies']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Strategy']
# ['Racing', 'Simulation']
# ['Strategy', 'Trading', 'Simulation', 'Economy']
# ['Strategy', 'RPG']
# ['Action', 'RPG', 'Magic']
# ['Racing', 'Simulation']
# ['Action', 'RPG']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Simulation']
# ['Simulation', 'Adventure']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Action', 'Adventure']
# ['Simulation']
# ['Strategy', 'Indie', 'Simulation']
# ['Strategy', 'Indie']
# ['Strategy']
# ['Strategy']
# ['RPG', 'Action', 'Horror', 'Survival Horror']
# ['Strategy']
# ['RPG']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Action']
# ['Action']
# ['Strategy', 'Indie', 'Simulation']
# ['Action']
# ['Adventure', 'RPG', 'Indie']
# ['Strategy']
# ['Action', 'Open World', 'Adventure', 'Third-Person Shooter']
# ['Action']
# ['Action']
# ['Strategy']
# ['Simulation', 'Action', 'Strategy', 'Military', 'Realistic', 'Tactical', 'FPS', 'Open World']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Simulation']
# ['Action', 'FPS']
# ['Strategy']
# ['Action', 'Open World']
# ['Strategy']
# ['Strategy']
# ['Strategy', 'RTS', 'Multiplayer', 'Singleplayer']
# ['Action']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR', 'Co-op']
# ['Action']
# ['Action']
# ['Strategy']
# ['Action']
# ['RPG', 'Action', 'FPS']
# ['Simulation', 'Trains', 'Co-op', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Action']
# ['Strategy']
# ['Strategy', 'Indie']
# ['Strategy', 'Simulation', 'World War II']
# ['Strategy']
# ['Strategy', 'Indie', 'Tower Defense']
# ['Simulation', 'Trains', 'Co-op', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Action', 'FPS', 'Multiplayer']
# ['Action']
# ['Strategy', 'RPG']
# ['Strategy', 'Simulation']
# ['RPG', 'Post-apocalyptic']
# ['RPG', 'Post-apocalyptic']
# ['RPG', 'Post-apocalyptic']
# ['RPG', 'Post-apocalyptic', 'Adventure']
# ['RPG', 'Post-apocalyptic']
# ['Strategy']
# ['Strategy']
# ['Simulation', 'Trains', 'Co-op', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Indie']
# ['Indie']
# ['Indie']
# ['Indie']
# ['Action', 'Multiplayer', 'FPS', 'Free to Play']
# ['Indie']
# ['Indie', 'Strategy', 'Simulation']
# ['Strategy']
# ['Simulation', 'Strategy', 'City Builder', 'Great Soundtrack', 'Economy', 'Singleplayer', 'Comedy', 'Sandbox', 'Cold War']
# ['Action']
# ['Adventure', 'Action']
# ['Action', 'Indie', 'Casual']
# ['Strategy', 'Simulation']
# ['Strategy', 'Indie']
# ['Strategy', 'Indie']
# ['Strategy']
# ['Action', 'Horror']
# ['Strategy', 'Indie']
# ['Simulation', 'Trains', 'Co-op', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Simulation', 'Trains', 'Co-op', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR']
# ['Simulation', 'Trains', 'Realistic', 'Family Friendly', 'TrackIR', 'Co-op', 'Open World', 'Sandbox', 'Physics', 'Atmospheric']
# ['Simulation', 'Trains', 'Open World', 'Sandbox', 'Physics', 'Atmospheric', 'Realistic', 'Family Friendly', 'TrackIR', 'Co-op']
# ['Strategy']
# ['Strategy', 'Casual']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['Strategy']
# ['RPG', 'Action', 'Zombies']
# ['Indie']
# ['RPG', 'Action']
# ['Strategy', 'Indie']
# ['Indie']
# ['Strategy', 'Indie', 'Simulation']
# ['Strategy', 'RPG']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Casual', 'Simulation']
# ['Free to Play', 'Action', 'Gore', 'Violent']
# ['Action']
# ['Strategy', 'RPG', 'Indie']
# ['Strategy', 'RPG', 'Indie', 'Turn-Based', 'Fantasy', 'Software', 'Online Co-Op', 'Utilities', 'Party-Based RPG', 'Sandbox']
# ['Simulation']
# ['Action', 'Massively Multiplayer', 'Indie']
# ['Indie', 'Casual']
# ['Action', 'Indie', 'Simulation', 'Racing', 'Gore', 'Violent']
# ['Indie', 'Casual']
# ['Indie', 'Casual']
# ['Adventure', 'Indie']
# ['Action', 'Adventure', 'Indie', 'Casual']
# ['Strategy', 'Action', 'Indie']
# ['Action', 'Gore', 'Violent']
# ['Utilities']
# ['Utilities']
# ['Utilities']
# ['Utilities']
# ['Action', 'Adventure', 'RPG', 'Indie', 'Casual']
# ['Utilities']
# ['Action', 'Indie']
# ['Action', 'Free to Play', 'Violent']
# ['Action', 'Indie', 'Casual', 'Racing', 'Free to Play', 'Singleplayer', 'Atmospheric', 'Arcade', '2D', 'Competitive', 'Minimalist', 'Retro']
# ['Indie', 'Simulation']
# ['Action', 'Indie', 'Casual', 'Racing', 'Free to Play', 'Singleplayer', 'Atmospheric', 'Arcade', '2D', 'Competitive', 'Minimalist', 'Retro']
# ['Action', 'Indie', 'Casual', 'Racing', 'Free to Play', 'Singleplayer', 'Atmospheric', 'Arcade', '2D', 'Competitive', 'Minimalist', 'Retro']
# ['Strategy', 'RPG', 'Indie', 'Casual', 'Simulation']
# ['Adventure', 'Indie', 'Casual', 'Simulation', 'Sports']
# ['Action', 'Adventure', 'RPG']
# ['Racing', 'Simulation', 'Kickstarter', 'Driving', 'Singleplayer']
# ['Strategy', 'Adventure', 'Indie', 'Casual', 'Simulation', 'Physics', 'Science']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Simulation', 'Racing', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Simulation', 'Racing', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Sexual Content', 'Nudity', 'Action', 'Adventure', 'RPG', 'Indie', 'Gore', 'Violent']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ['Massively Multiplayer', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Action', 'Adventure', 'Indie']
# ['Free to Play', 'Action', 'Massively Multiplayer', 'Casual', 'Sports']
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Casual', 'Sports']
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Casual', 'Sports']
# ['Strategy', 'Action', 'Adventure', 'Indie', 'Casual']
# ['Action', 'Indie']
# ['Adventure', 'Indie', 'Casual', 'Simulation', 'Sports']
# ['Adventure', 'Indie', 'Casual', 'Simulation', 'Sports']
# ['Strategy', 'Indie']
# ['Action', 'Massively Multiplayer', 'Racing']
# ['Strategy', 'Action', 'Adventure', 'RPG', 'Indie']
# ['RPG', 'Violent', 'Nudity']
# ['Massively Multiplayer', 'Simulation', 'Racing', 'Sports']
# ['Action', 'Adventure', 'Indie', 'Casual']
# ['Indie']
# ['Adventure', 'Indie', 'Casual', 'Free to Play']
# ['Design & Illustration', 'Utilities', 'Animation & Modeling']
# ['Action', 'Indie', 'Casual', 'Racing', 'Free to Play', 'Singleplayer', 'Atmospheric', 'Arcade', '2D', 'Competitive', 'Minimalist', 'Retro']
# ['Adventure', 'Indie', 'Casual', 'Simulation', 'Sports']
# ['Action', 'Indie', 'Casual', 'Racing', 'Free to Play', 'Singleplayer', 'Atmospheric', 'Arcade', '2D', 'Competitive', 'Minimalist', 'Retro']
# ['Action', 'Free to Play', 'Violent']
# ['Action', 'Indie', 'Casual', 'Racing', 'Free to Play', 'Singleplayer', 'Atmospheric', 'Arcade', '2D', 'Competitive', 'Minimalist', 'Retro']
# ['Free to Play', 'Action', 'Indie', 'Casual', 'Racing', 'Singleplayer', 'Atmospheric', 'Arcade', '2D', 'Competitive', 'Minimalist', 'Retro']
# ['Action', 'Free to Play', 'Violent']
# ['Action', 'Free to Play', 'Violent']
# ['Adventure', 'RPG', 'Indie', 'Casual']
# ['Strategy', 'Adventure', 'RPG', 'Indie', 'Casual', 'Simulation']
# ['Action', 'Indie']
# ['Adventure', 'RPG', 'Indie']
# ['Utilities']
# ['Casual']
# ['Utilities']
# ['Casual', 'Strategy']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Simulation']
# ['Strategy']
# ['Action', 'Indie']
# ['Action', 'Indie']
# ['Indie']
# ['Action']
# ['Simulation']
# ['Casual']
# ['Action', 'Indie', 'Casual', 'Simulation']
# ['Strategy', 'RPG', 'Indie']
# ['Strategy', 'RPG', 'Indie', 'Lovecraftian', 'Turn-Based', 'Online Co-Op', 'Software', 'Utilities', 'Sandbox', 'Party-Based RPG', 'Story Rich']
# ['Strategy', 'RPG', 'Indie']
# ['Free to Play', 'RPG', 'Massively Multiplayer']
# ['RPG']
# ['Adventure', 'Indie']
# ['Casual', 'Simulation']
# ['Adventure', 'Indie']
# ['Action', 'Adventure']
# ['Free to Play', 'Massively Multiplayer', 'Action', 'Adventure', 'RPG', 'Casual']
# ['Strategy']
# ['Action', 'Massively Multiplayer', 'Adventure', 'Free to Play', 'RPG', 'Casual']
# ['Design & Illustration', 'Web Publishing']
# ['Strategy', 'RPG', 'Indie', 'Casual', 'Simulation']
# ['Animation & Modeling']
# ['Simulation']
# ['Animation & Modeling']
# ['Racing']
# ['Action', 'Violent']
# ['Indie', 'Casual', 'Simulation']
# ['Adventure', 'Indie']
# ['Racing', 'Simulation', 'Sports']
# ['Action', 'Indie']
# ['Strategy', 'Action', 'Free to Play']
# ['Free to Play', 'Action']
# ['Action', 'Violent']
# ['Simulation']
# ['Indie']
# ['Indie']
# ['Indie']
# ['Action', 'Free to Play', 'RPG', 'Indie']
# ['RPG', 'Indie', 'Action', 'Free to Play']
# ['Free to Play', 'RPG', 'Indie', 'Action']
# ['Indie', 'Adventure', 'Casual', 'Atmospheric', 'Point & Click', 'Singleplayer', 'Puzzle', 'Surreal', 'Dark', 'Mature', 'Mystery', 'Great Soundtrack', 'Episodic', 'Exploration', '2D', 'Third Person', 'Story Rich', 'Drama', 'Interactive Fiction', 'Horror']
# ['Adventure', 'Indie']
# ['Simulation']
# ['Simulation', 'Indie', 'Driving', 'Open World', 'Multiplayer', 'Free to Play']
# ['Free to Play', 'Massively Multiplayer', 'Simulation', 'Sports']
# ['Simulation']
# ['Action', 'RPG', 'Indie', 'Simulation']
# ['Strategy', 'Action', 'Indie']
# ['Simulation']
# ['Strategy', 'Casual']
# ['Simulation']
# ['RPG', 'Indie']
# ['Racing']
# ['Indie', 'Casual']
# ['RPG']
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# 30       None
#          ...
# 12811    None
# 12812    None
# 12813    None
# 12814    None
# 12815    None
# 12816    None
# 12817    None
# 12818    None
# 12819    None
# 12820    None
# 12821    None
# 12822    None
# 12823    None
# 12824    None
# 12825    None
# 12826    None
# 12827    None
# 12828    None
# 12829    None
# 12830    None
# 12831    None
# 12832    None
# 12833    None
# 12834    None
# 12835    None
# 12836    None
# 12837    None
# 12838    None
# 12839    None
# 12840    None
# Length: 12572, dtype: object

# %%
print(len(dlc_tags))
# Out:
# 285

# %%
dlc_tags_count
# Out:
# {'2D': 65,
#  '2D Fighter': 9,
#  '3D Platformer': 3,
#  '3D Vision': 0,
#  '4 Player Local': 9,
#  '4X': 13,
#  '6DOF': 3,
#  'Abstract': 1,
#  'Action': 4260,
#  'Action RPG': 15,
#  'Action-Adventure': 8,
#  'Adventure': 2522,
#  'Agriculture': 0,
#  'Aliens': 5,
#  'Alternate History': 7,
#  'America': 2,
#  'Animation & Modeling': 111,
#  'Anime': 75,
#  'Arcade': 34,
#  'Arena Shooter': 1,
#  'Assassin': 6,
#  'Asynchronous Multiplayer': 4,
#  'Atmospheric': 221,
#  'Audio Production': 42,
#  'Base Building': 12,
#  'Based On A Novel': 4,
#  'Batman': 10,
#  "Beat 'em up": 3,
#  'Benchmark': 1,
#  'Blood': 8,
#  'Board Game': 20,
#  'Building': 41,
#  'Bullet Hell': 9,
#  'CRPG': 3,
#  'Capitalism': 0,
#  'Card Game': 2,
#  'Cartoon': 4,
#  'Cartoony': 3,
#  'Casual': 3046,
#  'Character Customization': 6,
#  'Choices Matter': 14,
#  'Choose Your Own Adventure': 10,
#  'Cinematic': 2,
#  'City Builder': 38,
#  'Class-Based': 1,
#  'Classic': 18,
#  'Clicker': 5,
#  'Co-op': 107,
#  'Co-op Campaign': 0,
#  'Cold War': 5,
#  'Colorful': 1,
#  'Comedy': 28,
#  'Comic Book': 2,
#  'Competitive': 26,
#  'Conspiracy': 1,
#  'Controller': 8,
#  'Crafting': 18,
#  'Crime': 7,
#  'Crowdfunded': 2,
#  'Cult Classic': 9,
#  'Cute': 24,
#  'Cyberpunk': 9,
#  'Dark': 28,
#  'Dark Comedy': 2,
#  'Dark Fantasy': 15,
#  'Dark Humor': 5,
#  'Dating Sim': 1,
#  'Demons': 6,
#  'Design & Illustration': 358,
#  'Destruction': 4,
#  'Detective': 2,
#  'Difficult': 40,
#  'Dinosaurs': 15,
#  'Diplomacy': 0,
#  'Documentary': 1,
#  'Dragons': 11,
#  'Drama': 9,
#  'Driving': 42,
#  'Dungeon Crawler': 8,
#  'Dynamic Narration': 0,
#  'Dystopian': 9,
#  'Early Access': 1,
#  'Economy': 12,
#  'Education': 70,
#  'Episodic': 9,
#  'Experience': 0,
#  'Experimental': 1,
#  'Exploration': 34,
#  'FPS': 128,
#  'Family Friendly': 129,
#  'Fantasy': 237,
#  'Fast-Paced': 8,
#  'Female Protagonist': 36,
#  'Fighting': 27,
#  'First-Person': 48,
#  'Flight': 27,
#  'Football': 0,
#  'Free to Play': 1152,
#  'Funny': 53,
#  'Futuristic': 11,
#  'Gambling': 1,
#  'Game Development': 63,
#  'GameMaker': 25,
#  'Games Workshop': 10,
#  'Gaming': 0,
#  'Golf': 0,
#  'Gore': 127,
#  'Grand Strategy': 37,
#  'Great Soundtrack': 166,
#  'Grid-Based Movement': 1,
#  'Gun Customization': 3,
#  'Hack and Slash': 6,
#  'Hacking': 5,
#  'Hand-drawn': 1,
#  'Heist': 15,
#  'Hex Grid': 9,
#  'Hidden Object': 2,
#  'Historical': 48,
#  'Horror': 78,
#  'Horses': 3,
#  'Hunting': 3,
#  'Illuminati': 6,
#  'Indie': 5051,
#  'Interactive Fiction': 4,
#  'Investigation': 3,
#  'Isometric': 7,
#  'JRPG': 7,
#  'Kickstarter': 3,
#  'LEGO': 18,
#  'Level Editor': 28,
#  'Linear': 1,
#  'Local Co-Op': 8,
#  'Local Multiplayer': 11,
#  'Loot': 9,
#  'Lore-Rich': 4,
#  'Lovecraftian': 22,
#  'MMORPG': 7,
#  'MOBA': 7,
#  'Magic': 8,
#  'Management': 6,
#  'Martial Arts': 0,
#  'Massively Multiplayer': 639,
#  'Mature': 10,
#  'Mechs': 1,
#  'Medieval': 14,
#  'Memes': 19,
#  'Metroidvania': 4,
#  'Military': 13,
#  'Minimalist': 20,
#  'Mod': 2,
#  'Moddable': 37,
#  'Modern': 4,
#  'Mouse only': 3,
#  'Movie': 1,
#  'Multiplayer': 166,
#  'Multiple Endings': 3,
#  'Music': 94,
#  'Music-Based Procedural Generation': 0,
#  'Mystery': 11,
#  'Mystery Dungeon': 2,
#  'Mythology': 1,
#  'Naval': 5,
#  'Ninja': 6,
#  'Noir': 8,
#  'Nonlinear': 0,
#  'Nudity': 45,
#  'Online Co-Op': 215,
#  'Open World': 204,
#  'Otome': 1,
#  'Parkour': 5,
#  'Parody': 1,
#  'Party-Based RPG': 189,
#  'Perma Death': 7,
#  'Photo Editing': 38,
#  'Physics': 97,
#  'Pinball': 7,
#  'Pirates': 11,
#  'Pixel Graphics': 22,
#  'Platformer': 22,
#  'Point & Click': 18,
#  'Political': 0,
#  'Politics': 1,
#  'Post-apocalyptic': 26,
#  'Procedural Generation': 5,
#  'Programming': 1,
#  'Psychological': 5,
#  'Psychological Horror': 17,
#  'Puzzle': 41,
#  'Puzzle-Platformer': 15,
#  'PvE': 4,
#  'PvP': 11,
#  'RPG': 2729,
#  'RPGMaker': 44,
#  'RTS': 33,
#  'Racing': 460,
#  'Real Time Tactics': 3,
#  'Real-Time': 6,
#  'Realistic': 131,
#  'Relaxing': 33,
#  'Remake': 4,
#  'Replay Value': 32,
#  'Resource Management': 8,
#  'Retro': 25,
#  'Rhythm': 4,
#  'Robots': 2,
#  'Rogue-like': 19,
#  'Rogue-lite': 5,
#  'Romance': 4,
#  'Rome': 10,
#  'Runner': 4,
#  'Sailing': 4,
#  'Sandbox': 232,
#  'Satire': 0,
#  'Sci-fi': 64,
#  'Science': 3,
#  'Score Attack': 0,
#  'Sexual Content': 41,
#  "Shoot 'Em Up": 17,
#  'Shooter': 68,
#  'Short': 9,
#  'Side Scroller': 4,
#  'Silent Protagonist': 0,
#  'Simulation': 4158,
#  'Singleplayer': 197,
#  'Sniper': 2,
#  'Soccer': 0,
#  'Software': 214,
#  'Software Training': 42,
#  'Soundtrack': 100,
#  'Space': 31,
#  'Space Sim': 5,
#  'Sports': 649,
#  'Star Wars': 0,
#  'Stealth': 46,
#  'Steampunk': 7,
#  'Story Rich': 205,
#  'Strategy': 3486,
#  'Strategy RPG': 1,
#  'Stylized': 15,
#  'Superhero': 1,
#  'Supernatural': 2,
#  'Surreal': 5,
#  'Survival': 51,
#  'Survival Horror': 22,
#  'Swordplay': 4,
#  'Tactical': 34,
#  'Tactical RPG': 2,
#  'Tanks': 2,
#  'Team-Based': 12,
#  'Text-Based': 0,
#  'Third Person': 24,
#  'Third-Person Shooter': 9,
#  'Top-Down': 3,
#  'Top-Down Shooter': 7,
#  'Touch-Friendly': 5,
#  'Tower Defense': 4,
#  'TrackIR': 108,
#  'Trading': 4,
#  'Trading Card Game': 3,
#  'Trains': 116,
#  'Turn-Based': 258,
#  'Turn-Based Combat': 9,
#  'Turn-Based Strategy': 32,
#  'Turn-Based Tactics': 11,
#  'Twin Stick Shooter': 3,
#  'Typing': 1,
#  'Underground': 1,
#  'Underwater': 1,
#  'Utilities': 350,
#  'VR': 12,
#  'Vampire': 2,
#  'Video Production': 40,
#  'Violent': 177,
#  'Visual Novel': 38,
#  'Walking Simulator': 6,
#  'War': 23,
#  'Wargame': 6,
#  'Warhammer 40K': 10,
#  'Web Publishing': 253,
#  'Werewolves': 1,
#  'Western': 11,
#  'World War I': 1,
#  'World War II': 16,
#  'Zombies': 47,
#  'e-sports': 0}

# %%
# save dictionaries as csv
(pd.DataFrame.from_dict(data=dlc_tags_count, orient='index').
to_csv('dlc_tags_count.csv', header=True))

(pd.DataFrame.from_dict(data=dlc_tags, orient='index').
to_csv('dlc_tags.csv', header=True))

# %% [markdown]
# #### Cleaning

# %%
cleaned_dlcs.drop(columns=['discount_price', 'url', 'app_name', 'parent_game', 'reviews_url'], inplace=True)
print(len(cleaned_dlcs))
cleaned_dlcs.head()
# Out:
# 12572
#                                          description  \
# 0  [, About This Content, ►, Murum Charta, Commun...
# 1  [, About This Content, Unlocks three new ultra...
# 2  [, About This Content, The Wilmington Internat...
# 3  [, About This Content, Get ready for another h...
# 4  [, About This Content, With its three dark ele...
#
#                         developer                      genres      id  \
# 0             ImaginationOverflow     [Action, Casual, Indie]  777450
# 1  Stegalosaurus Game Development     [Adventure, Indie, RPG]  694780
# 2              Drawbridge Designs                [Simulation]  623613
# 3             Thomson Interactive                [Simulation]  642803
# 4                     Bryan Minus  [Adventure, Casual, Indie]  722550
#
#                              parent_game_url  price                publisher  \
# 0  http://store.steampowered.com/app/517330/   Free                      NaN
# 1  http://store.steampowered.com/app/592200/   0.99                      NaN
# 2  http://store.steampowered.com/app/269950/  19.99            Aerosoft GmbH
# 3   http://store.steampowered.com/app/24010/  19.99  Dovetail Games - Trains
# 4  http://store.steampowered.com/app/717830/   1.99        Minus Equals Plus
#
#   release_date       sentiment  \
# 0   2017-12-30             NaN
# 1   2018-01-11             NaN
# 2   2018-01-11             NaN
# 3   2018-01-11  5 user reviews
# 4   2018-01-11             NaN
#
#                                                specs  \
# 0  [Single-player, Downloadable Content, Steam Ac...
# 1  [Single-player, Downloadable Content, Steam Ac...
# 2  [Single-player, Online Multi-Player, Local Mul...
# 3  [Single-player, Downloadable Content, Steam Ac...
# 4              [Single-player, Downloadable Content]
#
#                          tags  \
# 0     [Action, Indie, Casual]
# 1     [Adventure, RPG, Indie]
# 2                [Simulation]
# 3                [Simulation]
# 4  [Adventure, Indie, Casual]
#
#                                                title
# 0                   Stellar Interface - Murum Charta
# 1  SUPER ARMY OF TENTACLES 3, Winter Outfit Pack ...
# 2  X-Plane 11 - Add-on: Aerosoft - Airport Wilmin...
# 3    Train Simulator: RhB Enhancement Pack 02 Add-On
# 4    Waiting For the Loop Official Soundtrack and EP

# %%
# check data types
for column in cleaned_dlcs.columns:
    print(str(column) + ': ' +  str(cleaned_dlcs[column].dtype))
# Out:
# description: object
# developer: object
# genres: object
# id: int64
# parent_game_url: object
# price: object
# publisher: object
# release_date: object
# sentiment: object
# specs: object
# tags: object
# title: object

# %%
# check for missing data
for column in cleaned_dlcs.columns:
    if np.any(pd.isnull(cleaned_dlcs[column])) == True:
        print(column)
# Out:
# description
# developer
# genres
# price
# publisher
# release_date
# sentiment
# title

# %% [markdown]
# #### Investigate missing data

# %%
# inspect missing description
print(len(cleaned_dlcs.loc[pd.isnull(cleaned_dlcs['description']), 'description']))
cleaned_dlcs.iloc[683]
# Out:
# 52
# description        [, About This Content, DCS: Flaming Cliffs 3 i...
# developer                                          Eagle Dynamics SA
# genres                                                  [Simulation]
# id                                                            249320
# parent_game_url            http://store.steampowered.com/app/223750/
# price                                                          39.99
# publisher                                     The Fighter Collection
# release_date                                              2012-11-08
# sentiment                                              Very Positive
# specs              [Single-player, Multi-player, Downloadable Con...
# tags                                  [Simulation, Flight, Military]
# title                                          DCS: Flaming Cliffs 3
# Name: 706, dtype: object

# %%
# fill in missing description with empty string
cleaned_dlcs['description'].fillna('', inplace=True)

# %%
print(cleaned_dlcs['price'].unique())
# Out:
# ['Free' 0.99 19.99 1.99 2.99 11.99 9.99 199.99 39.99 7.99 10.99 24.99 6.99
#  8.99 14.99 13.99 4.99 5.99 7.49 3.49 3.99 nan 1.49 1.5899999999999999
#  12.99 29.99 2.49 16.99 49.99 5.0 44.99 17.99 299.99 34.99 99.99 69.99
#  15.99 21.99 79.99 10.0 'Free to Play' 15.0 289.99 4.49 18.99 64.99
#  'Third-party' 'Play Now' 5.49 89.99 6.49 1.29 54.99 23.99
#  1.3900000000000001 36.99 31.99 'Free To Play' 199.0 49.0 99.0 59.99 27.99
#  2.66 249.99 499.99 26.98 119.99 131.4 22.99 995.0 27.49 6.0 3.39 19.95
#  149.99 38.85 71.7 20.0 30.0 74.99 7.0 20.99 42.99 'Install Theme' 41.99
#  4.29 59.95 109.99 1.25]

# %%
# drop row with price third-party
cleaned_dlcs.loc[cleaned_dlcs['price'] =='Third-party'].index
cleaned_dlcs.drop(cleaned_dlcs.loc[cleaned_dlcs['price'] =='Third-party'].index, inplace=True)

# %%
# fill in missing price (nan is usually for free products)
cleaned_dlcs['price'].fillna(0.0, inplace=True)

# %%
# clean price data
cleaned_dlcs.loc[cleaned_dlcs['price'] == 'Free', 'price'] = 0.0
cleaned_dlcs.loc[cleaned_dlcs['price'] == 'Play Now', 'price'] = 0.0
cleaned_dlcs.loc[cleaned_dlcs['price'] == 'Free to Play', 'price'] = 0.0
cleaned_dlcs.loc[cleaned_dlcs['price'] == 'Free To Play', 'price'] = 0.0
cleaned_dlcs.loc[cleaned_dlcs['price'] == 'Install Theme', 'price'] = 0.0

# %%
print(cleaned_dlcs['price'].unique())
cleaned_dlcs['price'] = cleaned_dlcs.price.astype(float)
# Out:
# [0.0 0.99 19.99 1.99 2.99 11.99 9.99 199.99 39.99 7.99 10.99 24.99 6.99
#  8.99 14.99 13.99 4.99 5.99 7.49 3.49 3.99 1.49 1.5899999999999999 12.99
#  29.99 2.49 16.99 49.99 5.0 44.99 17.99 299.99 34.99 99.99 69.99 15.99
#  21.99 79.99 10.0 15.0 289.99 4.49 18.99 64.99 5.49 89.99 6.49 1.29 54.99
#  23.99 1.3900000000000001 36.99 31.99 199.0 49.0 99.0 59.99 27.99 2.66
#  249.99 499.99 26.98 119.99 131.4 22.99 995.0 27.49 6.0 3.39 19.95 149.99
#  38.85 71.7 20.0 30.0 74.99 7.0 20.99 42.99 41.99 4.29 59.95 109.99 1.25]

# %%
# extract parent game app id from parent game url
def get_parent_game_id(row):
    """This function extracts the game app id from the url"""
    import re
    
    parent_url = row['parent_game_url']
    
    return re.findall('app/(\d+)/',row['parent_game_url'])[0]

# %%
cleaned_dlcs['parent_game_id'] = cleaned_dlcs.apply(get_parent_game_id, axis=1)
cleaned_dlcs['parent_game_id'] = cleaned_dlcs['parent_game_id'].astype(int)

# %%
cleaned_dlcs.head()
# Out:
#                                          description  \
# 0  [, About This Content, ►, Murum Charta, Commun...
# 1  [, About This Content, Unlocks three new ultra...
# 2  [, About This Content, The Wilmington Internat...
# 3  [, About This Content, Get ready for another h...
# 4  [, About This Content, With its three dark ele...
#
#                         developer                      genres      id  \
# 0             ImaginationOverflow     [Action, Casual, Indie]  777450
# 1  Stegalosaurus Game Development     [Adventure, Indie, RPG]  694780
# 2              Drawbridge Designs                [Simulation]  623613
# 3             Thomson Interactive                [Simulation]  642803
# 4                     Bryan Minus  [Adventure, Casual, Indie]  722550
#
#                              parent_game_url  price                publisher  \
# 0  http://store.steampowered.com/app/517330/   0.00                      NaN
# 1  http://store.steampowered.com/app/592200/   0.99                      NaN
# 2  http://store.steampowered.com/app/269950/  19.99            Aerosoft GmbH
# 3   http://store.steampowered.com/app/24010/  19.99  Dovetail Games - Trains
# 4  http://store.steampowered.com/app/717830/   1.99        Minus Equals Plus
#
#   release_date       sentiment  \
# 0   2017-12-30
# 1   2018-01-11
# 2   2018-01-11
# 3   2018-01-11  5 user reviews
# 4   2018-01-11
#
#                                                specs  \
# 0  [Single-player, Downloadable Content, Steam Ac...
# 1  [Single-player, Downloadable Content, Steam Ac...
# 2  [Single-player, Online Multi-Player, Local Mul...
# 3  [Single-player, Downloadable Content, Steam Ac...
# 4              [Single-player, Downloadable Content]
#
#                          tags  \
# 0     [Action, Indie, Casual]
# 1     [Adventure, RPG, Indie]
# 2                [Simulation]
# 3                [Simulation]
# 4  [Adventure, Indie, Casual]
#
#                                                title parent_game_id
# 0                   Stellar Interface - Murum Charta         517330
# 1  SUPER ARMY OF TENTACLES 3, Winter Outfit Pack ...         592200
# 2  X-Plane 11 - Add-on: Aerosoft - Airport Wilmin...         269950
# 3    Train Simulator: RhB Enhancement Pack 02 Add-On          24010
# 4    Waiting For the Loop Official Soundtrack and EP         717830

# %%
cleaned_dlcs = cleaned_dlcs.drop(columns=['parent_game_url', 'sentiment'])

# %%
cleaned_dlcs.head()
# Out:
#                                          description  \
# 0  [, About This Content, ►, Murum Charta, Commun...
# 1  [, About This Content, Unlocks three new ultra...
# 2  [, About This Content, The Wilmington Internat...
# 3  [, About This Content, Get ready for another h...
# 4  [, About This Content, With its three dark ele...
#
#                         developer                      genres      id  price  \
# 0             ImaginationOverflow     [Action, Casual, Indie]  777450   0.00
# 1  Stegalosaurus Game Development     [Adventure, Indie, RPG]  694780   0.99
# 2              Drawbridge Designs                [Simulation]  623613  19.99
# 3             Thomson Interactive                [Simulation]  642803  19.99
# 4                     Bryan Minus  [Adventure, Casual, Indie]  722550   1.99
#
#                  publisher release_date  \
# 0                      NaN   2017-12-30
# 1                      NaN   2018-01-11
# 2            Aerosoft GmbH   2018-01-11
# 3  Dovetail Games - Trains   2018-01-11
# 4        Minus Equals Plus   2018-01-11
#
#                                                specs  \
# 0  [Single-player, Downloadable Content, Steam Ac...
# 1  [Single-player, Downloadable Content, Steam Ac...
# 2  [Single-player, Online Multi-Player, Local Mul...
# 3  [Single-player, Downloadable Content, Steam Ac...
# 4              [Single-player, Downloadable Content]
#
#                          tags  \
# 0     [Action, Indie, Casual]
# 1     [Adventure, RPG, Indie]
# 2                [Simulation]
# 3                [Simulation]
# 4  [Adventure, Indie, Casual]
#
#                                                title parent_game_id
# 0                   Stellar Interface - Murum Charta         517330
# 1  SUPER ARMY OF TENTACLES 3, Winter Outfit Pack ...         592200
# 2  X-Plane 11 - Add-on: Aerosoft - Airport Wilmin...         269950
# 3    Train Simulator: RhB Enhancement Pack 02 Add-On          24010
# 4    Waiting For the Loop Official Soundtrack and EP         717830

# %%
# check for missing data
for column in cleaned_dlcs.columns:
    if np.any(pd.isnull(cleaned_dlcs[column])) == True:
        print(column)
# Out:
# developer
# genres
# publisher
# release_date
# title

# %%
print(len(cleaned_dlcs.loc[pd.isnull(cleaned_dlcs['release_date'])]))
# Out:
# 34

# %%
len(cleaned_dlcs)
# Out:
# 12571

# %%
# check data types
for column in cleaned_dlcs.columns:
    print(str(column) + ': ' +  str(cleaned_dlcs[column].dtype))
# Out:
# description: object
# developer: object
# genres: object
# id: int64
# price: float64
# publisher: object
# release_date: object
# specs: object
# tags: object
# title: object
# parent_game_id: int64

# %%
cleaned_dlcs.head()
# Out:
#                                          description  \
# 0  [, About This Content, ►, Murum Charta, Commun...
# 1  [, About This Content, Unlocks three new ultra...
# 2  [, About This Content, The Wilmington Internat...
# 3  [, About This Content, Get ready for another h...
# 4  [, About This Content, With its three dark ele...
#
#                         developer                      genres      id  price  \
# 0             ImaginationOverflow     [Action, Casual, Indie]  777450      0
# 1  Stegalosaurus Game Development     [Adventure, Indie, RPG]  694780   0.99
# 2              Drawbridge Designs                [Simulation]  623613  19.99
# 3             Thomson Interactive                [Simulation]  642803  19.99
# 4                     Bryan Minus  [Adventure, Casual, Indie]  722550   1.99
#
#                  publisher release_date  \
# 0                            2017-12-30
# 1                            2018-01-11
# 2            Aerosoft GmbH   2018-01-11
# 3  Dovetail Games - Trains   2018-01-11
# 4        Minus Equals Plus   2018-01-11
#
#                                                specs  \
# 0  [Single-player, Downloadable Content, Steam Ac...
# 1  [Single-player, Downloadable Content, Steam Ac...
# 2  [Single-player, Online Multi-Player, Local Mul...
# 3  [Single-player, Downloadable Content, Steam Ac...
# 4              [Single-player, Downloadable Content]
#
#                          tags  \
# 0     [Action, Indie, Casual]
# 1     [Adventure, RPG, Indie]
# 2                [Simulation]
# 3                [Simulation]
# 4  [Adventure, Indie, Casual]
#
#                                                title parent_game_id
# 0                   Stellar Interface - Murum Charta         517330
# 1  SUPER ARMY OF TENTACLES 3, Winter Outfit Pack ...         592200
# 2  X-Plane 11 - Add-on: Aerosoft - Airport Wilmin...         269950
# 3    Train Simulator: RhB Enhancement Pack 02 Add-On          24010
# 4    Waiting For the Loop Official Soundtrack and EP         717830

# %%
cleaned_dlcs['publisher'].unique()
# Out:
# array(['', 'Aerosoft GmbH', 'Dovetail Games - Trains', ..., 'Motion Twin',
#        'KoheiGallery', 'IzHard'], dtype=object)

# %%
cleaned_dlcs['developer'] = cleaned_dlcs['developer'].astype(str)
cleaned_dlcs['publisher'] = cleaned_dlcs['publisher'].astype(str)
cleaned_dlcs['title'] = cleaned_dlcs['title'].astype(str)
cleaned_dlcs['price'] = cleaned_dlcs['price'].astype(float)

# %%
cleaned_dlcs.to_csv('dlcs_cleaned.csv')

# %% [markdown]
# # Cleaning scraped DLC reviews data

# %%
# load scraped dlc reviews
data1 = pd.read_json('raw_data/reviews_1.json', dtype=False)
data2 = pd.read_json('raw_data/reviews_2.json', dtype=False)
data3 = pd.read_json('raw_data/reviews_3.json', dtype=False)
data4 = pd.read_json('raw_data/reviews_4.json', dtype=False)
data5 = pd.read_json('raw_data/reviews_5.json', dtype=False)

# %%
reviews_raw = pd.DataFrame(columns=data1.columns)
reviews_raw = reviews_raw.append(data1).append(data2).append(data3).append(data4)
print(len(reviews_raw))
reviews_raw.head()
# Out:
# 73128
#   compensation        date  hours num_reviews product_id  products  \
# 0        False  January-13    NaN          35     642803     468.0
# 1        False  January-12    NaN           6     760610     888.0
# 2        False  January-11    NaN          37     760610     213.0
# 3        False  January-15    NaN           8     779280     164.0
# 4        False  January-14    NaN          94     779280     304.0
#
#    recommended                                               text  \
# 0  Recommended  Okay, get thisyou can open the cab's side door...
# 1  Recommended  Bought for the pure respect of the original pr...
# 2  Recommended  One of my favorite pages is 23 1920.pngThey ar...
# 3  Recommended                             i have found my queen.
# 4  Recommended                    Should be called: The Flat Pack
#
#              user_id           user_url        username
# 0                NaN             taschi      🚂🚃Taschi🚃🚃
# 1  76561197999899413                NaN  Crimson-Albedo
# 2                NaN            MoeShan         MoeShan
# 3                NaN         plachtaA17   I know de wae
# 4                NaN  disabledchildlite        Putotyra

# %%
# reset index and drop extraneous index column
reviews_raw = reviews_raw.reset_index().drop(columns='index')

# %% [markdown]
# #### Grabbing user_ids from the user_urls

# %%
# Steam has different ways to route to the user profiles
# by user_url: http://steamcommunity.com/id/user_url/
# by user id:  http://steamcommunity.com/profiles/user_id

api_key = 'your api key'
my_id = 'your steam id'

# %%
# write a function that grabs the user_id based on their user_url (if user_id is missing) 
# user_ids are required to make Steam API calls later
grabbed_user_ids = pd.Series(index = reviews_raw.index)
def get_user_id(row):
    """This function gets the user steamID64 from the user_url"""
    from urllib.request import Request, urlopen
    import json
    
    # if user_id is null, we want to get the user_id from the user_url
    if pd.isnull(row['user_id']):
        url = """
        http://api.steampowered.com/ISteamUser/ResolveVanityURL/v1/?key={}&steamid={}&format=json&vanityurl={}
        """.format(api_key, my_id, row['user_url'])
    
        print(row['user_url'])
        req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        data = urlopen(req).read().decode('utf-8')
        feed = json.loads(data)
        #print(feed)
        
        try:
            # grab user_id if it exists
            user_id = feed['response']['steamid']
            
            # append to instantiated series
            grabbed_user_ids.iloc[row.name] = user_id
            
            return user_id
        except:
            pass

# %%
# grab the user ids and print to a separate file in order to retrieve their owned games later
grabbed_user_ids = pd.Series(index = reviews_raw.index)
reviews_raw['grabbed_user_id'] = reviews_raw.apply(get_user_id, axis=1)
np.savetxt('user_id_1.txt', grabbed_user_ids, fmt='%s')

# %% [markdown]
# #### Unify user info columns to get the final user id

# %%
reviews_raw.head()
# Out:
#   compensation        date  hours num_reviews product_id  products  \
# 0        False  January-13    NaN          35     642803     468.0
# 1        False  January-12    NaN           6     760610     888.0
# 2        False  January-11    NaN          37     760610     213.0
# 3        False  January-15    NaN           8     779280     164.0
# 4        False  January-14    NaN          94     779280     304.0
#
#    recommended                                               text  \
# 0  Recommended  Okay, get thisyou can open the cab's side door...
# 1  Recommended  Bought for the pure respect of the original pr...
# 2  Recommended  One of my favorite pages is 23 1920.pngThey ar...
# 3  Recommended                             i have found my queen.
# 4  Recommended                    Should be called: The Flat Pack
#
#              user_id           user_url        username    grabbed_user_id
# 0                NaN             taschi      🚂🚃Taschi🚃🚃  76561198067019938
# 1  76561197999899413                NaN  Crimson-Albedo                NaN
# 2                NaN            MoeShan         MoeShan  76561198151921721
# 3                NaN         plachtaA17   I know de wae  76561198141277447
# 4                NaN  disabledchildlite        Putotyra  76561198067653526

# %%
def combine_user_id(row):
    """This function combines the user_id and grabbed_user_id column into a new column"""
    
    # if grabbed_user_id is null, we want to get the user_id from the user_id (assuming it exists)
    if pd.isnull(row['grabbed_user_id']):
        if not pd.isnull(row['user_id']):
            return row['user_id']
    # if grabbed_user_id is not null, return original value
    else:
        return row['grabbed_user_id']

# %%
# perform apply operations to combine the grabbed_user_id and user_id
reviews_raw['final_user_id'] = reviews_raw.apply(combine_user_id, axis=1)

# %%
# check how many null values exist in the final_user_id column
null_user_id = reviews_raw.loc[pd.isnull(reviews_raw['final_user_id']), 'final_user_id']
print('Number of user data that cannot be tracked: '+str(len(null_user_id)))
# Out:
# Number of user data that cannot be tracked: 4

# %%
# inspect the null data rows
print(null_user_id)
print(reviews_raw.iloc[6174])
print(reviews_raw.iloc[31853])
# Out:
# 6174     None
# 31853    None
# 49031    None
# 59322    None
# Name: final_user_id, dtype: object
# compensation                                                   False
# date                                                    June-21-2017
# hours                                                            NaN
# num_reviews                                                       51
# product_id                                                    210937
# products                                                         117
# recommended                                              Recommended
# text               my favorite character i always played during t...
# user_id                                                          NaN
# user_url                                       Wrath_Of_The_Ancients
# username                                                      Mhorti
# grabbed_user_id                                                  NaN
# final_user_id                                                   None
# Name: 6174, dtype: object
# compensation                                                   False
# date                                                 December-5-2015
# hours                                                            NaN
# num_reviews                                                       16
# product_id                                                    379233
# products                                                         159
# recommended                                          Not Recommended
# text               Though appreciating other lights over the defa...
# user_id                                                          NaN
# user_url                                                     Riggert
# username                                                   Riggert♥J
# grabbed_user_id                                                  NaN
# final_user_id                                                   None
# Name: 31853, dtype: object

# %%
# save current process to file
#reviews_raw.to_csv('raw_data/raw_dlc_review_data_1.csv')

# %%
reviews_raw.head()
# Out:
#   compensation        date  hours num_reviews product_id  products  \
# 0        False  January-13    NaN          35     642803     468.0
# 1        False  January-12    NaN           6     760610     888.0
# 2        False  January-11    NaN          37     760610     213.0
# 3        False  January-15    NaN           8     779280     164.0
# 4        False  January-14    NaN          94     779280     304.0
#
#    recommended                                               text  \
# 0  Recommended  Okay, get thisyou can open the cab's side door...
# 1  Recommended  Bought for the pure respect of the original pr...
# 2  Recommended  One of my favorite pages is 23 1920.pngThey ar...
# 3  Recommended                             i have found my queen.
# 4  Recommended                    Should be called: The Flat Pack
#
#              user_id           user_url        username    grabbed_user_id  \
# 0                NaN             taschi      🚂🚃Taschi🚃🚃  76561198067019938
# 1  76561197999899413                NaN  Crimson-Albedo                NaN
# 2                NaN            MoeShan         MoeShan  76561198151921721
# 3                NaN         plachtaA17   I know de wae  76561198141277447
# 4                NaN  disabledchildlite        Putotyra  76561198067653526
#
#        final_user_id
# 0  76561198067019938
# 1  76561197999899413
# 2  76561198151921721
# 3  76561198141277447
# 4  76561198067653526

# %% [markdown]
# ### Cleaning

# %%
# check data types
cleaned_reviews = reviews_raw
for column in cleaned_reviews.columns:
    print(str(column) + ': ' +  str(cleaned_reviews[column].dtype))
# Out:
# compensation: object
# date: object
# hours: float64
# num_reviews: object
# product_id: object
# products: float64
# recommended: object
# text: object
# user_id: object
# user_url: object
# username: object
# grabbed_user_id: object
# final_user_id: object

# %%
# check for missing data
for column in cleaned_reviews.columns:
    if np.any(pd.isnull(cleaned_reviews[column])) == True:
        print(column)
# Out:
# hours
# products
# user_id
# user_url
# username
# grabbed_user_id
# final_user_id

# %% [markdown]
# #### Investigate missing data

# %%
# inspecting null columns of products, seems like NaN was pulled for private user profiles
private_users = cleaned_reviews.loc[pd.isnull(cleaned_reviews['products']) == True]
print(len(private_users))
private_users.index
# Out:
# 66
# Int64Index([ 2595,  5440,  8426,  9419, 15259, 15633, 15648, 15722, 15764,
#             16118, 16247, 16806, 17655, 18553, 23001, 26733, 29398, 29595,
#             29612, 29694, 30033, 30928, 32197, 32571, 32620, 34029, 35605,
#             35652, 36039, 36194, 38084, 38538, 39738, 42890, 45200, 46640,
#             46977, 48217, 49655, 49738, 50874, 51149, 51596, 52182, 54485,
#             54488, 55437, 56445, 56468, 57183, 64459, 64508, 64609, 64614,
#             65975, 66466, 68562, 68564, 68677, 68849, 68972, 69234, 69960,
#             70533, 70564, 70946],
#            dtype='int64')

# %%
# inspect missing ids

# Create variable with TRUE if user_id is missing
missing_id = pd.isnull(cleaned_reviews['user_id']) == True
# Create variable with TRUE if grabbed_user_id is missing
missing_grabbed_id = pd.isnull(cleaned_reviews['grabbed_user_id']) == True

# Select all cases where user ID is missing
no_id = cleaned_reviews[missing_id & missing_grabbed_id]
no_id.index
# Out:
# Int64Index([6174, 31853, 49031, 59322], dtype='int64')

# %%
# drop rows with missing user ids and products
drop_indices = private_users.index.append(no_id.index)
print(len(drop_indices))

# Drop rows with missing product information and user id information
cleaned_reviews = cleaned_reviews.drop(drop_indices)
# Out:
# 70

# %%
# check if the rows were dropped correctly
print('before dropping rows with missing products: ' + str(len(reviews_raw)))
print('after dropping rows with missing products: ' + str(len(cleaned_reviews)))
# Out:
# before dropping rows with missing products: 73128
# after dropping rows with missing products: 73058

# %%
# fill in missing hours
cleaned_reviews["hours"].fillna(0.0, inplace=True)

# %%
# fill in missing text fields with empty string
cleaned_reviews["text"] = cleaned_reviews["text"].fillna('')

# %%
# check progress so far
for column in cleaned_reviews.columns:
    if np.any(pd.isnull(cleaned_reviews[column])) == True:
        print(column)
# Out:
# user_id
# user_url
# username
# grabbed_user_id

# %%
# drop unnecessary columns
cleaned_reviews = cleaned_reviews.drop(columns=['user_id', 'user_url', 'username', 'grabbed_user_id'])
cleaned_reviews.head()
# Out:
#   compensation        date  hours num_reviews product_id  products  \
# 0        False  January-13    0.0          35     642803     468.0
# 1        False  January-12    0.0           6     760610     888.0
# 2        False  January-11    0.0          37     760610     213.0
# 3        False  January-15    0.0           8     779280     164.0
# 4        False  January-14    0.0          94     779280     304.0
#
#    recommended                                               text  \
# 0  Recommended  Okay, get thisyou can open the cab's side door...
# 1  Recommended  Bought for the pure respect of the original pr...
# 2  Recommended  One of my favorite pages is 23 1920.pngThey ar...
# 3  Recommended                             i have found my queen.
# 4  Recommended                    Should be called: The Flat Pack
#
#        final_user_id
# 0  76561198067019938
# 1  76561197999899413
# 2  76561198151921721
# 3  76561198141277447
# 4  76561198067653526

# %% [markdown]
# #### Convert data types

# %%
cleaned_reviews['compensation'].unique()
# Out:
# array([False, True], dtype=object)

# %%
# convert compensation to boolean
cleaned_reviews.loc[cleaned_reviews['compensation'] == True, 'compensation'] = 1
cleaned_reviews.loc[cleaned_reviews['compensation'] == False, 'compensation'] = 0

# %%
cleaned_reviews['recommended'].unique()
# Out:
# array(['Recommended', 'Not Recommended'], dtype=object)

# %%
# convert recommended to boolean
cleaned_reviews.loc[cleaned_reviews['recommended'] == 'Recommended', 'recommended'] = 1
cleaned_reviews.loc[cleaned_reviews['recommended'] == 'Not Recommended', 'recommended'] = 0

# %%
cleaned_reviews.head(20)
# Out:
#     compensation              date  hours num_reviews product_id  products  \
# 0              0        January-13    0.0          35     642803     468.0
# 1              0        January-12    0.0           6     760610     888.0
# 2              0        January-11    0.0          37     760610     213.0
# 3              0        January-15    0.0           8     779280     164.0
# 4              0        January-14    0.0          94     779280     304.0
# 5              0        January-14    0.0          11     779280      90.0
# 6              0        January-13    0.0          22     779280     127.0
# 7              0        January-12    0.0          13     779280     259.0
# 8              0       July-8-2014    0.1           2      25940     197.0
# 9              0   December-6-2017    0.0          19       8650       8.0
# 10             0      July-11-2017    0.0          10       8650     502.0
# 11             0      June-11-2017    0.0          31       8650     245.0
# 12             0    January-8-2017    0.0           4       8650      12.0
# 13             0  February-15-2016    0.0         339       8650     343.0
# 14             0  February-12-2016    0.0          33       8650      36.0
# 15             0  December-26-2015    0.0          40       8650     417.0
# 16             0  December-22-2015    0.0          28       8650      17.0
# 17             0      June-14-2015    0.0          17       8650      93.0
# 18             0       June-9-2015    0.0           4       8650     741.0
# 19             0    January-8-2015    0.0        1602       8650     181.0
#
#     recommended                                               text  \
# 0             1  Okay, get thisyou can open the cab's side door...
# 1             1  Bought for the pure respect of the original pr...
# 2             1  One of my favorite pages is 23 1920.pngThey ar...
# 3             1                             i have found my queen.
# 4             1                    Should be called: The Flat Pack
# 5             1                              Nice Skill and Damage
# 6             1                                      For my waifu.
# 7             1  as I review in main gameyou can't play as "Sak...
# 8             1  Under System requirements it says: Controller ...
# 9             0                Can't get it to work. What a shame.
# 10            0  IT DONT WORK ...says some bullarke bout cant f...
# 11            1            www.steam://run/8670Should Make it work
# 12            1      I like   Its a bit dated but  still great fun
# 13            0                                      What is this?
# 14            1                          free racing circuit... :)
# 15            1  Pros:- its freeCons:- It does not workEDIT: it...
# 16            0                         it says missing executable
# 17            1                                   Jó játék. Ennyi.
# 18            1             steam://run/8670if it doesn't download
# 19            1  With the high price of the other Race 07 DLC, ...
#
#         final_user_id
# 0   76561198067019938
# 1   76561197999899413
# 2   76561198151921721
# 3   76561198141277447
# 4   76561198067653526
# 5   76561198374084021
# 6   76561198029850210
# 7   76561198056989242
# 8   76561198037549250
# 9   76561198343391469
# 10  76561198147713812
# 11  76561198154756156
# 12  76561198199115533
# 13  76561198056983075
# 14  76561198052603954
# 15  76561198107534431
# 16  76561198188997159
# 17  76561198080619261
# 18  76561198022621589
# 19  76561198045381877

# %%
# process date so that both pandas and psql will understand
def format_date(date):
    date = str(date)
    if len(date) < 2:
        return '0' + date
    else:
        return date
    
def convert_date(row):
    """This function converts the date string to date ISO 8601 format"""
    import datetime
    
    # mapping string to int
    map_month = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6, 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12}
    
    # process string and map to dateformat that datetime will understand
    date_list = row['date'].split('-')
    month = format_date(str(map_month[date_list[0]]))
    day = format_date(str(date_list[1]))
    if len(date_list) == 2:
        year = '2018'
    else:
        year = str(date_list[2])
    
    date = month + day + year

    return datetime.datetime.strptime(date, "%m%d%Y").isoformat()

# %%
cleaned_reviews['date_iso'] = cleaned_reviews.apply(convert_date, axis=1)

# %%
cleaned_reviews = cleaned_reviews.drop(columns=['date'])
cleaned_reviews.head()
# Out:
#    compensation  hours num_reviews product_id  products  recommended  \
# 0             0    0.0          35     642803     468.0            1
# 1             0    0.0           6     760610     888.0            1
# 2             0    0.0          37     760610     213.0            1
# 3             0    0.0           8     779280     164.0            1
# 4             0    0.0          94     779280     304.0            1
#
#                                                 text      final_user_id  \
# 0  Okay, get thisyou can open the cab's side door...  76561198067019938
# 1  Bought for the pure respect of the original pr...  76561197999899413
# 2  One of my favorite pages is 23 1920.pngThey ar...  76561198151921721
# 3                             i have found my queen.  76561198141277447
# 4                    Should be called: The Flat Pack  76561198067653526
#
#               date_iso
# 0  2018-01-13T00:00:00
# 1  2018-01-12T00:00:00
# 2  2018-01-11T00:00:00
# 3  2018-01-15T00:00:00
# 4  2018-01-14T00:00:00

# %%
# check data types
for column in cleaned_reviews.columns:
    print(str(column) + ': ' +  str(cleaned_reviews[column].dtype))
# Out:
# compensation: int64
# hours: float64
# num_reviews: int64
# product_id: int64
# products: float64
# recommended: int64
# text: object
# final_user_id: int64
# date_iso: object

# %%
cleaned_reviews.head()
# Out:
#    compensation  hours  num_reviews  product_id  products  recommended  \
# 0             0    0.0           35      642803     468.0            1
# 1             0    0.0            6      760610     888.0            1
# 2             0    0.0           37      760610     213.0            1
# 3             0    0.0            8      779280     164.0            1
# 4             0    0.0           94      779280     304.0            1
#
#                                                 text      final_user_id  \
# 0  Okay, get thisyou can open the cab's side door...  76561198067019938
# 1  Bought for the pure respect of the original pr...  76561197999899413
# 2  One of my favorite pages is 23 1920.pngThey ar...  76561198151921721
# 3                             i have found my queen.  76561198141277447
# 4                    Should be called: The Flat Pack  76561198067653526
#
#               date_iso
# 0  2018-01-13T00:00:00
# 1  2018-01-12T00:00:00
# 2  2018-01-11T00:00:00
# 3  2018-01-15T00:00:00
# 4  2018-01-14T00:00:00

# %%
cleaned_reviews.to_csv('reviews_cleaned.csv')

# %% [markdown]
# # Cleaning game data

# %%
games_raw = pd.read_json('raw_data/games_all.json')

# %%
print(len(games_raw))
games_raw.head()
# Out:
# 32645
#                          app_name  \
# 0               The Hardest Thing
# 1                  Serious Office
# 2                        OVERVIEW
# 3      Global Soccer Manager 2017
# 4  Full Metal Furies - Soundtrack
#
#                                          description  \
# 0  [, About This Game, Do you love puzzles? What ...
# 1  [, About This Game, , Dear Bob,, I know you kn...
# 2  [, About This Game, OVERVIEW is a 30 minutes n...
# 3  [, About This Game, In Global Soccer Manager 2...
# 4  [, About This Content, Loved the game?  Then w...
#
#                                         developer  discount_price  \
# 0                                        ChillFun             NaN
# 1                                           NOS3D             NaN
# 2                                             NaN             NaN
# 3  gsmpcgame,globalsoccermanager,Andrea Hochstein             NaN
# 4                              A Shell in the Pit             NaN
#
#    early_access                                             genres        id  \
# 0         False                                         [Strategy]  773510.0
# 1          True  [Action, Casual, Indie, Massively Multiplayer,...  776170.0
# 2         False                                                NaN  751110.0
# 3         False      [Casual, Indie, Simulation, Sports, Strategy]  625700.0
# 4         False                    [Action, Adventure, Indie, RPG]  788060.0
#
#   metascore        parent_game                            parent_game_url  \
# 0       NaN                NaN                                        NaN
# 1       NaN                NaN                                        NaN
# 2       NaN                NaN                                        NaN
# 3       NaN                NaN                                        NaN
# 4       NaN  Full Metal Furies  http://store.steampowered.com/app/416600/
#
#    price          publisher release_date  \
# 0  14.99           ChillFun   2018-01-17
# 1    NaN              NOS3D     Jan 2018
# 2    NaN                NaN          NaN
# 3   9.99          gsmpcgame   2017-05-24
# 4   7.99  Cellar Door Games   2018-01-17
#
#                                          reviews_url sentiment  \
# 0  http://steamcommunity.com/app/773510/reviews/?...       NaN
# 1  http://steamcommunity.com/app/776170/reviews/?...       NaN
# 2  http://steamcommunity.com/app/751110/reviews/?...       NaN
# 3  http://steamcommunity.com/app/625700/reviews/?...  Positive
# 4  http://steamcommunity.com/app/788060/reviews/?...       NaN
#
#                                                specs  \
# 0  [Single-player, Partial Controller Support, St...
# 1  [Multi-player, Online Multi-Player, Partial Co...
# 2  [Single-player, HTC Vive, Oculus Rift, Tracked...
# 3  [Single-player, Steam Achievements, Steam Trad...
# 4  [Single-player, Co-op, Online Co-op, Local Co-...
#
#                                                 tags  \
# 0  [Strategy, Cartoon, Puzzle, First-Person, Phys...
# 1  [Early Access, Strategy, Action, Massively Mul...
# 2                    [Adventure, Casual, Simulation]
# 3  [Sports, Strategy, Simulation, Indie, Casual, ...
# 4                    [Action, Adventure, RPG, Indie]
#
#                             title  \
# 0               The Hardest Thing
# 1                  Serious Office
# 2                             NaN
# 3      Global Soccer Manager 2017
# 4  Full Metal Furies - Soundtrack
#
#                                                  url
# 0  http://store.steampowered.com/app/773510/The_H...
# 1  http://store.steampowered.com/app/776170/Serio...
# 2  http://store.steampowered.com/app/751110/OVERV...
# 3  http://store.steampowered.com/app/625700/Globa...
# 4  http://store.steampowered.com/app/788060/Full_...

# %%
game_specs
# Out:
# {'Captions available': 0,
#  'Co-op': 0,
#  'Commentary available': 0,
#  'Cross-Platform Multiplayer': 0,
#  'Downloadable Content': 0,
#  'Full controller support': 0,
#  'Game demo': 0,
#  'Gamepad': 0,
#  'HTC Vive': 0,
#  'In-App Purchases': 0,
#  'Includes Source SDK': 0,
#  'Includes level editor': 0,
#  'Keyboard / Mouse': 0,
#  'Local Co-op': 0,
#  'Local Multi-Player': 0,
#  'MMO': 0,
#  'Mods': 0,
#  'Mods (require HL1)': 0,
#  'Mods (require HL2)': 0,
#  'Multi-player': 0,
#  'Oculus Rift': 0,
#  'Online Co-op': 0,
#  'Online Multi-Player': 0,
#  'Partial Controller Support': 0,
#  'Room-Scale': 0,
#  'Seated': 0,
#  'Shared/Split Screen': 0,
#  'Single-player': 0,
#  'Standing': 0,
#  'Stats': 0,
#  'Steam Achievements': 0,
#  'Steam Cloud': 0,
#  'Steam Leaderboards': 0,
#  'Steam Trading Cards': 0,
#  'Steam Turn Notifications': 0,
#  'Steam Workshop': 0,
#  'SteamVR Collectibles': 0,
#  'Tracked Motion Controllers': 0,
#  'Valve Anti-Cheat enabled': 0,
#  'Windows Mixed Reality': 0}

# %%
game_specs = {}
game_specs_count = {}
#unpack dlc tags and put it in dictionary
def unpack_specs(row):
    """This function unpacks the list of genres and stores it into a dictionary"""
    specs = row['specs']
    #print(tags)
    try:
        for i in range(len(specs)):
            if specs[i] not in game_specs:
                game_specs[specs[i]] = 0
                game_specs_count[specs[i]] = 0
            else:
                game_specs_count[specs[i]] += 1
    except:
        pass

games_raw.apply(unpack_specs, axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
#          ...
# 32615    None
# 32616    None
# 32617    None
# 32618    None
# 32619    None
# 32620    None
# 32621    None
# 32622    None
# 32623    None
# 32624    None
# 32625    None
# 32626    None
# 32627    None
# 32628    None
# 32629    None
# 32630    None
# 32631    None
# 32632    None
# 32633    None
# 32634    None
# 32635    None
# 32636    None
# 32637    None
# 32638    None
# 32639    None
# 32640    None
# 32641    None
# 32642    None
# 32643    None
# 32644    None
# Length: 32645, dtype: object

# %%
# save dictionaries as csv
(pd.DataFrame.from_dict(data=game_specs_count, orient='index').
to_csv('game_specs_count.csv', header=True))

(pd.DataFrame.from_dict(data=game_specs, orient='index').
to_csv('game_specs.csv', header=True))

# %%
game_tags = {}
game_tags_count = {}
#unpack dlc tags and put it in dictionary
def unpack_tags(row):
    """This function unpacks the list of genres and stores it into a dictionary"""
    tags = row['tags']
    #print(tags)
    try:
        for i in range(len(tags)):
            if tags[i] not in game_tags:
                game_tags[tags[i]] = 0
                game_tags_count[tags[i]] = 0
            else:
                game_tags_count[tags[i]] += 1
    except:
        pass

games_raw.apply(unpack_tags, axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
#          ...
# 32615    None
# 32616    None
# 32617    None
# 32618    None
# 32619    None
# 32620    None
# 32621    None
# 32622    None
# 32623    None
# 32624    None
# 32625    None
# 32626    None
# 32627    None
# 32628    None
# 32629    None
# 32630    None
# 32631    None
# 32632    None
# 32633    None
# 32634    None
# 32635    None
# 32636    None
# 32637    None
# 32638    None
# 32639    None
# 32640    None
# 32641    None
# 32642    None
# 32643    None
# 32644    None
# Length: 32645, dtype: object

# %%
# save dictionaries as csv
(pd.DataFrame.from_dict(data=game_tags_count, orient='index').
to_csv('game_tags_count.csv', header=True))

(pd.DataFrame.from_dict(data=game_tags, orient='index').
to_csv('game_tags.csv', header=True))

# %%
game_genres = {}
game_genres_count = {}
#unpack dlc genre and put it in dictionary
def unpack_genre(row):
    """This function unpacks the list of genres and stores it into a dictionary"""
    genres = row['genres']
    #print(genres)
    try:
        for i in range(len(genres)):
            if genres[i] not in game_genres:
                game_genres[genres[i]] = 0
                game_genres_count[genres[i]] = 0
            else:
                game_genres_count[genres[i]] += 1
    except:
        pass

games_raw.apply(unpack_genre, axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
#          ...
# 32615    None
# 32616    None
# 32617    None
# 32618    None
# 32619    None
# 32620    None
# 32621    None
# 32622    None
# 32623    None
# 32624    None
# 32625    None
# 32626    None
# 32627    None
# 32628    None
# 32629    None
# 32630    None
# 32631    None
# 32632    None
# 32633    None
# 32634    None
# 32635    None
# 32636    None
# 32637    None
# 32638    None
# 32639    None
# 32640    None
# 32641    None
# 32642    None
# 32643    None
# 32644    None
# Length: 32645, dtype: object

# %%
# save dictionaries as csv
(pd.DataFrame.from_dict(data=game_genres_count, orient='index').
to_csv('game_genres_count.csv', header=True))

(pd.DataFrame.from_dict(data=game_genres, orient='index').
to_csv('game_genres.csv', header=True))

# %%
cleaned_games = games_raw

# %%
# check data types
def check_df(df):    
    for column in cleaned_games.columns:
        if np.any(pd.isnull(cleaned_games[column])) == True:
            print(str(column) + ': ' +  str(cleaned_games[column].dtype) + "    (has NaN)")
        else:
            print(str(column) + ': ' +  str(cleaned_games[column].dtype))

# %%
check_df(cleaned_games)
# Out:
# description: object    (has NaN)
# developer: object    (has NaN)
# genres: object    (has NaN)
# id: float64    (has NaN)
# parent_game: object    (has NaN)
# parent_game_url: object    (has NaN)
# price: object    (has NaN)
# publisher: object    (has NaN)
# release_date: object    (has NaN)
# sentiment: object    (has NaN)
# specs: object    (has NaN)
# tags: object    (has NaN)
# title: object    (has NaN)

# %%
cleaned_games = cleaned_games.drop(columns=['app_name', 'discount_price', 'metascore', 'reviews_url', 'url', 'early_access'])

# %%
cleaned_games.head()
# Out:
#                                          description  \
# 0  [, About This Game, Do you love puzzles? What ...
# 1  [, About This Game, , Dear Bob,, I know you kn...
# 2  [, About This Game, OVERVIEW is a 30 minutes n...
# 3  [, About This Game, In Global Soccer Manager 2...
# 4  [, About This Content, Loved the game?  Then w...
#
#                                         developer  \
# 0                                        ChillFun
# 1                                           NOS3D
# 2                                             NaN
# 3  gsmpcgame,globalsoccermanager,Andrea Hochstein
# 4                              A Shell in the Pit
#
#                                               genres        id  \
# 0                                         [Strategy]  773510.0
# 1  [Action, Casual, Indie, Massively Multiplayer,...  776170.0
# 2                                                NaN  751110.0
# 3      [Casual, Indie, Simulation, Sports, Strategy]  625700.0
# 4                    [Action, Adventure, Indie, RPG]  788060.0
#
#          parent_game                            parent_game_url  price  \
# 0                NaN                                        NaN  14.99
# 1                NaN                                        NaN    NaN
# 2                NaN                                        NaN    NaN
# 3                NaN                                        NaN   9.99
# 4  Full Metal Furies  http://store.steampowered.com/app/416600/   7.99
#
#            publisher release_date sentiment  \
# 0           ChillFun   2018-01-17       NaN
# 1              NOS3D     Jan 2018       NaN
# 2                NaN          NaN       NaN
# 3          gsmpcgame   2017-05-24  Positive
# 4  Cellar Door Games   2018-01-17       NaN
#
#                                                specs  \
# 0  [Single-player, Partial Controller Support, St...
# 1  [Multi-player, Online Multi-Player, Partial Co...
# 2  [Single-player, HTC Vive, Oculus Rift, Tracked...
# 3  [Single-player, Steam Achievements, Steam Trad...
# 4  [Single-player, Co-op, Online Co-op, Local Co-...
#
#                                                 tags  \
# 0  [Strategy, Cartoon, Puzzle, First-Person, Phys...
# 1  [Early Access, Strategy, Action, Massively Mul...
# 2                    [Adventure, Casual, Simulation]
# 3  [Sports, Strategy, Simulation, Indie, Casual, ...
# 4                    [Action, Adventure, RPG, Indie]
#
#                             title
# 0               The Hardest Thing
# 1                  Serious Office
# 2                             NaN
# 3      Global Soccer Manager 2017
# 4  Full Metal Furies - Soundtrack

# %%
# inspect missing publisher / developer

# Create variable with TRUE if publisher is missing
missing_pub = pd.isnull(cleaned_games['publisher']) == True
# Create variable with TRUE if developer is missing
missing_dev = pd.isnull(cleaned_games['developer']) == True
# Create variable with False if parent game is missing (i.e. True if parent game exists, thus is a DLC)
existing_parent = pd.isnull(cleaned_games['parent_game_url']) == False

# Drop rows where all three fields are missing
#no_pub_dev_parent = cleaned_dlcs[missing_pub & missing_dev & missing_parent]
#print(len(no_pub_dev_parent))
#cleaned_dlcs.drop(no_pub_dev_parent.index, inplace=True)

# Drop rows where parent game exists because this is a DLC
exist_parent = cleaned_games[existing_parent]
print(len(exist_parent))
cleaned_games.drop(exist_parent.index, inplace=True)
# Out:
# 12680

# %%
print(len(cleaned_games))
# Out:
# 19965

# %% [markdown]
# #### Original scraper choked on games with VR info because the html structure is different for these games
#
# - need to re-scrape these games for info

# %%
need_more_info = cleaned_games[missing_pub & missing_dev]
#need_more_info.tail()
# Out:
# /Users/hyunjoohwang/anaconda3/envs/insight/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
x = 'Jan 2018'
def standardize_date(x):
    from datetime import datetime, date
    
    try:
        if datetime.strptime(x, '%Y-%m-%d'):
            return x
    except:
        for fmt in ["%b %d, %Y", "%B %d, %Y"]:
            try:
                return datetime.strptime(x, fmt).strftime("%Y-%m-%d")
            except:
                fmt_fail = True

        for fmt in ["%b %Y", "%B %Y"]:
            try:
                d = datetime.strptime(x, fmt)
                d = d.replace(day=1)
                return d.strftime("%Y-%m-%d")
            except:
                fmt_fail = True
        
print(standardize_date(x))
# Out:
# 2018-01-01

# %%
# set up beautiful soup to scrape info for these 3k games
# title, developer, genres, parent game, publisher, release_date, sentiment
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import re

info = pd.DataFrame(index=need_more_info.index, columns=['title','genres','developer','publisher','release_date'])
def scrape_game_info(row):
    print(row.name)
    url = "http://store.steampowered.com/app/{}".format(row['id'])
#     url = 'http://store.steampowered.com/app/251810/Leadwerks_Game_Engine/'
    page = urlopen(url) 
    soup = BeautifulSoup(page,'lxml') # scrape page
    details = soup.findAll("div", {"class": "details_block"}) # fetch details block div

    import collections
    def flatten(l):
        for el in l:
            if isinstance(el, collections.Iterable) and not isinstance(el, (str, bytes)):
                yield from flatten(el)
            else:
                yield el

    #print(details)
    for item in details:
        title = re.findall("Title:\<\/b\>\s+([\w+\s+\w+]+)\<br", str(item))
        #print(title)
        #import pdb; pdb.set_trace()
        if title:
            detail = item.get_text().split('<br/>')
            #print(detail)

            items = item.get_text().split('\n')
            items2 = list(flatten([item.split(':') for item in items]))
            items2 = [x for x in items2 if x]
            #print(items2)

            for prop, name in [
                ('Title', 'title'),
                ('Genre', 'genres'),
                ('Developer', 'developer'),
                ('Publisher', 'publisher'),
                ('Release Date', 'release_date')
            ]:
                #print(prop,name)
                try:
                    foundIndex = items2.index(prop)
                    if prop == 'Genre':
                        value = items2[foundIndex+1].strip().split(',')
                        info.loc[row.name,'genres'] = value
                        print('genre: ' + str(value))
                    elif prop == 'Release Date':
                        value = standardize_date(items2[foundIndex+1].strip())
                        info.loc[row.name,'release_date'] = value
                        print(value)
                    else:
                        value = items2[foundIndex+1].strip()
                        info.loc[row.name,name] = value
                        print(value)
                except:
                    pass

# %%
cleaned_games[missing_pub & missing_dev].apply(scrape_game_info, axis=1)
# Out:
# /Users/hyunjoohwang/anaconda3/envs/insight/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 2
# OVERVIEW
# genre: ['Adventure', ' Casual', ' Simulation']
# Orbital Views
# Orbital Views
# 2018-01-01
# 33
# 35
# Second Nature
# 2017-09-18
# 56
# The Iron Lady
# 2012-04-10
# 57
# LIV Client
# genre: ['Utilities', ' Video Production', ' Web Publishing']
# LIV Inc
# LIV Inc
# 2018-01-01
# 70
# Awakening
# genre: ['Animation & Modeling', ' Design & Illustration', ' Utilities']
# AwingSoft
# AwingSoft
# 2017-08-15
# 78
# Mech League Boxing
# genre: ['Action', ' Simulation', ' Sports']
# VRGEN
# VRGEN
# 2018-01-10
# 109
# The Defector
# 2018-01-06
# 111
# 347
# 1439
# War Thunder
# genre: ['Action', ' Free to Play', ' Massively Multiplayer', ' Simulation']
# Gaijin Entertainment
# Gaijin Entertainment
# 2013-08-15
# 1474
# 1480
# Legend of Dungeon
# genre: ['Action', ' Indie', ' RPG']
# Robot Loves Kitty
# 2013-09-13
# 1576
# 1615
# 1616
# 1631
# 1638
# 1639
# 1692
# Leadwerks Game Engine
# genre: ['Animation & Modeling', ' Design & Illustration', ' Education', ' Software Training', ' Utilities']
# Leadwerks Software
# Leadwerks Software
# 2014-01-06
# 1700
# 1701
# 1702
# 1703
# 2265
# Infinity Runner
# genre: ['Action', ' Indie']
# Wales Interactive
# Wales Interactive
# 2014-07-14
# 2362
# 2410
# NoLimits 2 Roller Coaster Simulation
# genre: ['Indie', ' Simulation']
# Ole Lange
# Mad Data GmbH & Co. KG
# 2014-08-21
# 2707
# 2883
# Volo Airsport
# genre: ['Action', ' Indie', ' Simulation', ' Sports', ' Early Access']
# Ramjet Anvil
# Ramjet Anvil
# 2014-12-04
# 2928
# Subnautica
# genre: ['Adventure', ' Indie', ' Early Access']
# Unknown Worlds Entertainment
# Unknown Worlds Entertainment
# 2018-01-23
# 3017
# Motorbike
# genre: ['Action', ' Casual', ' Indie', ' Racing', ' Simulation', ' Sports']
# baKno Games
# baKno Games
# 2011-05-09
# 3185
# The Art of Playing
# 2015-02-10
# 3249
# 3353
# 3365
# Project CARS
# genre: ['Racing', ' Simulation', ' Sports']
# Slightly Mad Studios
# Slightly Mad Studios, BANDAI NAMCO Entertainment
# 2015-03-15
# 3399
# 3421
# Why We Ride
# 2015-03-27
# 3518
# 3531
# Ogrest
# 2015-04-23
# 3547
# 3656
# 3726
# Forge Quest
# genre: ['Action', ' Adventure', ' Indie', ' RPG']
# 2015-05-22
# 3739
# RaidersSphere4th
# genre: ['Action', ' Indie', ' Simulation']
# Rectangle
# Sekai Project
# 2013-12-31
# 3772
# Tabletop Simulator
# genre: ['Casual', ' Indie', ' RPG', ' Simulation', ' Strategy']
# Berserk Games
# Berserk Games
# 2015-06-05
# 3867
# Austin High
# 2012-04-20
# 3870
# Gaming In Color
# 2015-03-10
# 3902
# Coffin Dodgers
# genre: ['Action', ' Casual', ' Indie', ' Racing']
# Milky Tea Studios
# Milky Tea Studios
# 2015-07-08
# 3906
# 3910
# Men With Beards
# 2013-11-01
# 3923
# How We Got Away With It
# 2014-03-24
# 3928
# One Couch at a Time
# 2013-09-07
# 3953
# 3954
# 3993
# The Golden Scallop
# 2014-05-01
# 3995
# Cancerpants
# 2013-03-10
# 3996
# 3998
# FARAWAY
# 2014-11-25
# 4020
# 4030
# 4036
# 4047
# Bound By Sea
# 2014-10-01
# 4051
# THE WORST YEAR OF MY LIFE
# 2014-01-13
# 4063
# Stripped
# 2015-08-06
# 4156
# 4244
# Tinertia
# genre: ['Action', ' Indie']
# Candescent Games
# Candescent & Section
# 2015-09-03
# 4250
# InCell VR
# genre: ['Free to Play', ' Indie', ' Racing', ' Strategy']
# Luden.io
# Nival
# 2015-09-03
# 4435
# Sayonara Umihara Kawase
# genre: ['Action', ' Indie']
# Studio Saizensen
# Degica
# 2015-10-06
# 4445
# Keep Talking and Nobody Explodes
# genre: ['Indie']
# Steel Crate Games
# Steel Crate Games
# 2015-10-08
# 4511
# 4531
# All Work All Play
# 2015-10-23
# 4550
# 4560
# 4565
# 4566
# 4567
# 4626
# Over the Dream
# 2015-11-06
# 4651
# Alienware Steam Machine
# 2015-11-10
# 4652
# Steam Controller
# 2015-11-10
# 4700
# 4789
# Celestrion
# genre: ['Simulation']
# dSky9, Inc.
# dSky9, Inc.
# 2015-12-07
# 4799
# 4829
# Emily Wants To Play
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' Simulation', ' Strategy']
# Shawn Hitchcock
# SKH Apps
# 2015-12-10
# 4842
# 4929
# 4974
# 5002
# 3 Suicides of Paul Hamilton
# 2015-11-11
# 5010
# 5014
# Everything is Grey
# 2016-01-21
# 5066
# 101 Secrets
# 2015-05-05
# 5084
# 5113
# 5199
# Forest Ground Tiling Texture Tutorial
# 2016-02-22
# 5244
# SOLRAVEN
# genre: ['Free to Play', ' Indie', ' Simulation']
# Inception Soft
# Inception Soft
# 2016-03-01
# 5276
# 5278
# Back to Dinosaur Island Part 2
# genre: ['Simulation']
# Crytek
# Crytek
# 2016-03-10
# 5280
# 5319
# 5324
# Game Changers
# 2016-03-18
# 5375
# Dead Secret
# genre: ['Adventure', ' Indie']
# Robot Invader
# Robot Invader
# 2016-03-28
# 5378
# 5399
# Minigolf VR
# genre: ['Casual', ' Indie', ' Sports', ' Early Access']
# Virtualex
# Virtualex
# 2016-04-05
# 5401
# The Visitor
# genre: ['Casual', ' Indie']
# Stephen Long
# Stephen Long
# 2016-04-01
# 5406
# 5414
# 5415
# 5416
# 5419
# Apollo 11 VR
# genre: ['Adventure', ' Simulation']
# Immersive VR Education Ltd.
# Immersive VR Education Ltd.
# 2016-04-01
# 5420
# 5425
# SculptrVR
# genre: ['Indie']
# Nathan Rowe
# SculptrVR
# 2016-04-04
# 5426
# 5428
# 5429
# 5430
# 5431
# Ruckus Ridge VR Party
# genre: ['Action', ' Indie']
# Foreignvr
# Foreignvr
# 2016-04-05
# 5432
# Proton Pulse
# genre: ['Indie']
# Justin Moravetz
# ZeroTransform
# 2016-04-05
# 5433
# Beach Ball Valley
# genre: ['Casual', ' Simulation', ' Sports', ' Early Access']
# Paul Eckhardt
# 2016-04-05
# 5437
# Windlands
# genre: ['Adventure', ' Indie']
# Psytec Games Ltd
# Psytec Games Ltd
# 2016-04-05
# 5439
# The Lab
# genre: ['Free to Play']
# Valve
# Valve
# 2016-04-05
# 5440
# 5441
# Tilt Brush
# genre: ['Design & Illustration']
# Google
# Google
# 2016-04-05
# 5442
# 5443
# Holodance
# genre: ['Casual', ' Indie', ' Sports', ' Early Access']
# narayana games UG
# narayana games UG
# 2016-04-05
# 5444
# 5454
# XLR
# genre: ['Action', ' Indie', ' Simulation', ' Strategy', ' Early Access']
# Metaware Limited, LLC
# Metaware Limited, LLC
# 2016-04-05
# 5472
# Chunks
# genre: ['Indie', ' Simulation', ' Early Access']
# Facepunch Studios
# Facepunch Studios
# 2016-04-11
# 5474
# Dawn of the Robot Empire
# genre: ['Action', ' Indie', ' Early Access']
# oeFun, Inc.
# oeFun, Inc.
# 2016-04-11
# 5476
# 5508
# Paintey
# genre: ['Indie', ' Simulation', ' Early Access']
# Brian Lindenhof
# ShadowBrain Games
# 2016-04-18
# 5513
# Sisters
# genre: ['Adventure', ' Indie']
# Otherworld Interactive
# Otherworld Interactive
# None
# 5514
# Poly Runner VR
# genre: ['Casual', ' Indie']
# Lucid Sight, Inc.
# Lucid Sight, Inc.
# 2016-04-18
# 5518
# Andromedum
# genre: ['Casual', ' Indie']
# Imbanova Entertainment Inc.
# Imbanova Entertainment Inc.
# 2016-04-15
# 5527
# Sweet Escape VR
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' Massively Multiplayer', ' Racing', ' Simulation', ' Sports', ' Early Access']
# Monster VR
# Monster VR
# 2016-04-20
# 5530
# 5540
# Colosse
# genre: ['Adventure']
# Colosse Team
# Fire Panda Ltd.
# 2016-04-20
# 5551
# Heaven Island Life
# genre: ['Indie', ' Simulation']
# Fabio Ferrara
# Chubby Pixel
# 2016-04-20
# 5582
# 5585
# Natural Born Pranksters
# 2015-04-01
# 5587
# Deck the Halls
# 2011-12-20
# 5589
# 5590
# Warm Bodies
# 2013-02-01
# 5591
# Leprechaun
# 1993-04-07
# 5593
# Killer Joe
# 2012-07-27
# 5594
# 5595
# Sex Drive
# 2008-10-17
# 5598
# Gamer
# 2009-09-04
# 5599
# Meatballs
# 2003-06-24
# 5600
# Apocalypse Now Redux
# 2010-05-18
# 5602
# Hostel
# 2006-04-18
# 5603
# Raw Deal
# 1998-06-22
# 5604
# 5605
# 5606
# Waiting
# 2006-02-07
# 5607
# Cyborg 2
# 1993-11-24
# 5608
# Requiem for a Dream
# 2001-05-22
# 5609
# 5610
# Scary Movie 2
# 2001-12-18
# 5611
# 5612
# See No Evil 2
# 2014-10-21
# 5613
# Scary Movie 3
# 2004-05-11
# 5614
# The Possession
# 2013-01-15
# 5615
# School Dance
# 2014-07-02
# 5616
# Warrior
# 2011-09-09
# 5617
# 5654
# 5677
# iOMoon
# genre: ['Action', ' Adventure', ' Indie', ' Simulation', ' Early Access']
# Headtrip Games llc
# Headtrip Games llc
# 2016-04-27
# 5680
# Bigscreen Beta
# genre: ['Simulation']
# Bigscreen, Inc.
# Bigscreen, Inc.
# 2016-04-28
# 5689
# 5697
# IS Defense Editor
# 2016-04-29
# 5699
# Stealth Labyrinth
# genre: ['Action', ' Indie']
# Reddoll Srl
# IV Production
# 2016-04-29
# 5703
# PaintLab
# genre: ['Animation & Modeling', ' Design & Illustration']
# LAB4242
# LAB4242
# 2016-04-29
# 5723
# Omega Agent
# genre: ['Action', ' Indie']
# Fireproof Games
# Fireproof Games
# 2016-05-04
# 5740
# Mind Unleashed
# genre: ['Action', ' Indie']
# Frost Earth
# IV Productions
# 2016-05-05
# 5744
# Ultimate Avengers 2
# 2006-08-08
# 5746
# Ultimate Avengers
# 2006-02-21
# 5747
# The Invincible Iron Man
# 2007-01-23
# 5752
# VIRTUAnimator
# genre: ['Animation & Modeling', ' Early Access']
# Pheonise
# Pheonise
# 2016-05-09
# 5753
# Orc Assault
# genre: ['Indie', ' RPG', ' Strategy']
# Ghost Machine
# Ghost Machine
# 2016-05-10
# 5766
# Gravity Compass
# genre: ['Casual']
# NovaWake Studios
# NovaWake Studios
# 2016-05-07
# 5775
# 5780
# Source Code
# 2011-07-26
# 5781
# 5782
# Sling Blade
# 1998-01-06
# 5783
# 5784
# The Way of the Gun
# 2001-01-02
# 5785
# Supercop
# 1998-04-21
# 5786
# The Punisher
# 2004-09-07
# 5787
# The Cold Light of Day
# 2013-01-29
# 5788
# The Perks of Being a Wallflower
# 2013-02-12
# 5789
# 5790
# 5791
# 5795
# 5797
# An American Werewolf in London
# 1985-10-16
# 5805
# Ad Exitum
# genre: ['Action', ' Indie']
# Since Idea Games
# Since Idea Games
# 2016-05-13
# 5813
# Incident at Loch Ness
# 2004-09-17
# 5823
# Disney Movies VR
# genre: ['Utilities']
# Walt Disney Studios
# Disney Interactive
# 2016-05-16
# 5828
# 5830
# Sketchfab VR
# genre: ['Adventure']
# Sketchfab
# Sketchfab
# 2016-05-13
# 5831
# Dolphin Defense
# genre: ['Action', ' Adventure', ' Indie']
# Tanner Thayer
# Tanner Thayer
# 2016-05-16
# 5844
# Gods of Egypt
# 2016-05-17
# 5853
# 5864
# 5887
# Time Machine VR
# genre: ['Adventure', ' Indie', ' Simulation']
# Minority Media Inc.
# Minority Media Inc.
# 2016-05-19
# 5889
# Canis Belli
# 2016-03-11
# 5900
# Holodaze
# genre: ['Action', ' Casual', ' Indie']
# Sysdia Games
# Sysdia Games
# 2016-05-19
# 5907
# bloxyz
# genre: ['Casual', ' Indie']
# Svution
# Svution
# 2016-05-19
# 5910
# VR Karts SteamVR
# genre: ['Casual', ' Indie', ' Racing']
# Viewpoint Games
# Viewpoint Games
# 2016-05-20
# 5915
# Please Hold
# 2016-04-05
# 5916
# 5932
# Surge
# genre: ['Indie']
# House of Secrets
# House of Secrets
# 2016-05-19
# 5949
# vrAMP
# genre: ['Casual', ' Indie', ' Early Access']
# Oriku Inc
# Oriku Inc
# 2016-05-27
# 5964
# Leave The Nest
# genre: ['Action', ' Casual', ' Indie']
# Kaio Interactive
# Kaio Interactive
# 2016-05-27
# 5970
# 5971
# Waltz of the Wizard
# genre: ['Adventure', ' Indie', ' Simulation']
# Aldin Dynamics
# Aldin Dynamics
# 2016-05-31
# 5980
# Lightblade VR
# genre: ['Action', ' Indie', ' Simulation']
# Andreas Hager Gaming
# Andreas Hager Gaming
# 2016-05-31
# 5988
# Sports Bar VR
# genre: ['Casual', ' Indie', ' Simulation', ' Sports', ' Strategy']
# Cherry Pop Games
# Perilous Orbit
# 2016-06-01
# 6040
# 6042
# Turbo Kid
# 2015-08-28
# 6046
# Facing Ali
# 2009-12-29
# 6048
# See No Evil
# 2006-11-28
# 6054
# 6067
# 6086
# 6110
# Dogfight Elite
# genre: ['Action', ' Indie', ' Massively Multiplayer', ' Simulation', ' Strategy', ' Early Access']
# Echoboom S.L.
# Echoboom S.L.
# 2016-06-11
# 6115
# Octoshield VR
# genre: ['Action', ' Indie', ' Simulation', ' Sports', ' Early Access']
# Potato Games
# Potato Games
# 2016-06-15
# 6143
# 6165
# 6166
# WITHIN
# genre: ['Utilities']
# Within Unlimited, Inc.
# Within Unlimited, Inc.
# 2016-06-16
# 6181
# 6188
# Annie Amber
# genre: ['Adventure', ' Casual', ' Indie']
# Pantumaca Barcelona
# Talking About Media
# 2016-06-17
# 6199
# Hoops VR
# genre: ['Simulation', ' Sports']
# Wizard Games Inc
# Wizard Games Inc
# 2016-06-20
# 6202
# Astroderps
# genre: ['Casual', ' Indie', ' Strategy']
# Chronos VR
# Chronos VR
# 2016-06-17
# 6214
# L U N E
# genre: ['Casual', ' Indie', ' Simulation']
# Isaac Cohen
# Isaac Cohen
# 2016-06-20
# 6226
# QuiVr
# genre: ['Action', ' Casual', ' Indie', ' Simulation', ' Early Access']
# Blueteak
# Alvios, Inc.
# 2016-12-19
# 6227
# 6233
# 6237
# Bowl VR
# genre: ['Casual', ' Simulation', ' Sports']
# Carbon Fiber Games
# Carbon Fiber Games
# 2016-06-24
# 6246
# VirZOOM Arcade
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' Racing', ' Sports']
# VirZOOM
# VirZOOM
# 2016-06-30
# 6249
# Klepto
# genre: ['Action', ' Indie', ' Simulation', ' Early Access']
# Meerkat Gaming
# Meerkat Gaming
# 2016-06-30
# 6258
# 6261
# Rumpus
# genre: ['Animation & Modeling', ' Audio Production', ' Design & Illustration', ' Education', ' Early Access']
# Luke Iannini
# Luke Iannini
# 2016-07-04
# 6283
# Car Car Crash Hands On Edition
# genre: ['Action', ' Casual', ' Indie', ' Early Access']
# Chocolatefudge Games
# Chocolatefudge Games
# 2016-07-04
# 6284
# Ghost Train VR
# genre: ['Casual', ' Indie']
# JDMSoftware
# JDMSoftware
# 2016-07-05
# 6293
# Waddle Home
# genre: ['Casual', ' Indie', ' Strategy']
# Archiact
# Archiact Interactive Ltd.
# 2016-07-07
# 6301
# DUO
# genre: ['Action', ' Casual', ' Indie', ' Sports']
# NiVision
# NiVision
# 2016-07-08
# 6305
# 6310
# Slam
# genre: ['Casual', ' Indie', ' Strategy']
# Aera Studios
# Aera Studios
# 2016-07-11
# 6311
# VR Boxing Workout
# genre: ['Simulation', ' Sports']
# Wenkly Studio Sp. z o.o.
# Wenkly Studio Sp. z o.o.
# 2016-07-10
# 6356
# Ultimate Booster Experience
# genre: ['Action', ' Adventure', ' Casual', ' Simulation']
# GexagonVR
# GexagonVR
# 2016-04-16
# 6361
# Dashy Square VR
# genre: ['Action', ' Indie']
# Kastriot Sulejmani
# Kastriot Sulejmani
# 2016-07-14
# 6372
# Trials on Tatooine
# genre: ['Action']
# ILMxLAB
# ILMxLAB
# 2016-07-18
# 6391
# The Assembly
# genre: ['Adventure', ' Indie']
# nDreams
# nDreams
# 2016-07-19
# 6403
# My Own Pet
# genre: ['Casual', ' Indie', ' Simulation', ' Early Access']
# JDMSoftware
# JDMSoftware
# 2016-07-19
# 6407
# Emergence Fractal Multiverse ᵠ
# genre: ['Education', ' Early Access']
# 17th Dimension
# 2016-07-17
# 6409
# 6410
# 6420
# The Wicker Man
# 1999-11-30
# 6421
# Copter and Sky
# genre: ['Action', ' Casual', ' Indie', ' Simulation']
# Kopnin Pavel
# Fly Dream Dev
# 2016-07-25
# 6435
# Puzzle Blocks
# genre: ['Adventure', ' Casual', ' Indie', ' Early Access']
# Ayy Caramba Games
# Ayy Caramba Games
# 2016-07-22
# 6438
# The Anchorite
# 2016-04-01
# 6439
# American Hostage
# 2016-05-06
# 6440
# Queen of Spades
# 2016-06-10
# 6442
# 6450
# Brick Stack VR
# genre: ['Casual', ' Indie']
# Andrew French
# Andrew French
# 2016-07-26
# 6451
# BellyBots
# genre: ['Indie', ' Early Access']
# Grumpy Company GmbH
# Grumpy Company GmbH
# 2016-07-26
# 6462
# VR Fractals
# genre: ['Design & Illustration', ' Utilities', ' Video Production']
# Phylliida
# Phylliida
# 2016-07-22
# 6465
# Think Space
# genre: ['Design & Illustration', ' Utilities']
# Funly, LLC
# Funly, LLC
# 2016-07-26
# 6467
# 6469
# The Crystal Nebula
# genre: ['Action', ' Indie']
# Tristan Hodges
# Tristan Hodges
# 2016-07-26
# 6470
# 6486
# Black Hat Cooperative
# genre: ['Action', ' Casual', ' Indie', ' Strategy']
# Team Future LLC
# Team Future LLC
# 2016-07-29
# 6513
# C O S M
# genre: ['Indie', ' Simulation', ' Early Access']
# Dynamoid
# Dynamoid
# 2016-08-03
# 6517
# Konrad the Kitten
# genre: ['Casual', ' Indie', ' Simulation', ' Early Access']
# FusionPlay
# FusionPlay
# 2016-08-05
# 6518
# Abandoned Hospital VR
# genre: ['Adventure', ' Indie']
# munsunghyun
# munsunghyun
# 2016-08-03
# 6520
# HVR Demo
# genre: ['Action', ' Indie', ' Simulation']
# Andre Le
# Andre Le
# 2016-08-04
# 6536
# 6537
# 6538
# 6539
# 6540
# 6541
# 6542
# 6545
# 6547
# 6550
# Wake Up
# genre: ['Adventure', ' Indie']
# Black Cell OG
# Black Cell OG
# 2016-08-09
# 6557
# Meet the Blacks
# 2016-08-02
# 6565
# 6566
# Empire of Assassins
# 2011-07-05
# 6568
# The Crow
# 1998-02-03
# 6569
# Glengarry GlenRoss
# 2009-09-01
# 6570
# More Than a Game
# 2010-02-02
# 6573
# LooWarVR
# genre: ['Action', ' Casual', ' RPG']
# CrystalGame
# CrystalGame
# 2016-08-11
# 6591
# 6592
# 6595
# Meteor Crush VR
# genre: ['Action', ' Indie']
# XIERRA Games
# XIERRA Games
# 2016-08-17
# 6607
# Professor Layton and the Eternal Diva
# 2011-11-08
# 6611
# 6617
# 6618
# Grapply
# genre: ['Racing', ' Early Access']
# Glyphic Productions
# Glyphic Productions
# 6630
# Multiscreens
# genre: ['Utilities', ' Early Access']
# Phylliida
# Phylliida
# 2016-08-17
# 6651
# CyberThreat
# genre: ['Action', ' Indie', ' Early Access']
# Enigmatic
# Enigmatic, Leading Role
# 2016-08-18
# 6657
# Fancy Slingshot VR
# genre: ['Action', ' Casual', ' Simulation']
# 哈视奇科技
# 哈视奇科技
# 2016-08-16
# 6669
# 6671
# Draft Day
# 2014-08-19
# 6673
# Zombie City Defense 2
# genre: ['Action', ' Indie', ' Simulation', ' Strategy']
# Mozg Labs
# Mozg Labs
# 2016-08-19
# 6674
# Now You See Me 2
# 2016-08-23
# 6678
# 6679
# Streamer Simulator
# genre: ['Casual', ' Indie', ' Simulation', ' Strategy']
# 2016-08-23
# 6684
# Imperium
# 2016-11-01
# 6689
# The VR Museum of Fine Art
# genre: ['Casual', ' Free to Play', ' Indie', ' Simulation']
# Finn Sinclair
# Finn Sinclair
# 2016-08-20
# 6691
# 6692
# Duckpocalypse
# genre: ['Action', ' Casual', ' Indie']
# Capitola VR
# Capitola VR
# 2016-08-22
# 6696
# Paddle Up
# genre: ['Indie', ' Sports', ' Early Access']
# Pavel Jamal
# Pavel Jamal
# 2016-08-24
# 6699
# Obduction
# genre: ['Adventure', ' Indie']
# Cyan Inc.
# Cyan Inc.
# 2016-08-24
# 6723
# Tvori
# genre: ['Animation & Modeling', ' Design & Illustration', ' Utilities', ' Video Production', ' Early Access']
# Tvori
# Tvori
# 2016-08-25
# 6726
# Mount Wingsuit
# genre: ['Action', ' Indie', ' Simulation', ' Sports']
# Ninja Whale Studios
# Ninja Whale Studios
# 2016-08-25
# 6732
# Quarterback SNAP
# genre: ['Action', ' Casual', ' Simulation', ' Sports']
# River Studios
# River Studios
# 2016-08-26
# 6737
# 6738
# Evil Robot Traffic Jam HD
# genre: ['Action', ' Casual', ' Indie', ' Strategy']
# Element Games, LLC
# Element Games, LLC
# 2016-08-26
# 6740
# The Enlightened League of Bone Builders and the Osseous Enigma
# genre: ['Adventure', ' Casual', ' Indie', ' Simulation', ' Strategy']
# INVIVO Communications
# INVIVO Communications
# 2016-08-24
# 6748
# Frantic Freighter
# genre: ['Casual', ' Indie', ' Simulation']
# Phr00t's Software
# Phr00t's Software
# 2016-08-29
# 6750
# 6772
# Rail Adventures
# genre: ['Indie', ' Early Access']
# exosyphen studios
# exosyphen studios
# None
# 6776
# Across Flash
# genre: ['Casual', ' Indie', ' Racing']
# Uborm
# Uborm
# 2016-08-31
# 6787
# Antboy
# 2013-01-01
# 6788
# NIGHTSTAR
# genre: ['Action', ' Indie']
# SOLIDMESH
# SOLIDMESH
# 2017-03-07
# 6789
# EDMtv VR
# genre: ['Audio Production', ' Video Production']
# Big Beats & Brimstone
# EDMtv
# 2016-08-25
# 6790
# Artstage
# genre: ['Animation & Modeling', ' Design & Illustration', ' Early Access']
# Soy-software
# Soy-software
# 2016-09-01
# 6804
# Caketomino
# genre: ['Casual', ' Indie']
# Smoketree Studios
# Smoketree Studios
# 2016-09-02
# 6807
# Kubz VR
# genre: ['Casual', ' Indie']
# bibimbapstudio
# bibimbapstudio
# 2016-09-05
# 6819
# 6820
# GE Neuro
# genre: ['Casual', ' Simulation']
# Kite & Lightning
# Kite & Lightning
# 2016-09-05
# 6835
# Ten Little Roosters
# 2014-11-05
# 6836
# Compadres
# 2016-09-06
# 6842
# Temple of the Apsara
# genre: ['Adventure', ' Indie']
# Attraction Studios
# Attraction Studios
# 2016-09-06
# 6843
# 6858
# CloudBound
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' Early Access']
# Silicon Storm
# Silicon Storm
# 2016-09-07
# 6868
# Cockroach VR
# genre: ['Casual', ' Indie']
# TANTANMEN
# TANTANMEN
# 2016-09-08
# 6878
# Final Fleet
# genre: ['Action', ' Adventure', ' Indie', ' Early Access']
# Team2Bit
# Team2Bit
# 2016-09-08
# 6882
# Mars Odyssey
# genre: ['Simulation']
# Steel Wool Studios
# Steel Wool Studios
# 2016-09-08
# 6889
# Raptor Valley
# genre: ['Action', ' Adventure', ' Indie', ' Simulation']
# Andrew Stout
# Andrew Stout
# 2016-09-09
# 6895
# Live In Color
# genre: ['Casual', ' Indie', ' Early Access']
# Atakote Studios
# Atakote Studios
# 2016-09-11
# 6903
# 9Grids VR
# genre: ['Action', ' Casual', ' Indie']
# Klexian
# Ignite VR
# 2016-09-12
# 6915
# We The Voters
# 2016-09-14
# 6916
# Aleph Null
# genre: ['Action', ' Casual', ' Simulation', ' Early Access']
# Aleph=Null
# Aleph=Null
# 2016-08-15
# 6925
# VRNinja
# genre: ['Action', ' Casual', ' Indie', ' Simulation']
# OutOfBounds Software Solutions Inc
# OutOfBounds Software Solutions Inc
# 2016-09-14
# 6927
# Out of Ammo
# genre: ['Action', ' Indie', ' Strategy']
# RocketWerkz
# RocketWerkz
# 2016-09-14
# 6928
# Found
# genre: ['Adventure', ' Casual', ' Free to Play', ' Indie', ' Early Access']
# Priyam Parikh
# FoundVR
# 2016-09-14
# 6950
# 6963
# ShowdownVR
# genre: ['Action']
# Frontseat Studio
# Frontseat Studio
# 2016-09-19
# 6966
# Golf Pro VR
# genre: ['Sports', ' Early Access']
# Marklar
# Marklar
# 2016-09-19
# 6970
# Egg Time
# genre: ['Action', ' Casual', ' Free to Play', ' Indie', ' Sports']
# Bartoš Studio
# Bartoš Studio
# 2016-09-19
# 6971
# 6977
# 6991
# 6992
# 6994
# Garden of Words
# 2013-05-31
# 6995
# Grave of the Fireflies
# 1988-04-16
# 6996
# Children Who Chase Lost Voices
# 2011-05-07
# 6997
# 6998
# 6999
# 7000
# 7001
# 7003
# 7006
# 7016
# Awesome Obstacle Challenge
# genre: ['Action', ' Indie', ' Racing', ' Sports', ' Early Access']
# VRoximity LLC
# VRoximity LLC
# 2016-09-22
# 7018
# Colorful the Movie
# 2010-08-21
# 7025
# Deep Below
# genre: ['Adventure', ' Indie']
# Confused Studios
# Confused Studios
# 2016-09-23
# 7030
# Dirty 30
# 2016-09-23
# 7042
# 7044
# City VR
# genre: ['Simulation', ' Early Access']
# Amber Garage, Inc.
# Amber Garage, Inc.
# 2016-09-26
# 7047
# Howard Lovecraft and the Frozen Kingdom
# 2016-09-27
# 7073
# 7075
# 7076
# 7077
# 7078
# 7079
# Soundboxing
# genre: ['Indie']
# Maxint LLC
# Maxint LLC
# 2016-09-29
# 7080
# 7083
# 7085
# Sailor Moon Crystal
# 2014-07-05
# 7089
# 7092
# Soldiers of Heaven VR
# genre: ['Action', ' Indie', ' Simulation', ' Early Access']
# Filmtyme
# Coqui 3D, Gorilla Productions
# 2016-09-29
# 7093
# Cmoar VR Cinema
# genre: ['Simulation']
# 10Ants Hill
# 10Ants Hill
# 2016-09-29
# 7095
# 7104
# Beyond Power VR
# genre: ['Action', ' Indie']
# Unparalleled Games
# Unparalleled Games
# 2016-09-30
# 7114
# 7115
# 7116
# FILE 9
# genre: ['Action', ' Adventure', ' Indie', ' Strategy']
# Cypress Inheritance, LLC
# Cypress Inheritance, LLC
# 2016-09-30
# 7123
# 7125
# 7126
# 7130
# 7133
# Fast Action Hero
# genre: ['Action', ' Casual', ' Indie', ' Strategy', ' Early Access']
# Sirius Sam
# RL Agency
# 2016-10-01
# 7139
# Spectre
# genre: ['Indie', ' Simulation', ' Strategy']
# Proscenium
# Proscenium
# 2016-10-03
# 7151
# Hat Trick Header
# genre: ['Action', ' Casual', ' Sports']
# no-pact
# no-pact
# 2016-10-04
# 7170
# Chicken Chase
# genre: ['Casual', ' Indie']
# Kalan Ray
# VKTRY Creative Studios
# 2016-10-05
# 7173
# 7174
# Anyland
# genre: ['Adventure', ' Casual', ' Indie', ' Massively Multiplayer']
# Scott Lowe
# Scott Lowe, Philipp Lenssen
# 2016-10-06
# 7191
# On bike Nurburgring Experience
# 2004-11-22
# 7197
# Alveari
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' RPG', ' Early Access']
# BeehiveBob
# BeehiveBob
# 2016-10-10
# 7206
# Thumper
# genre: ['Action', ' Indie']
# Drool
# Drool
# 2016-10-10
# 7208
# Senza Peso
# genre: ['Adventure', ' Casual']
# Kite & Lightning
# Kite & Lightning
# 2016-10-11
# 7215
# The Unwelcomed
# genre: ['Casual', ' Indie', ' Simulation', ' Early Access']
# The Unwelcomed Studios
# The Unwelcomed Studios
# 2016-10-11
# 7217
# Ballistic Protection
# genre: ['Action', ' Indie', ' Strategy']
# 2016-10-12
# 7243
# Battle Disc
# 2016-10-14
# 7249
# Edmersiv
# genre: ['Education']
# EvoBooks
# EvoBooks
# 2016-10-14
# 7254
# Ship It
# genre: ['Action', ' Casual', ' Indie', ' Early Access']
# Think On Labs
# Think On Labs
# 2016-10-14
# 7273
# Nerve
# 2016-10-11
# 7283
# Café Society
# 2016-10-18
# 7288
# The Rise of Captain Longbeard
# genre: ['Action', ' Adventure', ' RPG', ' Early Access']
# Colopl NI
# Colopl NI
# 2016-10-19
# 7292
# Destroyer
# genre: ['Action', ' Casual', ' Indie', ' Simulation']
# CFlat
# Degica
# 2016-10-19
# 7294
# 7309
# 7314
# Boxing Saga
# genre: ['Action', ' Sports']
# VR PrinceTechnology development Beijing Co. Ltd
# VR PrinceTechnology development Beijing Co. Ltd
# 2016-10-20
# 7330
# Push For Emor
# genre: ['Action', ' Indie', ' RPG', ' Early Access']
# Lupus Solus Studio
# Lupus Solus Studio
# 2016-10-24
# 7333
# Yore VR
# genre: ['Action', ' Adventure', ' Indie', ' RPG', ' Simulation', ' Early Access']
# Tectonic VR
# Tectonic VR
# 2016-10-12
# 7336
# Extreme Skiing VR
# genre: ['Adventure', ' Sports']
# 乐客游戏
# 乐客游戏
# 2016-10-20
# 7351
# Million Dollar Duck
# 2016-08-09
# 7353
# 7357
# Escape Bloody Mary
# genre: ['Adventure', ' Indie', ' Simulation']
# Well Told Entertainment
# Well Told Entertainment
# 2016-10-25
# 7368
# Hoverboards VR
# genre: ['Action', ' Indie']
# Mike Harris
# Mike Harris Design
# 2016-10-26
# 7376
# ALICE VR
# genre: ['Adventure', ' Indie']
# Carbon Studio
# Klabater
# 2016-10-27
# 7387
# 7390
# Killing Zombies
# genre: ['Action', ' Indie']
# FRS Game Studio
# Front Range Software, LLC
# 2016-10-27
# 7391
# 7413
# 7415
# 7419
# 7421
# Kitten Cannon
# genre: ['Casual']
# Chris Gallello
# Mr. Paws
# 2016-10-31
# 7423
# VR RunningJoe
# genre: ['Casual', ' Racing']
# ELIOT
# ELIOT
# 2016-10-26
# 7430
# 3dSunshine
# genre: ['Animation & Modeling', ' Design & Illustration', ' Utilities', ' Early Access']
# Vain Media LLC
# Vain Media LLC
# 2016-11-01
# 7431
# The Journey
# genre: ['Adventure', ' Casual', ' Indie', ' Simulation']
# Mugurel-Adrian Enache
# MD Lab Games
# 2016-10-28
# 7440
# 7444
# God Of Arrows VR
# genre: ['Action', ' Casual', ' Indie', ' Simulation', ' Early Access']
# Reactor Entertainment
# Reactor Entertainment
# 2016-11-02
# 7449
# VRCapture
# genre: ['Utilities', ' Video Production']
# XR Team
# XR Team
# 2016-11-03
# 7450
# VRMark
# genre: ['Utilities']
# Futuremark
# Futuremark
# 2016-11-03
# 7464
# Steam Dev Days
# 2016-11-03
# 7468
# Pass the Light
# 2016-08-17
# 7469
# Lifeliqe VR Museum
# genre: ['Free to Play', ' Simulation']
# Lifeliqe, Inc.
# Lifeliqe, Inc.
# 2016-11-04
# 7480
# Across
# genre: ['Action', ' Indie']
# Jonathan Sprauel Games
# Jonathan Sprauel Games
# 2016-11-04
# 7481
# 7484
# Constricting Cubes
# genre: ['Action', ' Casual', ' Indie', ' Strategy']
# D.W.S.
# D.W.S.
# 2016-11-07
# 7514
# Calcflow
# genre: ['Design & Illustration', ' Education', ' Software Training', ' Utilities']
# Nanome
# Nanome
# 2016-11-10
# 7518
# Viking Escape
# genre: ['Adventure', ' Indie']
# Viktor Pekar
# Viktor Pekar
# 2016-11-10
# 7519
# 7532
# 7543
# Very Real Chess
# genre: ['Indie', ' Simulation', ' Sports', ' Strategy']
# Zachary Geier
# Zachary Geier
# 2016-11-11
# 7544
# 7571
# 7572
# Google Earth VR
# genre: ['Adventure', ' Casual', ' Free to Play', ' Simulation']
# Google
# Google
# 2016-11-16
# 7584
# 7585
# Salvaged
# genre: ['Action', ' Strategy', ' Early Access']
# Opposable Games
# Opposable Games
# 2016-11-17
# 7593
# Fractasia
# genre: ['Design & Illustration']
# Start VR
# Start VR
# 2016-11-17
# 7621
# Robot Incursion
# genre: ['Action']
# MobileFusion Apps Ltd
# MobileFusion Apps Ltd
# 2016-11-21
# 7623
# 7624
# 7625
# 7630
# 7638
# Gary the Gull
# genre: ['Adventure']
# Motional Entertainment
# Limitless Ltd
# 2016-11-22
# 7674
# 7682
# Pinball FX2 VR
# genre: ['Simulation']
# Zen Studios
# Zen Studios
# 2016-11-29
# 7694
# Draco Dux
# genre: ['Action', ' Adventure', ' Indie']
# BraveDev
# BraveDev
# None
# 7697
# Snowday
# genre: ['Action', ' Early Access']
# Breachgate
# Breachgate
# 2016-11-30
# 7701
# 7710
# Driftwatch VR
# genre: ['Action']
# Sevenedge Interactive Media
# Sevenedge Interactive Media
# 2016-12-01
# 7719
# 7727
# Theme Park Studio
# genre: ['Indie', ' Simulation']
# Pantera Entertainment
# Pantera Entertainment
# 2016-12-02
# 7735
# Snakes on an Extradimensional Plane
# genre: ['Action', ' Indie']
# Team Neon Snakes
# Fox Buchele
# 2016-12-05
# 7750
# 7751
# 7752
# Kingspray Graffiti VR
# genre: ['Simulation']
# Andrew Bates
# Infectious Ape
# 2016-12-06
# 7756
# 7757
# 7758
# 7772
# 7790
# 7796
# Broken Blue
# genre: ['Casual', ' Free to Play', ' Indie', ' Simulation']
# BacklotRealities
# Cacti Council, BacklotRealities
# 2016-12-05
# 7798
# WackyMoles
# genre: ['Action', ' Casual', ' Simulation', ' Sports']
# CrystalGame
# CrystalGame
# 2016-12-12
# 7800
# 7802
# Bleach
# 2004-10-05
# 7806
# Tornuffalo
# genre: ['Action']
# RealityRig
# RealityRig
# 2016-12-12
# 7837
# Wipe Out VR
# genre: ['Simulation']
# PnagaeaVR
# PnagaeaVR
# 2016-11-10
# 7844
# Arma 3 Community Guide Series
# 2013-03-07
# 7856
# Children of Colossus
# genre: ['Action', ' Indie']
# Colossus Interactive
# Colossus Interactive
# 2016-12-15
# 7863
# Alpine Ski VR
# genre: ['Casual', ' Racing', ' Sports']
# Suchworks Ltd
# Suchworks Ltd
# 2016-12-16
# 7865
# 7866
# Snow Fortress
# genre: ['Action', ' Casual', ' Indie', ' Simulation', ' Strategy']
# Mythical City Games
# Mythical City Games
# 2016-12-16
# 7877
# Dragon Skies VR
# genre: ['Action', ' Adventure', ' RPG']
# Tristan Hodges
# FoxLeap Games
# 2016-12-01
# 7883
# FriendShip
# genre: ['Casual']
# Grayson Malinowski
# 2Tall Inc.
# 2016-12-16
# 7884
# VR Apocalypse
# genre: ['Action', ' Indie', ' Early Access']
# NextGen Games
# NextGen Games
# 2016-12-16
# 7885
# 7886
# Fast Break
# 2008-12-01
# 7887
# Smash Party VR
# genre: ['Action', ' Casual', ' Indie', ' Early Access']
# Viacom NEXT
# Viacom NEXT
# 2016-12-18
# 7890
# Arcane
# genre: ['Action']
# Offpeak Games
# Offpeak Games
# 2016-12-19
# 7894
# Fastigium
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' RPG']
# ifgames studio
# ifgames studio
# 2016-12-17
# 7909
# Drone Hunter VR
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' Simulation']
# VR VISIO
# Forever Entertainment S. A.
# 2016-12-21
# 7914
# SwingStar VR
# genre: ['Action', ' Adventure', ' Simulation']
# Computer Lunch
# Computer Lunch
# 2016-12-20
# 7917
# Eagle Flight
# genre: ['Action', ' Simulation']
# Ubisoft Montreal Studio
# Ubisoft
# 2016-12-20
# 7923
# Santa Sling
# genre: ['Casual', ' Indie', ' Simulation']
# 8th Shore, Inc.
# 8th Shore, Inc.
# 2016-12-20
# 7925
# 7930
# Chunky Orbits
# genre: ['Simulation']
# Don Whitaker
# Brain Blinks
# 2015-09-08
# 7932
# Robot City Stadium
# genre: ['Action', ' Casual', ' Indie', ' Sports', ' Early Access']
# Virtual Vengeance
# Virtual Vengeance
# 2016-12-21
# 7934
# TacoFace
# genre: ['Casual', ' Indie']
# KLNK Inc.
# KLNK Inc.
# 2016-12-21
# 7939
# Blueshift
# genre: ['Casual', ' Free to Play', ' Indie', ' Racing', ' Simulation', ' Early Access']
# Zach Tsiakalis-Brown
# Zulubo Productions
# 2016-12-21
# 7941
# House of Meditation
# genre: ['Education']
# Cerevrum Inc.
# Cerevrum Inc.
# 2016-12-22
# 7944
# Battle Dome
# genre: ['Action']
# Bad Bird Studios
# 2017-06-08
# 7947
# Pinheads Bowling VR
# genre: ['Action', ' Casual', ' Simulation', ' Sports', ' Early Access']
# Midnight Studios, Inc.
# Midnight Studios, Inc.
# 2016-12-22
# 7948
# VR Monster Awakens
# genre: ['Action', ' Indie', ' Simulation', ' Early Access']
# FIGHT4DREAM LIMITED
# FIGHT4DREAM LIMITED
# 2016-12-22
# 7949
# VR Photo Viewer
# genre: ['Utilities']
# SprocketVR
# SprocketVR
# 2017-06-22
# 7950
# Danger Room
# genre: ['Action', ' Indie']
# Actually Sane Studios
# Actually Sane Studios
# 2016-12-22
# 7951
# Weird creatures
# genre: ['Action', ' Indie']
# mchernykh
# mchernykh
# 2016-12-22
# 7953
# Cosmos Crash VR
# genre: ['Casual', ' Indie']
# Viriver Network Technology Co., Ltd.
# Viriver Network Technology Co., Ltd.
# 2016-09-01
# 7960
# 7963
# Borealis
# 2016-12-23
# 7964
# 7978
# Clazer
# genre: ['Simulation', ' Sports', ' Early Access']
# SynapticSwitch, LLC
# SynapticSwitch, LLC, LeadTech, LLC
# 2016-12-27
# 7980
# Christmas Massacre VR
# genre: ['Action', ' Indie']
# AndAll Interactive
# AndAll Interactive
# 2016-12-27
# 7984
# 7985
# Wave Magic VR
# genre: ['Action', ' Indie', ' RPG', ' Early Access']
# Overrun Games
# Overrun Games
# 2016-12-29
# 7989
# Space Badminton VR
# genre: ['Sports']
# Shashitha Kularatna
# Shashitha Kularatna
# 2016-12-29
# 7991
# VR Snowballs
# genre: ['Casual']
# Zabuza Labs
# Zabuza Labs
# 2016-12-29
# 7995
# 7997
# HVR
# genre: ['Action', ' Indie', ' Simulation']
# Andre Le
# Andre Le
# 2016-12-30
# 8004
# 3D Organon VR Anatomy
# genre: ['Education']
# Medis Media
# Medis Media
# 2016-12-09
# 8006
# Spooky Night
# genre: ['Action', ' Casual', ' Free to Play', ' Indie', ' Strategy']
# AurealStudio
# AurealStudio
# 2016-11-14
# 8008
# Equilibrium VR
# genre: ['Action', ' Adventure', ' Casual', ' Indie']
# Funny Twins
# Funny Twins
# 2017-01-07
# 8010
# Escape the Bunker
# genre: ['Adventure', ' Casual', ' Indie']
# Virtual Escapes, Inc.
# Virtual Escapes, Inc.
# 2017-01-02
# 8011
# Marimba VR
# genre: ['Casual', ' Indie', ' Simulation']
# Ruby Games
# Ruby Games
# 2017-01-02
# 8015
# The Rainbow Kid
# 2016-11-01
# 8018
# 8019
# 8020
# RAYGUN COMMANDO VR
# genre: ['Casual', ' Free to Play', ' Indie']
# Chun Y.
# Chun Y.
# 2017-01-23
# 8022
# 8031
# 8036
# GoalkeepVr
# genre: ['Action', ' Simulation', ' Sports']
# DigitalBadger Design
# DigitalBadger Design
# 2017-01-06
# 8040
# vRhythm
# genre: ['Indie', ' Early Access']
# Pixelpointer Studios
# Pixelpointer Studios
# 2017-09-07
# 8052
# Beats Fever
# genre: ['Action', ' Casual', ' Indie', ' Sports']
# Arrowiz
# Arrowiz
# 2017-01-10
# 8066
# Lucid Trips
# genre: ['Adventure', ' Indie', ' Early Access']
# Nico Uthe, Sara Lisa Vogl, Julian Heinken
# Sara Lisa Vogl, VR Nerds
# 2017-01-12
# 8067
# VRSailing by BeTomorrow
# genre: ['Indie', ' Simulation', ' Sports']
# BeTomorrow
# BeTomorrow
# 2017-01-12
# 8075
# Space Slam
# genre: ['Action', ' Indie']
# ;)
# Quickdraw Studios
# 2017-01-12
# 8076
# 8078
# Embrace The Fear
# genre: ['Action', ' Adventure', ' Simulation']
# 世纪龙信息网络有限责任公司
# 世纪龙信息网络有限责任公司
# 2017-01-12
# 8079
# Beach Bowling Dream VR
# genre: ['Casual', ' Indie', ' Sports']
# Lucid Dreams VR, LLC
# Lucid Dreams VR, LLC
# 2017-01-13
# 8080
# Fractal
# genre: ['Action', ' Adventure', ' Indie', ' Early Access']
# Phosphene Designs LLC
# Phosphene Designs LLC
# 2017-01-12
# 8083
# Blackwater Bayou VR
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' RPG', ' Simulation']
# Virtual Rage Studios LLC
# Virtual Rage Studios LLC
# 2017-01-13
# 8084
# 8085
# Haywire
# 2012-05-01
# 8086
# 8088
# Judge Archer
# 2016-11-01
# 8089
# The Grand Canyon VR Experience
# genre: ['Adventure', ' Casual', ' Indie', ' Simulation']
# Immersive Entertainment, Inc.
# Immersive Entertainment, Inc
# 2017-01-13
# 8094
# HORROR OF THE DEEP
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' Early Access']
# DRUNKEN APES
# DRUNKEN APES
# 2017-01-13
# 8098
# 8101
# GridVR
# genre: ['Action']
# iPOL
# iPOL
# 2017-01-17
# 8104
# Puzzle Island VR
# genre: ['Casual', ' Early Access']
# Interaction Ideas GmbH
# Interaction Ideas GmbH
# 2017-01-17
# 8109
# Starship Disco
# genre: ['Action', ' Indie']
# Solus Games, Inc.
# Solus Games, Inc.
# 2017-01-17
# 8119
# Go North
# 2017-01-13
# 8121
# Come and Find Me
# 2016-11-11
# 8122
# Huntwatch
# 2017-01-17
# 8143
# HVRGUN
# genre: ['Action', ' Indie', ' Early Access']
# Jonathan Bartram
# Jonathan Bartram, Thomas Bartram
# 2017-01-19
# 8152
# The Physiology of the Eye
# genre: ['Casual', ' Simulation']
# Intervoke
# Intervoke
# 2017-01-19
# 8169
# Siege And Destroy
# genre: ['Action', ' Casual', ' Indie', ' Early Access']
# Makketron LLC
# Makketron LLC
# 2017-01-23
# 8175
# 8182
# 8202
# Snowman
# genre: ['Action', ' Indie', ' Sports']
# 2017-01-27
# 8208
# Magic Lantern
# genre: ['Adventure', ' Free to Play', ' Simulation']
# Parovoz Animation Studio
# Interactive Moolt
# 2017-01-29
# 8211
# 8217
# 8234
# King Kaiju
# genre: ['Indie', ' Simulation']
# Fire Hose Games
# Fire Hose Games
# 2017-01-31
# 8236
# Snailiens
# genre: ['Action', ' Indie', ' Strategy', ' Early Access']
# 562 Interactive
# 562 Interactive LLC.
# 2017-01-31
# 8237
# Brush Up VR
# genre: ['Casual', ' Indie', ' Early Access']
# Games That Work
# Games That Work
# 2017-02-01
# 8241
# Snow Games VR
# genre: ['Action']
# Kenziko Ltd.
# Kenziko Ltd.
# 2017-01-30
# 8273
# Hollywood Hills Mansion
# LOOT Interactive, LLC
# LOOT Interactive, LLC
# 2017-02-02
# 8282
# Goalie Challenge VR
# genre: ['Free to Play', ' Simulation', ' Sports']
# Josh Beatty
# modulR
# 2017-02-01
# 8285
# SpaceJourney VR
# genre: ['Adventure', ' Indie', ' Simulation']
# GEESCAN
# GEESCAN
# 2017-01-19
# 8308
# Tomorrow
# genre: ['Adventure']
# Future Lighthouse
# Future Lighthouse
# 2017-02-08
# 8309
# 8312
# PowersVR
# genre: ['Action', ' Simulation', ' Early Access']
# Pseudocode Games
# Pseudocode Games
# 2017-02-08
# 8313
# I Am Road Comic
# 2014-08-26
# 8327
# Vision Therapy VR
# genre: ['Education']
# Cerevrum Inc.
# Cerevrum Inc.
# 2017-02-05
# 8341
# Defuser VR
# genre: ['Action', ' Casual', ' Indie']
# Niki Odolphie
# Somerset Online Ltd
# 2017-02-11
# 8364
# 8375
# 8377
# 8378
# 8379
# Tim Minchin And The Heritage Orchestra Live At Royal Albert
# 2011-11-14
# 8381
# 8385
# DEFCON VR
# genre: ['Indie', ' Strategy']
# Introversion Software
# Introversion Software
# 2017-02-15
# 8392
# 8396
# HOMEBOUND
# genre: ['Action', ' Adventure', ' Casual']
# Quixel
# Quixel
# 2017-02-16
# 8406
# 8418
# 8423
# IrreVRsible
# genre: ['Action', ' Indie']
# Raptor-Lab
# Raptor-Lab
# 2016-05-24
# 8428
# Neon Arena
# genre: ['Action', ' Casual', ' Indie']
# Axyos Games
# Axyos Games
# 2017-02-20
# 8445
# 8446
# Game of Aces
# 2016-09-09
# 8447
# 8448
# 8453
# 8455
# Climbtime
# genre: ['Casual', ' Indie']
# Saluda Systems
# Saluda Systems
# 2017-05-03
# 8460
# MixCast Studio
# genre: ['Education', ' Utilities', ' Video Production']
# Blueprint Reality Inc.
# Blueprint Reality Inc.
# 2017-02-22
# 8467
# 8468
# Stolen Steel VR
# genre: ['Action', ' Casual', ' Indie', ' Simulation']
# Impromptu Games
# Impromptu Games
# 2017-02-22
# 8481
# Skills Hockey VR
# genre: ['Sports', ' Early Access']
# Justin Jimmo
# Justin Jimmo
# 2017-02-23
# 8483
# VR Meditation SkyRun
# genre: ['Education']
# Weekend Soft
# Weekend Soft
# 2017-02-23
# 8484
# Seabed Prelude
# genre: ['Adventure', ' Casual', ' Indie', ' Simulation']
# MythicOwl
# MythicOwl
# 2017-02-24
# 8487
# Magazime Editor
# genre: ['Action', ' Indie', ' Simulation']
# 2017-02-24
# 8492
# Zombie in my city
# genre: ['Action', ' Indie', ' Early Access']
# SkyKan
# SkyKan
# 2017-02-24
# 8501
# LookVR
# genre: ['Utilities']
# Looker
# Looker
# 2017-02-27
# 8504
# HeapVR
# genre: ['Casual', ' Free to Play', ' Strategy']
# Richard Fox - Development
# Propeller Labs
# 2017-02-27
# 8506
# 8516
# Constellation Distantia
# genre: ['Action', ' Adventure', ' Indie', ' Strategy']
# Skanerbotten
# Skanerbotten
# 2017-02-28
# 8519
# Room Designer VR
# genre: ['Design & Illustration', ' Early Access']
# productivity-boost.com
# productivity-boost.com
# 2017-02-28
# 8529
# airRevo VR
# genre: ['Action', ' Casual', ' Indie']
# IndieRevo
# IndieRevo
# 2017-03-01
# 8533
# 8536
# Roomscale Coaster
# genre: ['Action', ' Casual', ' Sports']
# Blue Entropy Studios
# Blue Entropy Studios
# 2017-03-01
# 8538
# 8540
# 8546
# Light And Dance VR
# genre: ['Simulation', ' Sports']
# Hermann Fischer
# Hermann Fischer
# 2017-03-03
# 8547
# Lighting End VR
# genre: ['Casual', ' Indie']
# Time of Virtual Reality
# Time of Virtual Reality
# None
# 8559
# Diesel Power
# genre: ['Action', ' Casual', ' Indie', ' Racing']
# Irmas Ibric
# Irmas Ibric
# 2017-03-03
# 8568
# Deadly Hunter VR
# genre: ['Action', ' Adventure', ' RPG', ' Simulation', ' Sports', ' Strategy']
# Leiting Interactive
# Leiting Interactive
# 2017-06-19
# 8581
# 8589
# 994 W 24th
# genre: ['Casual', ' Indie', ' Early Access']
# Fat Finger Foundry
# Fat Finger Foundry
# 2017-04-11
# 8596
# Plevr
# genre: ['Utilities']
# Fervr Labs
# Fervr Labs
# 2017-03-08
# 8603
# 8607
# 8613
# GIPHY Museum of GIF Art
# genre: ['Design & Illustration']
# OONI
# GIPHY Arts
# 2017-03-08
# 8614
# Cowboy zombie
# genre: ['Casual', ' Indie', ' Simulation']
# 2017-03-08
# 8616
# Yeti Adventure
# genre: ['Action', ' Adventure', ' Casual', ' Indie']
# 2017-03-08
# 8637
# Revolution 25th Anniversary Documentary
# 2017-03-10
# 8647
# Constricted VR
# genre: ['Indie', ' Simulation', ' Strategy', ' Early Access']
# PNxDesigns
# PNxDesigns
# 2017-03-12
# 8650
# Shaun the Sheep
# 2015-11-24
# 8652
# Mighty Monster Mayhem
# genre: ['Action', ' Adventure', ' Casual', ' Simulation']
# Rank17
# Rank17
# 2017-04-20
# 8667
# Heaven Forest NIGHTS
# genre: ['Action', ' Adventure']
# Fabio Ferrara
# Chubby Pixel
# 2017-03-13
# 8671
# K Missing Kings
# 2014-07-12
# 8674
# World Builder
# genre: ['Casual', ' Indie', ' Simulation']
# Guruji VR, Inc
# Guruji VR, Inc
# 2017-03-14
# 8675
# Suspended Workshops
# genre: ['Free to Play', ' Indie']
# Suspended Reality
# Suspended Reality
# 2017-12-01
# 8676
# Masters Of Chess
# genre: ['Casual']
# MobileFusion Apps Ltd
# MobileFusion Apps Ltd
# 2017-03-14
# 8684
# GUNNVR
# genre: ['Action', ' Adventure', ' Indie', ' RPG', ' Simulation', ' Early Access']
# Artificient Games Inc.
# Artificient Games Inc.
# 2017-03-28
# 8686
# VRCURATOR
# genre: ['Audio Production', ' Utilities']
# Lobaki
# Lobaki
# 2017-03-15
# 8704
# 8708
# 8711
# Clash of Vessels VR
# genre: ['Action', ' Casual', ' Simulation', ' Strategy']
# Druid Technologies
# Druid Technologies
# 2017-03-17
# 8713
# 8715
# Hover Skate VR
# genre: ['Indie', ' Simulation', ' Sports', ' Early Access']
# Hyper Light Studios
# Hyper Light Studios
# 2017-03-17
# 8728
# Warpaint
# genre: ['Casual', ' Indie', ' Strategy']
# Adam Thompson
# LADDER
# 2017-03-17
# 8733
# Frontier VR
# genre: ['Adventure', ' Casual']
# Gaugepunk Games
# Gaugepunk Games
# 2017-03-16
# 8737
# 8739
# 8740
# The Crooked Man
# 2017-02-14
# 8741
# Star Hunter VR
# genre: ['Action', ' Adventure', ' Casual', ' Indie']
# LiangDeZhao
# LiangDeZhao
# 2017-03-17
# 8745
# Vive Video
# genre: ['Utilities']
# HTC Creative Labs
# HTC America Innovation, Inc.
# 2017-03-20
# 8747
# Shadow Circuit
# genre: ['Action', ' Sports', ' Early Access']
# WetWare / Games
# WetWare / Games
# 2017-03-20
# 8772
# Mech Skeleton
# genre: ['Action', ' Indie']
# Heavy Kick Games
# Heavy Kick Games
# 2017-03-21
# 8779
# Kira
# genre: ['Casual', ' Free to Play', ' Simulation']
# Bully Innovation Group, Inc.
# Bully Innovation Group, Inc.
# 2017-03-15
# 8800
# Chainless
# genre: ['Action', ' Adventure', ' Casual', ' Indie']
# Albert MN.
# Albert MN.
# 2017-03-24
# 8801
# 8802
# LyraVR
# genre: ['Indie', ' Early Access']
# LyraVR
# LyraVR
# 2017-03-22
# 8804
# EmbodyMe Beta
# genre: ['Casual', ' Free to Play', ' Massively Multiplayer', ' Early Access']
# Paneo, Inc.
# Paneo, Inc.
# 2017-03-22
# 8807
# ShapeLab
# genre: ['Animation & Modeling', ' Design & Illustration', ' Early Access']
# Leopoly
# Leopoly
# 2017-03-23
# 8816
# 8817
# Twisted Arrow
# genre: ['Action', ' Adventure']
# Phaser Lock Interactive
# Phaser Lock Interactive
# 2017-03-28
# 8818
# 8820
# 8821
# 8822
# 8823
# 8825
# 8826
# 8836
# Lion
# 2017-03-21
# 8837
# 8847
# Moonatees
# genre: ['Indie', ' Simulation']
# Fungi In The Basement
# Fungi In The Basement
# 2017-03-29
# 8854
# 8863
# 8872
# Aussie Sports VR
# genre: ['Sports']
# Mark Schramm
# Reload Labs
# None
# 8877
# OK Bob
# genre: ['Casual', ' Indie']
# Lumen Labs
# Lumen Labs
# 2017-03-31
# 8890
# 8898
# COMPOUND
# genre: ['Action', ' Indie']
# Bevan McKechnie
# Bevan McKechnie
# None
# 8914
# 8916
# Fort Awesome
# genre: ['Indie', ' Early Access']
# Ben McNelly
# Full Bore Studios, LLC
# 2017-04-04
# 8921
# Basketball Court VR
# genre: ['Casual', ' Indie', ' Sports']
# Chun Y.
# Chun Y.
# 2017-04-04
# 8922
# Basketball Court VR Demo
# genre: ['Casual', ' Free to Play', ' Simulation']
# Chun Y.
# Chun Y.
# 2017-04-04
# 8923
# Chaos Edge
# genre: ['Action', ' Adventure', ' RPG', ' Early Access']
# LaoniuStudio
# LaoniuStudio
# 2017-03-29
# 8924
# VR Interior Designer Pro
# genre: ['Free to Play', ' Indie', ' Simulation']
# Edgehill CGI
# Edgehill CGI
# 2017-03-29
# 8930
# SourVR Video Player Deluxe Edition
# genre: ['Utilities']
# River Twice Co., Ltd.
# River Twice Co., Ltd.
# 2017-04-05
# 8937
# 8947
# Xark
# genre: ['Action', ' Indie', ' RPG', ' Strategy', ' Early Access']
# Spencer Malone
# Spencer Malone
# None
# 8951
# Aftermath
# 2017-04-07
# 8964
# Dungeon Escape VR
# genre: ['Indie']
# Silver Machine Studios
# Silver Machine Studios
# 2017-04-07
# 8965
# Zombie Buster VR
# genre: ['Action']
# jackstree
# jackstree
# 2017-04-03
# 8972
# Bottle Flip Challenge VR
# genre: ['Casual', ' Simulation', ' Sports']
# Justin Jimmo
# Squawkybird Games
# 2017-04-09
# 8973
# 8974
# 8977
# The Thinning
# 2016-10-12
# 8979
# 9000
# PingBall VR
# genre: ['Action', ' Casual', ' Indie', ' Simulation', ' Sports']
# Immersive Artz
# Immersive Artz
# 2017-04-12
# 9002
# 9003
# TheWaveVR Beta
# genre: ['Massively Multiplayer', ' Simulation', ' Early Access']
# TheWaveVR
# TheWaveVR
# 2017-04-12
# 9023
# 9028
# 9031
# EGG HUNT VR
# genre: ['Adventure', ' Casual', ' Simulation']
# ThinkVirtual LLC
# ThinkVirtual LLC
# 2017-04-14
# 9033
# Free Enterprise
# 1999-06-04
# 9038
# 9044
# Hello inc VR
# genre: ['Action', ' Casual', ' Indie', ' Early Access']
# VRAD, Inc
# VRAD, Inc
# 2017-04-10
# 9057
# Altitude
# 2017-04-14
# 9075
# Mega Overload VR
# genre: ['Action']
# Subdream Studios
# Subdream Studios
# 2017-04-18
# 9089
# 9099
# 9100
# 9102
# 9104
# 9115
# 9119
# Train Harder
# genre: ['Action', ' Casual', ' Indie']
# 2Frogs Software
# 2Frogs Software
# 2017-04-21
# 9125
# Trapped With the Dolls VR
# genre: ['Adventure', ' Free to Play', ' Indie']
# Designated Play Space
# Designated Play Space
# 2017-04-23
# 9138
# Symphony of the Machine
# genre: ['Indie']
# Stirfire Studios
# Stirfire Studios
# 2017-04-24
# 9159
# Interkosmos
# genre: ['Action', ' Adventure', ' Indie', ' Simulation']
# Ovid Works
# Ovid Works
# 2017-04-25
# 9161
# 9165
# 9199
# Gem Hunter
# genre: ['Action', ' Adventure', ' Indie']
# FoxLeap
# FoxLeap
# 2017-04-28
# 9200
# Viking Rage
# genre: ['Action', ' Casual', ' Indie']
# N-Gon Entertainment
# Headup Games
# 2017-04-28
# 9203
# Glider Island
# genre: ['Action', ' Adventure', ' Casual', ' Racing', ' Simulation', ' Sports']
# Joey Sipos
# 5D Realities
# 2017-04-28
# 9213
# The Midnight Sanctuary Demo
# genre: ['Adventure', ' Indie']
# CAVYHOUSE
# Carpe Fulgur
# 2017-05-01
# 9225
# 9228
# VectorWars VR
# genre: ['Action', ' Adventure', ' Casual', ' Indie']
# Red Iron Labs
# Red Iron Labs
# 2017-05-01
# 9231
# VRIQ
# genre: ['Free to Play', ' Simulation']
# 3DIQ
# 3DIQ
# 2017-05-03
# 9263
# 9299
# Bounty Killer
# genre: ['Action', ' Indie', ' RPG', ' Early Access']
# Galaxy Game Studio
# Galaxy Game Studio
# 2017-05-09
# 9302
# Goaltender VR
# genre: ['Casual', ' Sports', ' Early Access']
# RunByCoffee
# RunByCoffee
# 2017-05-09
# 9314
# Blastercell
# genre: ['Action', ' Casual', ' Indie']
# Robot Games
# SmokinSkull
# 2017-05-10
# 9315
# Puppy Doge VR
# genre: ['Casual', ' Indie', ' Simulation']
# Chun Y.
# Chun Y.
# 2017-05-10
# 9318
# Battlezone
# genre: ['Action']
# Rebellion
# Rebellion
# 2017-05-11
# 9322
# Speed and Scream
# genre: ['Casual', ' Indie', ' Simulation']
# iNFINITE Production
# iNFINITE Production
# 2017-04-30
# 9354
# 9356
# Domain Defense VR
# genre: ['Casual', ' Indie', ' Strategy']
# Inclusion Studios
# Inclusion Studios
# 2017-05-11
# 9357
# Void Rangers
# genre: ['Action', ' Indie']
# Martin Senovsky
# Martin Senovsky
# 2017-05-11
# 9362
# 9363
# 9364
# 9365
# Making of Furi
# 2017-05-11
# 9384
# 9385
# Edge of Atlantis
# genre: ['Action', ' Adventure', ' Indie', ' RPG', ' Simulation', ' Early Access']
# Creality Studio
# Creality Studio
# 2018-02-01
# 9390
# Super Amazeballs
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' Racing', ' Simulation']
# Braincells Productions Inc.
# Braincells Productions Inc.
# 2017-05-16
# 9391
# 9392
# 9393
# Bitdude
# genre: ['Casual', ' Free to Play', ' Indie']
# Will Mearns
# Wicked Manatee Games
# 2016-01-06
# 9402
# Disc League
# genre: ['Action', ' Indie', ' Sports', ' Early Access']
# Virtually Invincible LLC
# Virtually Invincible LLC
# 2017-05-17
# 9405
# 9406
# Deep Blue 3D Maze
# genre: ['Action', ' Adventure', ' Casual', ' Indie']
# Ice Code Games
# Ice Code Games
# 2017-05-17
# 9426
# RUN
# genre: ['Action', ' Indie', ' Simulation']
# POPSAUR
# POPSAUR
# 2017-05-19
# 9428
# 9429
# 9432
# Donut Distraction
# genre: ['Casual', ' Indie', ' Early Access']
# MSFX Ltd
# MSFX Ltd
# 2017-05-19
# 9433
# Formula E powered by Virtually Live
# genre: ['Free to Play', ' Racing', ' Simulation', ' Sports']
# Virtually Live
# Virtually Live
# 2017-05-20
# 9459
# 9463
# CAD XR
# genre: ['Animation & Modeling', ' Design & Illustration', ' Utilities']
# Lucid Sight, Inc.
# Lucid Sight, Inc.
# 2017-05-24
# 9464
# 9478
# Everything Must Fall
# genre: ['Action', ' Adventure', ' Indie', ' Early Access']
# Carry Castle
# Carry Castle
# 2017-05-25
# 9479
# Rock Dog
# 2017-05-25
# 9483
# Lone Pirate VR
# genre: ['Action', ' Adventure']
# b08
# b08
# 2017-05-26
# 9489
# Australiens
# 2016-06-14
# 9491
# VR Scape
# genre: ['Action', ' Adventure', ' Indie', ' RPG', ' Early Access']
# David Dimond
# David Dimond
# 2017-05-26
# 9493
# Dirty Dancing TV Special
# 2017-05-25
# 9495
# Black Butterfly
# 2017-05-26
# 9499
# 9502
# IKEA VR Pancake Kitchen
# genre: ['Free to Play']
# IKEA Communications AB
# IKEA Communications AB
# 2017-05-30
# 9503
# 9507
# BREACH IT
# genre: ['Action', ' Indie', ' Strategy', ' Early Access']
# Domas Sabockis
# Domas Sabockis
# 2017-05-30
# 9508
# Dustoff Heli Rescue 2
# genre: ['Action', ' Casual', ' Indie']
# Invictus Games Ltd.
# Invictus Games Ltd.
# 2017-05-29
# 9511
# 9512
# 9518
# Throttle Powah VR
# genre: ['Action', ' Indie', ' Racing', ' Sports', ' Early Access']
# Diego F Beltran
# Diego F Beltran
# 2017-05-30
# 9525
# 9530
# Relax Walk VR
# genre: ['Simulation']
# Indiecode Games
# Indiecode Games
# 2017-06-02
# 9535
# 9538
# The Murder Room VR
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' Simulation']
# Bellcat Game
# Bellcat Game
# 2017-05-22
# 9539
# 9551
# Stunt Kite Masters VR
# genre: ['Action', ' Simulation', ' Sports']
# HandyGames
# HandyGames
# 2017-06-01
# 9554
# 9555
# FORM
# genre: ['Adventure', ' Casual', ' Indie']
# Charm Games
# Charm Games
# 2017-06-01
# 9558
# Escape The Gray
# genre: ['Casual', ' Indie']
# QRA-CS
# QRA-CS
# 2017-06-01
# 9564
# 9565
# VRun
# genre: ['Action', ' Adventure', ' Indie', ' Sports']
# Phoenix3
# Mr. L
# 2017-06-01
# 9572
# Microcosm
# genre: ['Indie', ' Simulation', ' Early Access']
# paulstraw
# paulstraw
# 2017-04-17
# 9573
# Streetball VR
# genre: ['Simulation', ' Sports']
# Indiecode Games
# Indiecode Games
# 2017-06-02
# 9574
# VectorWave
# genre: ['Action', ' Casual', ' Indie', ' Strategy']
# Fizzure Entertainment
# Fizzure Entertainment
# 2017-11-16
# 9583
# 4D Toys
# genre: ['Indie', ' Simulation']
# mtb design works, inc.
# mtb design works, inc.
# 2017-06-02
# 9584
# BARBAR BAR
# genre: ['Casual', ' Free to Play', ' Simulation']
# TEDI Games
# TEDI Games
# 2017-06-02
# 9587
# UNTITLED
# genre: ['Indie']
# Bean Boy Games
# Bean Boy Games
# 2017-06-02
# 9593
# 9597
# Adventures In Comedy
# 2017-05-01
# 9599
# StratoBash
# genre: ['Action', ' Indie', ' RPG']
# Phr00t's Software
# Phr00t's Software
# 2017-06-02
# 9600
# Far Space VR
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' Simulation']
# Alexey Glinskiy
# Alexey Glinskiy
# 2017-05-10
# 9607
# VR SUSHI BAR
# genre: ['Casual', ' Simulation']
# mikai inc.
# mikai inc.
# 2017-05-30
# 9617
# The Existence Abstract
# genre: ['Action', ' Indie']
# Soukdee Games
# Soukdee Games
# 2017-06-05
# 9631
# 9633
# Power Solitaire VR
# genre: ['Action', ' Casual', ' Simulation', ' Strategy']
# Parkerhill Reality Labs
# Parkerhill Reality Labs
# 2017-06-07
# 9638
# Airtone
# genre: ['Action', ' Adventure']
# historia Inc
# AMG GAMES
# 2017-06-08
# 9643
# VR Theme Park Rides
# genre: ['Casual', ' Simulation']
# EnsenaSoft
# EnsenaSoft
# 2017-06-08
# 9644
# Toy Plane Heroes
# genre: ['Action', ' Indie', ' Racing']
# Oasis VR
# Oasis VR
# 2017-06-08
# 9648
# Darknet
# genre: ['Indie', ' Strategy']
# E McNeill
# E McNeill
# 2017-06-08
# 9651
# Bubble Labs VR
# genre: ['Casual', ' Simulation']
# Kishan Emens (dev)
# Kishan Emens
# 2017-06-08
# 9653
# The Frontier Outskirts VR
# genre: ['Action', ' Adventure', ' Indie', ' Simulation', ' Early Access']
# Matt's Creations
# Matt's Creations
# 2017-06-11
# 9654
# Pixel Gear
# genre: ['Action', ' Indie']
# Geronimo Interactive
# Geronimo Interactive
# 2017-06-12
# 9657
# Isle in the Sky
# genre: ['Action', ' Simulation', ' Sports']
# Jan-Fredrik Braseth
# Fome Productions
# 2017-06-12
# 9667
# 9671
# WiseMind
# genre: ['Software Training', ' Early Access']
# REALITEER Corp.
# REALITEER Corp.
# 2017-06-13
# 9673
# BOXVR
# genre: ['Action', ' Casual', ' Indie', ' Sports', ' Early Access']
# FitXR
# FitXR
# 2017-06-13
# 9675
# 9676
# 9677
# Dying To Kill
# 2016-12-10
# 9678
# 9679
# 9680
# 9681
# 9682
# 9683
# 9684
# 9685
# 9693
# Bullet Dodge
# genre: ['Action', ' Casual', ' Indie']
# QRA-CS
# QRA-CS
# 2017-06-15
# 9705
# The Mechanical Room VR
# genre: ['Action']
# MASH Virtual
# MASH Virtual
# 2017-06-15
# 9719
# VINDICTA
# genre: ['Early Access']
# Game Cooks
# Game Cooks
# 2017-06-19
# 9720
# Child of the Wind
# genre: ['Action', ' Casual', ' Indie', ' Strategy']
# Freetale
# Freetale
# 2017-06-16
# 9721
# 9722
# Keep Defending
# genre: ['Action', ' Indie']
# Faster Time Games Limited
# Faster Time Games Limited
# 2017-06-19
# 9742
# Drone Hero
# genre: ['Action', ' Indie', ' Simulation', ' Sports', ' Early Access']
# Neuston AB
# Neuston AB
# 2017-06-20
# 9745
# 9762
# 9763
# ...
# Shortbreak Studios s.c.
# Shortbreak Studios s.c.
# 2016-04-19
# 23367
# Zombie Training Simulator
# genre: ['Action']
# Acceleroto, Inc.
# Acceleroto, Inc.
# 2016-04-15
# 23368
# SurrealVR
# genre: ['Adventure', ' Casual', ' Free to Play', ' Indie', ' Massively Multiplayer', ' Simulation']
# Surreal Games
# Surreal Games
# 2016-04-15
# 23371
# Deer Man
# genre: ['Adventure', ' Casual', ' Indie']
# Red Mount Media
# Red Mount Media
# 2016-04-11
# 23413
# 23417
# Vrideo
# genre: ['Utilities']
# Vrideo, Inc.
# Vrideo, Inc.
# 2016-04-08
# 23437
# 23441
# 23472
# Gunjack
# genre: ['Action', ' Casual']
# CCP
# CCP
# 2016-04-05
# 23474
# Hotel Blind
# genre: ['Casual', ' Indie', ' Simulation']
# Serellan LLC
# Serellan LLC
# 2016-04-05
# 23476
# Gunslinger Trainer
# genre: ['Action', ' Simulation', ' Early Access']
# Marcus Nichols
# HyperPub
# 2016-04-05
# 23478
# HTC Vive
# 2016-04-05
# 23479
# 23484
# 23487
# Atlas Reactor VR Character Viewer
# genre: ['Strategy']
# Trion Worlds
# Trion Worlds
# 2016-04-05
# 23488
# 23489
# Budget Cuts Demo
# genre: ['Action', ' Adventure', ' Indie']
# Neat Corporation
# Neat Corporation
# 2016-04-05
# 23490
# 23492
# 23493
# Minigame Party VR
# genre: ['Action', ' Casual', ' Indie']
# Scornz
# Scornz
# 2016-04-05
# 23494
# 23495
# Modbox
# genre: ['Casual', ' Indie', ' Simulation', ' Early Access']
# Alientrap
# Alientrap
# 2016-04-05
# 23496
# theBlu
# genre: ['Adventure', ' Casual', ' Indie', ' Simulation']
# Wevr, Inc.
# Wevr, Inc.
# 2016-04-05
# 23497
# Audioshield
# genre: ['Indie']
# Dylan Fitterer
# Dylan Fitterer
# 2016-04-05
# 23498
# 23500
# Fantastic Contraption
# genre: ['Indie', ' Simulation']
# Northway Games
# Northway Games
# 2016-04-05
# 23501
# Hover Junkers
# genre: ['Action', ' Adventure', ' Indie']
# Stress Level Zero
# Stress Level Zero
# 2016-04-05
# 23506
# 23507
# Bowslinger
# genre: ['Casual', ' Indie', ' Sports']
# Pompaduo
# Pompaduo
# 2016-04-05
# 23508
# Realities
# genre: ['Adventure', ' Free to Play', ' Simulation']
# realities.io
# realities.io
# 2016-04-05
# 23513
# The Rose and I
# genre: ['Casual', ' Indie']
# Eugene Chung
# Penrose Studios
# 2016-04-05
# 23515
# Job Simulator
# genre: ['Simulation']
# Owlchemy Labs
# Owlchemy Labs
# 2016-04-05
# 23516
# The FOO Show featuring Will Smith
# genre: ['Simulation', ' Early Access']
# FOO VR, Inc.
# FOO VR, Inc.
# 2016-04-05
# 23517
# Space Bit Attack
# genre: ['Action', ' Indie']
# Lucid Sight, Inc.
# Lucid Sight, Inc.
# 2016-04-05
# 23518
# Felt Tip Circus
# genre: ['Action', ' Casual', ' Indie']
# Alpha Wave Entertainment
# AAD Productions
# 2016-04-05
# 23519
# VR Baseball
# genre: ['Indie', ' Sports']
# Rank17
# Rank17
# 2016-04-04
# 23525
# 23526
# 23527
# 23528
# Final Approach
# genre: ['Action', ' Casual', ' Indie', ' Simulation', ' Strategy']
# Phaser Lock Interactive
# Phaser Lock Interactive
# 2016-04-04
# 23529
# 23530
# IKEA VR Experience
# genre: ['Free to Play']
# IKEA Communications AB
# IKEA Communications AB
# 2016-04-05
# 23531
# Holopoint
# genre: ['Action', ' Indie', ' Simulation', ' Sports']
# Alzan Studios, LLC
# Alzan Studios, LLC
# 2016-04-04
# 23532
# Marble Mountain
# genre: ['Action', ' Adventure', ' Casual', ' Indie']
# Lightning Rock
# Lightning Rock
# 2016-04-05
# 23533
# 23534
# Unseen Diplomacy
# genre: ['Action', ' Indie', ' Simulation']
# Triangular Pixels
# Triangular Pixels
# 2016-04-04
# 23535
# A Legend of Luca
# genre: ['Action', ' Adventure', ' Indie']
# Legend Studio
# Legend Studio
# 2016-04-05
# 23536
# 23537
# Jeeboman
# genre: ['Action', ' Indie']
# Futuretown
# Futuretown
# 2016-04-05
# 23539
# 23540
# Whirligig VR Media Player
# genre: ['Utilities', ' Video Production', ' Early Access']
# Philip Day
# Philip Day
# 2016-04-04
# 23548
# Gumball Drift
# genre: ['Action', ' Racing', ' Sports']
# Ghost Machine
# Ghost Machine
# 2016-04-05
# 23561
# 23570
# Virtual Desktop
# genre: ['Utilities']
# Guy Godin
# Guy Godin
# 2016-03-31
# 23584
# Tower Unite Dedicated Server
# 2016-03-29
# 23595
# Crystal Rift
# genre: ['Adventure', ' Indie']
# Psytec Games Ltd
# Psytec Games Ltd
# 2016-03-30
# 23603
# Thank You For Playing
# 2016-03-29
# 23611
# Amigdala
# genre: ['Action', ' Adventure', ' Indie']
# GuidiGermano
# GuidiGermano
# 2016-03-28
# 23625
# MadOut Open City
# genre: ['Action', ' Indie', ' Racing', ' Simulation', ' Sports']
# MadOut Games
# MadOut Games
# 2015-12-18
# 23631
# SAMOLIOTIK
# genre: ['Action', ' Casual', ' Indie']
# 2016-03-25
# 23637
# ADR1FT
# genre: ['Adventure', ' Indie']
# THREE ONE ZERO
# 505 Games
# 2016-03-28
# 23639
# 23641
# Bazaar
# genre: ['Indie', ' Strategy']
# Temple Gates Games
# Temple Gates Games
# 2016-03-28
# 23671
# 23677
# Spell Fighter VR
# genre: ['Action', ' Adventure', ' Indie', ' RPG']
# Kubold
# Kubold
# 2016-03-01
# 23780
# Engage
# genre: ['Education', ' Software Training', ' Utilities', ' Early Access']
# Immersive VR Education Ltd.
# Immersive VR Education Ltd.
# 2016-03-15
# 23821
# 23829
# Bellflower
# 2016-03-10
# 23845
# Buzzard
# 2016-03-09
# 23877
# 23886
# 23891
# Magnetic
# 2016-03-04
# 23920
# Coherence
# 2014-06-20
# 24116
# Void 21
# genre: ['Action', ' Indie', ' Racing']
# Taranasus Studio
# Taranasus Studio
# 2016-04-04
# 24123
# BrainBread 2 Mod Tools
# 2016-02-17
# 24132
# JourneyQuest Season Two
# 2012-08-10
# 24133
# JourneyQuest Season One
# 2010-10-01
# 24222
# 24224
# 24225
# 24226
# Naruto Shippuden the Movie
# 2007-08-04
# 24227
# 24228
# 24229
# 24230
# 24231
# 24235
# 24237
# 24251
# 24280
# 24293
# Water Bears VR
# genre: ['Casual', ' Indie']
# Schell Games
# Schell Games
# 2016-02-01
# 24646
# 24706
# Iverson
# 2015-12-08
# 24707
# 24794
# Metaverse Construction Kit
# genre: ['Casual', ' Free to Play', ' Indie', ' Simulation']
# Metaware
# Metaware
# 2015-12-06
# 24797
# DiRT Rally
# genre: ['Racing', ' Simulation', ' Sports']
# Codemasters Racing Studio
# Codemasters, Feral Interactive (Linux), Feral Interactive (Mac)
# 2015-12-07
# 24820
# Night Owls
# 2015-12-04
# 24832
# Fall of the Titanic
# genre: ['Adventure', ' Casual', ' Indie', ' Simulation']
# TheWgames
# TheWgames
# 2015-12-03
# 24836
# 24871
# Sculpting and Rendering an Axehead Demon
# 2015-12-02
# 24872
# Sculpting and Rendering a Biomech Creature Bust
# 2015-12-02
# 24873
# Sculpting and Rendering a Cthulhu Bust
# 2015-12-02
# 24875
# Creature Concepting In 3D
# 2015-12-02
# 24880
# 24919
# 24994
# 25050
# 25051
# 25053
# Dota 2 Player Profiles
# 2015-11-12
# 25083
# 25091
# Louie Cooks
# genre: ['Casual', ' Indie']
# starlit studios
# starlit studios, http
# 2015-11-10
# 25095
# Steam Link
# 2015-11-10
# 25098
# Syber Steam Machine
# 2015-11-10
# 25116
# Code Girl
# 2015-11-06
# 25124
# Enemy Empire
# 2015-03-03
# 25130
# 25135
# 25139
# 25213
# Boogeyman
# genre: ['Action', ' Indie', ' Strategy']
# Barry McCabe
# Clockwork Wolf
# 2015-11-02
# 25214
# Cloudrift
# genre: ['Action', ' Casual', ' Indie']
# friendlyOctopus
# friendlyOctopus
# 2015-10-30
# 25310
# Molly
# 2014-03-07
# 25318
# 25334
# Catching Up
# 2011-04-01
# 25364
# Introduction to Modo
# 2015-09-15
# 25365
# 25366
# Working Faster in Modo
# 2015-09-24
# 25367
# Modeling a Transport Vehicle in Modo
# 2015-09-27
# 25368
# 25413
# 25423
# All Fall Down
# genre: ['Action', ' Adventure', ' Indie']
# khos85
# khos85
# 2015-10-16
# 25444
# Caffeine
# genre: ['Adventure', ' Indie']
# Incandescent Imaging
# Incandescent Imaging
# 2015-10-12
# 25457
# Noximilian the Clockmaker
# 2015-10-13
# 25503
# Sublevel Zero Redux
# genre: ['Action', ' Indie']
# Sigtrap
# Sigtrap
# 2015-10-08
# 25565
# Double Fine Adventure
# 2015-10-01
# 25574
# Nevermind
# genre: ['Adventure', ' Indie']
# Flying Mollusk
# Flying Mollusk
# 2015-09-29
# 25614
# Euclidean
# genre: ['Action', ' Casual', ' Indie']
# Alpha Wave Entertainment
# AAD Productions
# 2015-09-25
# 25653
# Planetship
# genre: ['Action', ' Adventure', ' Indie']
# John Lawrence
# John Lawrence
# 2015-02-06
# 25687
# 25701
# 25723
# The Man From Orlando
# 2012-09-07
# 25748
# Future Farmer
# 2008-08-01
# 25750
# Gillespie
# 2010-08-01
# 25751
# 25779
# The Facility
# genre: ['Action', ' Adventure', ' Early Access']
# PolyDigital
# PolyDigital
# 2015-09-03
# 25788
# Mad Max Beyond Thunderdome
# 1985-07-10
# 25789
# 25793
# 25809
# Metal Gear Solid Legacy
# 2015-09-01
# 25899
# Universe Sandbox ²
# genre: ['Casual', ' Indie', ' Simulation', ' Early Access']
# Giant Army
# Giant Army
# 2015-08-24
# 25972
# 26041
# 26056
# Metro Warp
# genre: ['Casual', ' Indie', ' Strategy']
# Another Yeti
# Another Yeti
# 2015-08-05
# 26058
# REST DAYS
# 2014-12-10
# 26060
# 26061
# 26085
# THE BASEMENT
# 2015-05-15
# 26089
# JUMP
# genre: ['Action', ' Indie']
# Endeavor One Inc.
# Endeavor One Inc.
# 2015-07-30
# 26092
# Diving Normal
# 2015-01-15
# 26105
# 26106
# 26109
# 26150
# Fork Truck Challenge
# genre: ['Indie', ' Simulation', ' Early Access']
# Mint Arcade Ltd.
# Mint Arcade Ltd.
# 2015-07-24
# 26206
# A Survey of Open Space
# 2014-08-10
# 26224
# 26239
# Good Night
# 2013-11-15
# 26245
# 26247
# 26270
# Circle The Wagen
# 2014-07-29
# 26275
# In The Shadow
# 2013-03-01
# 26289
# Losing LeBron
# 2014-05-20
# 26291
# 26343
# 26379
# Dungeon Hero
# genre: ['Action', ' Adventure', ' Casual', ' Indie', ' RPG']
# Grzegorz Slazinski
# Grzegorz Slazinski
# 2015-07-07
# 26383
# 26384
# Good Game
# 2014-03-11
# 26411
# Creature Factory 2
# 2015-07-06
# 26413
# Knee Deep
# genre: ['Adventure', ' Indie']
# Prologue Games
# Prologue Games
# 2015-07-06
# 26424
# 26465
# Reflections
# genre: ['Adventure', ' Indie', ' Early Access']
# Broken Window Studios
# Broken Window Studios
# 2015-06-26
# 26475
# All Is Dust
# genre: ['Adventure', ' Free to Play']
# Mannequin Games LLC
# Mannequin Games LLC
# 2015-06-26
# 26484
# 26495
# 26531
# In Search of the Most Dangerous Town on the Internet
# 2015-06-18
# 26720
# Dungeon Crawlers HD
# genre: ['Indie', ' RPG', ' Strategy']
# Drowning Monkeys Games
# Drowning Monkeys Games
# 2015-06-01
# 26739
# Kung Fury
# 2015-05-28
# 26770
# Blender Game Asset Creation
# 2015-05-29
# 26774
# Catlateral Damage
# genre: ['Action', ' Casual', ' Indie', ' Simulation']
# Chris Chung
# Chris Chung
# 2015-05-27
# 26804
# 26805
# 26847
# 26848
# DREAMFLIGHT VR
# genre: ['Adventure', ' Simulation']
# REFUGIO3D®
# REFUGIO3D®, Claudio Panzanaro
# 2016-01-16
# 26861
# Monstrum
# genre: ['Indie']
# Team Junkfish
# Team Junkfish
# 2015-05-20
# 26975
# Football Manager Ruined My Life
# 2015-05-08
# 27037
# 27073
# Spermination
# genre: ['Action', ' Indie', ' Racing']
# Phr00t's Software
# Phr00t's Software
# 2015-04-29
# 27123
# 27142
# 27264
# 27272
# 27278
# Elite Dangerous
# genre: ['Action', ' Adventure', ' Massively Multiplayer', ' RPG', ' Simulation', ' Strategy']
# Frontier Developments
# Frontier Developments
# 2015-04-02
# 27360
# gravilon
# genre: ['Adventure', ' Indie', ' Strategy']
# 2015-03-30
# 27368
# Motivational Growth
# 2015-03-31
# 27375
# From Bedrooms to Billions
# 2015-03-31
# 27593
# SuperBike TT
# genre: ['Racing', ' Sports', ' Early Access']
# Ghost Machine
# Ghost Machine
# 2015-02-25
# 27603
# MyDream
# genre: ['Action', ' Adventure', ' Casual', ' Free to Play', ' Indie', ' RPG', ' Early Access']
# MyDream Interactive, Inc
# MyDream Interactive, Inc
# 2015-02-20
# 27706
# Crashed Lander
# genre: ['Indie']
# Don Whitaker
# Brain Blinks
# 2014-06-17
# 27828
# InMind VR
# genre: ['Action', ' Casual', ' Free to Play', ' Indie']
# Luden.io
# Nival
# 2015-01-19
# 27877
# iRacing
# genre: ['Massively Multiplayer', ' Racing', ' Simulation', ' Sports']
# iRacing.com Motorsport Simulations
# iRacing.com Motorsport Simulations, iRacing
# 2015-01-12
# 27889
# The Making of Grim Fandango Remastered
# 2015-01-13
# 27893
# 27964
# Assetto Corsa
# genre: ['Indie', ' Racing', ' Simulation', ' Sports']
# Kunos Simulazioni
# Kunos Simulazioni
# 2014-12-19
# 27983
# BOMB Dedicated Server
# 2014-12-17
# 28075
# Distance
# genre: ['Action', ' Indie', ' Racing', ' Early Access']
# Refract
# Refract
# 2014-12-09
# 28182
# Battle Fleet 2
# genre: ['Simulation', ' Strategy']
# Mythical City Games
# Mythical City Games
# 2014-11-20
# 28467
# Double Action Dedicated Server
# 2014-10-01
# 28652
# World of Diving
# genre: ['Adventure', ' Indie', ' Simulation', ' Early Access']
# Vertigo Games
# Vertigo Games
# 2014-08-26
# 28662
# 28671
# NoLimits 2 Roller Coaster Simulation Demo
# genre: ['Indie', ' Simulation']
# Ole Lange
# Mad Data GmbH & Co. KG
# 2014-08-21
# 28807
# Selknam Defense
# genre: ['Action', ' Indie', ' Strategy']
# 2014-07-25
# 28811
# Us and the Game Industry
# 2014-07-28
# 29167
# Super Game Jam
# 2014-05-22
# 29528
# Free to Play
# 2014-03-19
# 29867
# Nimble Quest
# genre: ['Action', ' Casual', ' Indie']
# 2013-12-06
# 29873
# Race The Sun
# genre: ['Action', ' Indie', ' Racing']
# Flippfly LLC
# Flippfly LLC
# 2013-12-09
# 29919
# 29921
# 29922
# 29925
# Dead Sky
# genre: ['Action', ' Indie']
# 2013-11-22
# 29935
# Beast Boxing Turbo
# genre: ['Action', ' Indie', ' Sports']
# 2013-11-19
# 29988
# A Walk in the Dark
# genre: ['Action', ' Indie']
# 2013-11-07
# 30013
# Vox
# genre: ['Action', ' Adventure', ' Indie', ' RPG', ' Early Access']
# 2013-11-12
# 30119
# 30198
# Artemis Spaceship Bridge Simulator
# genre: ['Action', ' Indie', ' Simulation']
# 2013-09-16
# 30243
# 30247
# Protocell
# genre: ['Indie']
# 2013-08-28
# 30292
# 30313
# DCS World
# genre: ['Free to Play', ' Simulation']
# Eagle Dynamics SA
# The Fighter Collection
# 2013-03-18
# 30322
# 30342
# Dota 2
# genre: ['Action', ' Free to Play', ' Strategy']
# Valve
# Valve
# 2013-07-09
# 30610
# 31228
# Lunar Flight
# genre: ['Indie', ' Simulation']
# Shovsoft
# Shovsoft
# 2012-01-15
# 32113
# GizmoVR Video Player
# genre: ['Utilities']
# DRI Digital Retail Innovations LTD
# DRI Digital Retail Innovations LTD
# 2018-01-05
# 32143
# Mortars VR
# genre: ['Action', ' Casual', ' Indie', ' Strategy', ' Early Access']
# Growl Interactive
# Growl Interactive
# 2018-01-03
# 32144
# 32146
# 32147
# The Gamble House
# 2016-11-19
# 32148
# 32150
# 32151
# Cricket Club
# genre: ['Casual', ' Indie', ' Simulation', ' Sports', ' Early Access']
# VersoVR
# VersoVR
# 2018-01-18
# 32159
# Log Challenge
# genre: ['Action', ' Casual', ' Indie', ' Sports']
# CGPills
# CGPills
# 2018-01-04
# 32165
# Marius
# genre: ['Free to Play']
# Granola Studios
# Granola Studios
# 2018-01-05
# 32166
# Snowmania
# genre: ['Casual', ' Indie']
# Legacy Productions
# VRena
# 2017-12-01
# 32168
# Icarus Six Sixty Six
# genre: ['Casual']
# Titmouse
# Titmouse
# 2018-01-04
# 32261
# My Little Pony
# 2017-12-19
# 32275
# VR Dunhuang
# genre: ['Adventure', ' Casual', ' RPG', ' Simulation']
# Beijing Gravitational Waves VR technology co.,LTD
# Beijing Gravitational Waves VR technology co.,LTD
# 2018-01-09
# 32280
# Unbound
# genre: ['Animation & Modeling', ' Design & Illustration', ' Early Access']
# Unbound Technologies, Inc.
# Unbound Technologies, Inc.
# 2018-01-08
# 32281
# COMPLEX a VR Puzzle Game
# genre: ['Casual', ' Indie', ' Simulation', ' Strategy']
# Rock AK Games
# Rock AK Games (AK)
# 2018-01-08
# 32284
# 32341
# The Homestead Invasion
# genre: ['Action', ' Adventure', ' Indie', ' Early Access']
# Ore
# Ore
# 2018-01-11
# 32342
# Paddington
# 2015-04-17
# 32416
# VR_PlayRoom
# genre: ['Action', ' Casual', ' Simulation', ' Sports']
# WeVery
# WeVery
# 2017-12-31
# 32439
# Namaste Virtual Yoga Retreat
# genre: ['Casual', ' Early Access']
# APG Studios LLC
# APG Studios LLC
# 2018-01-12
# 32440
# Primitive
# genre: ['Software Training', ' Early Access']
# John Voorhees
# Prime Software Systems, Inc.
# None
# 32451
# Light Tracer
# genre: ['Action', ' Adventure', ' Indie']
# Void Dimensions
# Oasis Games
# 2018-01-14
# 32456
# 32460
# 32462
# 32474
# Kamikazo VR
# genre: ['Action', ' Racing', ' Simulation']
# Refugio3D
# Refugio3D
# 2018-01-12
# 32482
# Boxplosion
# genre: ['Casual', ' Indie', ' Simulation']
# DNV
# DNV
# 2018-01-15
# 32484
# 32486
# Stunt Corgi VR
# genre: ['Simulation']
# Studio Roqovan, Inc.
# Studio Roqovan, Inc.
# 2018-01-15
# 32488
# Bike Rush
# genre: ['Action', ' Casual', ' Indie', ' Racing']
# Axyos Games
# Axyos Games
# 2018-01-15
# 32505
# GNOG
# genre: ['Adventure', ' Casual', ' Indie']
# KO_OP
# Double Fine Presents
# 2018-01-01
# 32509
# Zeppelin VR
# genre: ['Casual', ' Free to Play', ' Simulation', ' Early Access']
# think360.today
# think360.today
# 2018-06-08
# 32558
# 32559
# Day of Destruction
# genre: ['Action', ' Strategy']
# SynaptixGames, LLC
# SynaptixGames, LLC
# 2018-01-16
# 32575
# 32576
# Ship Ahoy Open BETA
# genre: ['Action', ' Free to Play', ' Indie', ' Massively Multiplayer', ' Simulation']
# OKAM Studio
# OKAM Studio
# 2018-01-10
# 32577
# SAMSKARA
# 2015-12-10
# 32580
# 32581
# Piwall
# genre: ['Casual', ' Free to Play', ' Indie', ' Simulation']
# Norain Games.
# JanduSoft S.L.
# 2018-01-18
# 32586
# Progeny VR
# genre: ['Indie', ' RPG', ' Simulation']
# Silverstring Media Inc.
# Silverstring Media Inc.
# 2018-01-16
# 32644
# BrickWorks 360
# 2017-09-22
# 2        None
# 33       None
# 35       None
# 56       None
# 57       None
# 70       None
# 78       None
# 109      None
# 111      None
# 347      None
# 1439     None
# 1474     None
# 1480     None
# 1576     None
# 1615     None
# 1616     None
# 1631     None
# 1638     None
# 1639     None
# 1692     None
# 1700     None
# 1701     None
# 1702     None
# 1703     None
# 2265     None
# 2362     None
# 2410     None
# 2707     None
# 2883     None
# 2928     None
#          ...
# 32261    None
# 32275    None
# 32280    None
# 32281    None
# 32284    None
# 32341    None
# 32342    None
# 32416    None
# 32439    None
# 32440    None
# 32451    None
# 32456    None
# 32460    None
# 32462    None
# 32474    None
# 32482    None
# 32484    None
# 32486    None
# 32488    None
# 32505    None
# 32509    None
# 32558    None
# 32559    None
# 32575    None
# 32576    None
# 32577    None
# 32580    None
# 32581    None
# 32586    None
# 32644    None
# Length: 3170, dtype: object

# %%
info = pd.read_csv('info.csv', index_col=0)
info
# Out:
#                                       title  \
# 2                                  OVERVIEW
# 33                                      NaN
# 35                            Second Nature
# 56                            The Iron Lady
# 57                               LIV Client
# 70                                Awakening
# 78                       Mech League Boxing
# 109                            The Defector
# 111                                     NaN
# 347                                     NaN
# 1439                            War Thunder
# 1474                                    NaN
# 1480                      Legend of Dungeon
# 1576                                    NaN
# 1615                                    NaN
# 1616                                    NaN
# 1631                                    NaN
# 1638                                    NaN
# 1639                                    NaN
# 1692                  Leadwerks Game Engine
# 1700                                    NaN
# 1701                                    NaN
# 1702                                    NaN
# 1703                                    NaN
# 2265                        Infinity Runner
# 2362                                    NaN
# 2410   NoLimits 2 Roller Coaster Simulation
# 2707                                    NaN
# 2883                          Volo Airsport
# 2928                             Subnautica
# ...                                     ...
# 32261                        My Little Pony
# 32275                           VR Dunhuang
# 32280                               Unbound
# 32281              COMPLEX a VR Puzzle Game
# 32284                                   NaN
# 32341                The Homestead Invasion
# 32342                            Paddington
# 32416                           VR_PlayRoom
# 32439          Namaste Virtual Yoga Retreat
# 32440                             Primitive
# 32451                          Light Tracer
# 32456                                   NaN
# 32460                                   NaN
# 32462                                   NaN
# 32474                           Kamikazo VR
# 32482                            Boxplosion
# 32484                                   NaN
# 32486                        Stunt Corgi VR
# 32488                             Bike Rush
# 32505                                  GNOG
# 32509                           Zeppelin VR
# 32558                                   NaN
# 32559                    Day of Destruction
# 32575                                   NaN
# 32576                   Ship Ahoy Open BETA
# 32577                              SAMSKARA
# 32580                                   NaN
# 32581                                Piwall
# 32586                            Progeny VR
# 32644                        BrickWorks 360
#
#                                                   genres  \
# 2                ['Adventure', ' Casual', ' Simulation']
# 33                                                   NaN
# 35                                                   NaN
# 56                                                   NaN
# 57     ['Utilities', ' Video Production', ' Web Publi...
# 70     ['Animation & Modeling', ' Design & Illustrati...
# 78                  ['Action', ' Simulation', ' Sports']
# 109                                                  NaN
# 111                                                  NaN
# 347                                                  NaN
# 1439   ['Action', ' Free to Play', ' Massively Multip...
# 1474                                                 NaN
# 1480                        ['Action', ' Indie', ' RPG']
# 1576                                                 NaN
# 1615                                                 NaN
# 1616                                                 NaN
# 1631                                                 NaN
# 1638                                                 NaN
# 1639                                                 NaN
# 1692   ['Animation & Modeling', ' Design & Illustrati...
# 1700                                                 NaN
# 1701                                                 NaN
# 1702                                                 NaN
# 1703                                                 NaN
# 2265                                ['Action', ' Indie']
# 2362                                                 NaN
# 2410                            ['Indie', ' Simulation']
# 2707                                                 NaN
# 2883   ['Action', ' Indie', ' Simulation', ' Sports',...
# 2928            ['Adventure', ' Indie', ' Early Access']
# ...                                                  ...
# 32261                                                NaN
# 32275    ['Adventure', ' Casual', ' RPG', ' Simulation']
# 32280  ['Animation & Modeling', ' Design & Illustrati...
# 32281   ['Casual', ' Indie', ' Simulation', ' Strategy']
# 32284                                                NaN
# 32341  ['Action', ' Adventure', ' Indie', ' Early Acc...
# 32342                                                NaN
# 32416    ['Action', ' Casual', ' Simulation', ' Sports']
# 32439                        ['Casual', ' Early Access']
# 32440             ['Software Training', ' Early Access']
# 32451                 ['Action', ' Adventure', ' Indie']
# 32456                                                NaN
# 32460                                                NaN
# 32462                                                NaN
# 32474               ['Action', ' Racing', ' Simulation']
# 32482                ['Casual', ' Indie', ' Simulation']
# 32484                                                NaN
# 32486                                     ['Simulation']
# 32488         ['Action', ' Casual', ' Indie', ' Racing']
# 32505                 ['Adventure', ' Casual', ' Indie']
# 32509  ['Casual', ' Free to Play', ' Simulation', ' E...
# 32558                                                NaN
# 32559                            ['Action', ' Strategy']
# 32575                                                NaN
# 32576  ['Action', ' Free to Play', ' Indie', ' Massiv...
# 32577                                                NaN
# 32580                                                NaN
# 32581  ['Casual', ' Free to Play', ' Indie', ' Simula...
# 32586                   ['Indie', ' RPG', ' Simulation']
# 32644                                                NaN
#
#                                                developer  \
# 2                                          Orbital Views
# 33                                                   NaN
# 35                                                   NaN
# 56                                                   NaN
# 57                                               LIV Inc
# 70                                             AwingSoft
# 78                                                 VRGEN
# 109                                                  NaN
# 111                                                  NaN
# 347                                                  NaN
# 1439                                Gaijin Entertainment
# 1474                                                 NaN
# 1480                                   Robot Loves Kitty
# 1576                                                 NaN
# 1615                                                 NaN
# 1616                                                 NaN
# 1631                                                 NaN
# 1638                                                 NaN
# 1639                                                 NaN
# 1692                                  Leadwerks Software
# 1700                                                 NaN
# 1701                                                 NaN
# 1702                                                 NaN
# 1703                                                 NaN
# 2265                                   Wales Interactive
# 2362                                                 NaN
# 2410                                           Ole Lange
# 2707                                                 NaN
# 2883                                        Ramjet Anvil
# 2928                        Unknown Worlds Entertainment
# ...                                                  ...
# 32261                                                NaN
# 32275  Beijing Gravitational Waves VR technology co.,LTD
# 32280                         Unbound Technologies, Inc.
# 32281                                      Rock AK Games
# 32284                                                NaN
# 32341                                                Ore
# 32342                                                NaN
# 32416                                             WeVery
# 32439                                    APG Studios LLC
# 32440                                      John Voorhees
# 32451                                    Void Dimensions
# 32456                                                NaN
# 32460                                                NaN
# 32462                                                NaN
# 32474                                          Refugio3D
# 32482                                                DNV
# 32484                                                NaN
# 32486                               Studio Roqovan, Inc.
# 32488                                        Axyos Games
# 32505                                              KO_OP
# 32509                                     think360.today
# 32558                                                NaN
# 32559                                 SynaptixGames, LLC
# 32575                                                NaN
# 32576                                        OKAM Studio
# 32577                                                NaN
# 32580                                                NaN
# 32581                                      Norain Games.
# 32586                            Silverstring Media Inc.
# 32644                                                NaN
#
#                                                publisher release_date
# 2                                          Orbital Views   2018-01-01
# 33                                                   NaN          NaN
# 35                                                   NaN   2017-09-18
# 56                                                   NaN   2012-04-10
# 57                                               LIV Inc   2018-01-01
# 70                                             AwingSoft   2017-08-15
# 78                                                 VRGEN   2018-01-10
# 109                                                  NaN   2018-01-06
# 111                                                  NaN          NaN
# 347                                                  NaN          NaN
# 1439                                Gaijin Entertainment   2013-08-15
# 1474                                                 NaN          NaN
# 1480                                                 NaN   2013-09-13
# 1576                                                 NaN          NaN
# 1615                                                 NaN          NaN
# 1616                                                 NaN          NaN
# 1631                                                 NaN          NaN
# 1638                                                 NaN          NaN
# 1639                                                 NaN          NaN
# 1692                                  Leadwerks Software   2014-01-06
# 1700                                                 NaN          NaN
# 1701                                                 NaN          NaN
# 1702                                                 NaN          NaN
# 1703                                                 NaN          NaN
# 2265                                   Wales Interactive   2014-07-14
# 2362                                                 NaN          NaN
# 2410                              Mad Data GmbH & Co. KG   2014-08-21
# 2707                                                 NaN          NaN
# 2883                                        Ramjet Anvil   2014-12-04
# 2928                        Unknown Worlds Entertainment   2018-01-23
# ...                                                  ...          ...
# 32261                                                NaN   2017-12-19
# 32275  Beijing Gravitational Waves VR technology co.,LTD   2018-01-09
# 32280                         Unbound Technologies, Inc.   2018-01-08
# 32281                                 Rock AK Games (AK)   2018-01-08
# 32284                                                NaN          NaN
# 32341                                                Ore   2018-01-11
# 32342                                                NaN   2015-04-17
# 32416                                             WeVery   2017-12-31
# 32439                                    APG Studios LLC   2018-01-12
# 32440                       Prime Software Systems, Inc.          NaN
# 32451                                        Oasis Games   2018-01-14
# 32456                                                NaN          NaN
# 32460                                                NaN          NaN
# 32462                                                NaN          NaN
# 32474                                          Refugio3D   2018-01-12
# 32482                                                DNV   2018-01-15
# 32484                                                NaN          NaN
# 32486                               Studio Roqovan, Inc.   2018-01-15
# 32488                                        Axyos Games   2018-01-15
# 32505                               Double Fine Presents   2018-01-01
# 32509                                     think360.today   2018-06-08
# 32558                                                NaN          NaN
# 32559                                 SynaptixGames, LLC   2018-01-16
# 32575                                                NaN          NaN
# 32576                                        OKAM Studio   2018-01-10
# 32577                                                NaN   2015-12-10
# 32580                                                NaN          NaN
# 32581                                     JanduSoft S.L.   2018-01-18
# 32586                            Silverstring Media Inc.   2018-01-16
# 32644                                                NaN   2017-09-22
#
# [3170 rows x 5 columns]

# %%
#info.to_csv('info.csv')
cleaned_games.loc[info.index, "developer"] = info['developer']
cleaned_games.loc[info.index, "publisher"] = info['publisher']
cleaned_games.loc[info.index, "title"] = info['title']
cleaned_games.loc[info.index, "genres"] = info['genres']
cleaned_games.loc[info.index, "release_date"] = info['release_date']

# %%
cleaned_games.head()
# Out:
#                                          description  \
# 0  [, About This Game, Do you love puzzles? What ...
# 1  [, About This Game, , Dear Bob,, I know you kn...
# 2  [, About This Game, OVERVIEW is a 30 minutes n...
# 3  [, About This Game, In Global Soccer Manager 2...
# 5  [, About This Game, , Survived By is a free-to...
#
#                                         developer  \
# 0                                        ChillFun
# 1                                           NOS3D
# 2                                   Orbital Views
# 3  gsmpcgame,globalsoccermanager,Andrea Hochstein
# 5                              Human Head Studios
#
#                                               genres        id parent_game  \
# 0                                         [Strategy]  773510.0         NaN
# 1  [Action, Casual, Indie, Massively Multiplayer,...  776170.0         NaN
# 2            ['Adventure', ' Casual', ' Simulation']  751110.0         NaN
# 3      [Casual, Indie, Simulation, Sports, Strategy]  625700.0         NaN
# 5  [Action, Free to Play, Indie, Massively Multip...  606140.0         NaN
#
#   parent_game_url  price         publisher release_date sentiment  \
# 0             NaN  14.99          ChillFun   2018-01-17       NaN
# 1             NaN    NaN             NOS3D     Jan 2018       NaN
# 2             NaN    NaN     Orbital Views   2018-01-01       NaN
# 3             NaN   9.99         gsmpcgame   2017-05-24  Positive
# 5             NaN    NaN  Digital Extremes   Early 2018       NaN
#
#                                                specs  \
# 0  [Single-player, Partial Controller Support, St...
# 1  [Multi-player, Online Multi-Player, Partial Co...
# 2  [Single-player, HTC Vive, Oculus Rift, Tracked...
# 3  [Single-player, Steam Achievements, Steam Trad...
# 5  [Multi-player, Online Multi-Player, MMO, Co-op...
#
#                                                 tags  \
# 0  [Strategy, Cartoon, Puzzle, First-Person, Phys...
# 1  [Early Access, Strategy, Action, Massively Mul...
# 2                    [Adventure, Casual, Simulation]
# 3  [Sports, Strategy, Simulation, Indie, Casual, ...
# 5  [Free to Play, Massively Multiplayer, Indie, R...
#
#                         title
# 0           The Hardest Thing
# 1              Serious Office
# 2                    OVERVIEW
# 3  Global Soccer Manager 2017
# 5                 Survived By

# %%
cleaned_games.drop(columns=['parent_game','parent_game_url'], inplace=True)

# %%
cleaned_games.head()
# Out:
#                                          description  \
# 0  [, About This Game, Do you love puzzles? What ...
# 1  [, About This Game, , Dear Bob,, I know you kn...
# 2  [, About This Game, OVERVIEW is a 30 minutes n...
# 3  [, About This Game, In Global Soccer Manager 2...
# 5  [, About This Game, , Survived By is a free-to...
#
#                                         developer  \
# 0                                        ChillFun
# 1                                           NOS3D
# 2                                   Orbital Views
# 3  gsmpcgame,globalsoccermanager,Andrea Hochstein
# 5                              Human Head Studios
#
#                                               genres        id  price  \
# 0                                         [Strategy]  773510.0  14.99
# 1  [Action, Casual, Indie, Massively Multiplayer,...  776170.0    NaN
# 2                  [Adventure,  Casual,  Simulation]  751110.0    NaN
# 3      [Casual, Indie, Simulation, Sports, Strategy]  625700.0   9.99
# 5  [Action, Free to Play, Indie, Massively Multip...  606140.0    NaN
#
#           publisher release_date sentiment  \
# 0          ChillFun   2018-01-17       NaN
# 1             NOS3D     Jan 2018       NaN
# 2     Orbital Views   2018-01-01       NaN
# 3         gsmpcgame   2017-05-24  Positive
# 5  Digital Extremes   Early 2018       NaN
#
#                                                specs  \
# 0  [Single-player, Partial Controller Support, St...
# 1  [Multi-player, Online Multi-Player, Partial Co...
# 2  [Single-player, HTC Vive, Oculus Rift, Tracked...
# 3  [Single-player, Steam Achievements, Steam Trad...
# 5  [Multi-player, Online Multi-Player, MMO, Co-op...
#
#                                                 tags  \
# 0  [Strategy, Cartoon, Puzzle, First-Person, Phys...
# 1  [Early Access, Strategy, Action, Massively Mul...
# 2                    [Adventure, Casual, Simulation]
# 3  [Sports, Strategy, Simulation, Indie, Casual, ...
# 5  [Free to Play, Massively Multiplayer, Indie, R...
#
#                         title
# 0           The Hardest Thing
# 1              Serious Office
# 2                    OVERVIEW
# 3  Global Soccer Manager 2017
# 5                 Survived By

# %% [markdown]
# #### Inspect data

# %%
# inspect missing ids, specs, tags, and genres

# Create variable with TRUE if id is missing
missing_id = pd.isnull(cleaned_games['id']) == True
# Create variable with TRUE if game specs is missing
missing_specs = pd.isnull(cleaned_games['specs']) == True
# Create variable with TRUE if game tags is missing
missing_tags = pd.isnull(cleaned_games['tags']) == True
# Create variable with TRUE if parent game is missing
missing_genres = pd.isnull(cleaned_games['genres']) == True

# Select all cases where all three fields are missing
no_spec_tag_genre = cleaned_games[missing_specs & missing_tags & missing_genres]
no_specs = cleaned_games[missing_specs]
no_tags = cleaned_games[missing_tags]
no_genres = cleaned_games[missing_genres]
no_id = cleaned_games[missing_id]

print('missing id: '+ str(len(no_id)))
print('missing all 3: '+ str(len(no_spec_tag_genre)))
print('missing specs: '+ str(len(no_specs)))
print('missing tags: '+ str(len(no_tags)))
print('missing genres: '+ str(len(no_genres)))

#cleaned_games.drop(no_tags.index, inplace=True)
# Out:
# missing id: 2
# missing all 3: 12
# missing specs: 680
# missing tags: 60
# missing genres: 1638

# %%
# inspect no id rows
no_id
# Out:
#                                            description  \
# 347                                                NaN
# 899  [, About This Game, Batman: Arkham City builds...
#
#                                       developer               genres  id  \
# 347                                         NaN                  NaN NaN
# 899  Rocksteady Studios,Feral Interactive (Mac)  [Action, Adventure] NaN
#
#      price                                          publisher release_date  \
# 347  39.99                                                NaN          NaN
# 899  19.99  Warner Bros. Interactive Entertainment, Feral ...   2012-09-07
#
#                    sentiment  \
# 347                      NaN
# 899  Overwhelmingly Positive
#
#                                                  specs  \
# 347                                                NaN
# 899  [Single-player, Steam Achievements, Steam Trad...
#
#                                                   tags  \
# 347                                                NaN
# 899  [Action, Open World, Batman, Adventure, Stealt...
#
#                                               title
# 347                                             NaN
# 899  Batman: Arkham City - Game of the Year Edition

# %%
# drop rows with no game id
cleaned_games.drop(no_id.index, inplace=True)

# %%
# inspect missing all 3
no_spec_tag_genre = no_spec_tag_genre.drop(347)
cleaned_games.drop(no_spec_tag_genre.index, inplace=True)

# %%
cleaned_games['id']=cleaned_games['id'].astype(int)
cleaned_games.head()
# Out:
#                                          description  \
# 0  [, About This Game, Do you love puzzles? What ...
# 1  [, About This Game, , Dear Bob,, I know you kn...
# 2  [, About This Game, OVERVIEW is a 30 minutes n...
# 3  [, About This Game, In Global Soccer Manager 2...
# 5  [, About This Game, , Survived By is a free-to...
#
#                                         developer  \
# 0                                        ChillFun
# 1                                           NOS3D
# 2                                   Orbital Views
# 3  gsmpcgame,globalsoccermanager,Andrea Hochstein
# 5                              Human Head Studios
#
#                                               genres      id  price  \
# 0                                         [Strategy]  773510  14.99
# 1  [Action, Casual, Indie, Massively Multiplayer,...  776170    NaN
# 2            ['Adventure', ' Casual', ' Simulation']  751110    NaN
# 3      [Casual, Indie, Simulation, Sports, Strategy]  625700   9.99
# 5  [Action, Free to Play, Indie, Massively Multip...  606140    NaN
#
#           publisher release_date sentiment  \
# 0          ChillFun   2018-01-17       NaN
# 1             NOS3D     Jan 2018       NaN
# 2     Orbital Views   2018-01-01       NaN
# 3         gsmpcgame   2017-05-24  Positive
# 5  Digital Extremes   Early 2018       NaN
#
#                                                specs  \
# 0  [Single-player, Partial Controller Support, St...
# 1  [Multi-player, Online Multi-Player, Partial Co...
# 2  [Single-player, HTC Vive, Oculus Rift, Tracked...
# 3  [Single-player, Steam Achievements, Steam Trad...
# 5  [Multi-player, Online Multi-Player, MMO, Co-op...
#
#                                                 tags  \
# 0  [Strategy, Cartoon, Puzzle, First-Person, Phys...
# 1  [Early Access, Strategy, Action, Massively Mul...
# 2                    [Adventure, Casual, Simulation]
# 3  [Sports, Strategy, Simulation, Indie, Casual, ...
# 5  [Free to Play, Massively Multiplayer, Indie, R...
#
#                         title
# 0           The Hardest Thing
# 1              Serious Office
# 2                    OVERVIEW
# 3  Global Soccer Manager 2017
# 5                 Survived By

# %%
print(len(pd.isnull(info['genres'])))
# Out:
# 3170

# %%
to_drop = no_tags.index.append(no_genres.index).append(no_specs.index)
to_drop_unique = to_drop.unique()

# %%
len(to_drop_unique)
# Out:
# 1943

# %%
for ix in to_drop_unique:
#     print(ix)
    try: 
        cleaned_games.drop(ix, inplace=True)
    except:
        pass
#to_drop_unique.drop([347, 5697, 7073, 7075, 7076, 7077, 7078, 9099, 21105, 21106, 24123, 27983])
#cleaned_games.drop(to_drop_unique)

# %%
len(cleaned_games)
# Out:
# 18021

# %%
cleaned_games.head()
# Out:
#                                          description  \
# 0  [, About This Game, Do you love puzzles? What ...
# 1  [, About This Game, , Dear Bob,, I know you kn...
# 2  [, About This Game, OVERVIEW is a 30 minutes n...
# 3  [, About This Game, In Global Soccer Manager 2...
# 5  [, About This Game, , Survived By is a free-to...
#
#                                         developer  \
# 0                                        ChillFun
# 1                                           NOS3D
# 2                                   Orbital Views
# 3  gsmpcgame,globalsoccermanager,Andrea Hochstein
# 5                              Human Head Studios
#
#                                               genres      id  price  \
# 0                                         [Strategy]  773510  14.99
# 1  [Action, Casual, Indie, Massively Multiplayer,...  776170    NaN
# 2                  [Adventure,  Casual,  Simulation]  751110    NaN
# 3      [Casual, Indie, Simulation, Sports, Strategy]  625700   9.99
# 5  [Action, Free to Play, Indie, Massively Multip...  606140    NaN
#
#           publisher release_date sentiment  \
# 0          ChillFun   2018-01-17       NaN
# 1             NOS3D     Jan 2018       NaN
# 2     Orbital Views   2018-01-01       NaN
# 3         gsmpcgame   2017-05-24  Positive
# 5  Digital Extremes   Early 2018       NaN
#
#                                                specs  \
# 0  [Single-player, Partial Controller Support, St...
# 1  [Multi-player, Online Multi-Player, Partial Co...
# 2  [Single-player, HTC Vive, Oculus Rift, Tracked...
# 3  [Single-player, Steam Achievements, Steam Trad...
# 5  [Multi-player, Online Multi-Player, MMO, Co-op...
#
#                                                 tags  \
# 0  [Strategy, Cartoon, Puzzle, First-Person, Phys...
# 1  [Early Access, Strategy, Action, Massively Mul...
# 2                    [Adventure, Casual, Simulation]
# 3  [Sports, Strategy, Simulation, Indie, Casual, ...
# 5  [Free to Play, Massively Multiplayer, Indie, R...
#
#                         title
# 0           The Hardest Thing
# 1              Serious Office
# 2                    OVERVIEW
# 3  Global Soccer Manager 2017
# 5                 Survived By

# %% [markdown]
# #### re-format date, clean/inspect price, clean sentiment

# %%
cleaned_games['release_date'] = cleaned_games['release_date'].apply(lambda x: standardize_date(x))

# %%
# drop NaN release dates -- these are games yet to be released
missing_date = cleaned_games[pd.isnull(cleaned_games['release_date'])]
for i in missing_date.index:
    try:
        cleaned_games.drop(i, inplace=True)
    except:
        pass

# %%
# inspect missing prices
len(cleaned_games.loc[pd.isnull(cleaned_games['price'])])
# Out:
# 664

# %%
# drop NaN prices -- some are not released, some are no longer availabe etc
missing_price = cleaned_games[pd.isnull(cleaned_games['price'])]
for i in missing_price.index:
    try:
        cleaned_games.drop(i, inplace=True)
    except:
        pass

# %%
cleaned_games['price'].unique()
# Out:
# array([14.99, 9.99, 19.99, 0.99, 1.99, 2.99, 'Free', 4.99, 8.99, 6.99,
#        3.99, 5.99, 12.99, 39.99, 'Free to Play', 7.99, 29.99, 10.99, 2.49,
#        15.99, 54.99, 89.99, 4.49, 18.99, 15.0, 11.99, 13.99, 0.98,
#        'Free Demo', 24.99, 'Free To Play', 99.99, 74.48, 160.91, 49.99,
#        19.98, 34.99, 59.95, 17.99, 59.99, 9.53, 0.74, 16.99, 689.75,
#        189.96, 13.37, 79.99, 23.99, 129.99, 12.0, 44.99, 15.98, 0.5, 72.49,
#        1.0, 0.59, 4.05, 1.47, 0.49, 31.99, 11.66, 4.79, 20.0, 9.98, 9.69,
#        'Play the Demo', 3.98, 9.0, 2.0, 1.9500000000000002, 1.79, 1.5,
#        2.66, 11.15, 1.48, 254.72, 6.66, 6.48, 3.34, 26.99, 399.99, 149.99,
#        10.97, 10.96, 2.47, 40.0, 199.99, 9.08, 3.33, 289.97, 202.76, 44.98,
#        20.99, 1.29, 'Free Mod', 11.96, 16.06, 5.35, 5.98,
#        1.5899999999999999, 2.3, 0.9500000000000001, 1.98, 172.24, 1.49,
#        0.79, 6.27, 24.94, 19.95, 10.74, 0.66, 7.12, 64.99, 5.83, 3.49,
#        69.99, 2.89, 4.0, 87.94, 8.98, 9.95, 19.12, 3.0, 25.0, 13.47, 36.67,
#        3.29, 299.99, 9.9, 12.89, 21.99, 1.87, 20.94, 7.49, 0.89, 10.0,
#        17.88, 2.48, 10.98, 139.92, 23.96, 13.52, 5.65, 119.99,
#        'Play WARMACHINE: Tactics Demo', 0.64, 139.95, 'Install Now', 43.96,
#        8.13, 13.98, 14.95, 32.99, 'Play for Free!', 61.99, 'Third-party'], dtype=object)

# %%
# clean price data
cleaned_games.loc[cleaned_games['price'] == 'Free', 'price'] = 0.0
cleaned_games.loc[cleaned_games['price'] == 'Free Demo', 'price'] = 0.0
cleaned_games.loc[cleaned_games['price'] == 'Play Now', 'price'] = 0.0
cleaned_games.loc[cleaned_games['price'] == 'Free to Play', 'price'] = 0.0
cleaned_games.loc[cleaned_games['price'] == 'Free To Play', 'price'] = 0.0
cleaned_games.loc[cleaned_games['price'] == 'Install Theme', 'price'] = 0.0
cleaned_games.loc[cleaned_games['price'] == 'Third-party', 'price'] = 0.0
cleaned_games.loc[cleaned_games['price'] == 'Play for Free!', 'price'] = 0.0
cleaned_games.loc[cleaned_games['price'] == 'Install Now', 'price'] = 0.0

# %%
cleaned_games['price'].unique()
# Out:
# array([14.99, 9.99, 19.99, 0.99, 1.99, 2.99, 0.0, 4.99, 8.99, 6.99, 3.99,
#        5.99, 12.99, 39.99, 7.99, 29.99, 10.99, 2.49, 15.99, 54.99, 89.99,
#        4.49, 18.99, 15.0, 11.99, 13.99, 0.98, 24.99, 99.99, 74.48, 160.91,
#        49.99, 19.98, 34.99, 59.95, 17.99, 59.99, 9.53, 0.74, 16.99, 689.75,
#        189.96, 13.37, 79.99, 23.99, 129.99, 12.0, 44.99, 15.98, 0.5, 72.49,
#        1.0, 0.59, 4.05, 1.47, 0.49, 31.99, 11.66, 4.79, 20.0, 9.98, 9.69,
#        'Play the Demo', 3.98, 9.0, 2.0, 1.9500000000000002, 1.79, 1.5,
#        2.66, 11.15, 1.48, 254.72, 6.66, 6.48, 3.34, 26.99, 399.99, 149.99,
#        10.97, 10.96, 2.47, 40.0, 199.99, 9.08, 3.33, 289.97, 202.76, 44.98,
#        20.99, 1.29, 'Free Mod', 11.96, 16.06, 5.35, 5.98,
#        1.5899999999999999, 2.3, 0.9500000000000001, 1.98, 172.24, 1.49,
#        0.79, 6.27, 24.94, 19.95, 10.74, 0.66, 7.12, 64.99, 5.83, 3.49,
#        69.99, 2.89, 4.0, 87.94, 8.98, 9.95, 19.12, 3.0, 25.0, 13.47, 36.67,
#        3.29, 299.99, 9.9, 12.89, 21.99, 1.87, 20.94, 7.49, 0.89, 10.0,
#        17.88, 2.48, 10.98, 139.92, 23.96, 13.52, 5.65, 119.99,
#        'Play WARMACHINE: Tactics Demo', 0.64, 139.95, 43.96, 8.13, 13.98,
#        14.95, 32.99, 61.99], dtype=object)

# %%
index_1 = cleaned_games.loc[cleaned_games['price'] == 'Starting at $449.00'].index
index_2 = cleaned_games.loc[cleaned_games['price'] == 'Free Mod'].index
index_3 = cleaned_games.loc[cleaned_games['price'] == 'Free Movie'].index
index_4 = cleaned_games.loc[cleaned_games['price'] == 'Play WARMACHINE: Tactics Demo'].index
index_5 = cleaned_games.loc[cleaned_games['price'] == 'Free to Try'].index
index_6 = cleaned_games.loc[cleaned_games['price'] == 'Play the Demo'].index
print(index_1, index_2, index_3, index_4, index_5, index_6)
# Out:
# Int64Index([], dtype='int64') Int64Index([13421, 27416, 28521, 28522], dtype='int64') Int64Index([], dtype='int64') Int64Index([28187], dtype='int64') Int64Index([], dtype='int64') Int64Index([6101], dtype='int64')

# %%
to_drop = index_1.append(index_2).append(index_3).append(index_4).append(index_5).append(index_6)

# %%
for i in to_drop:
    try:
        cleaned_games.drop(i, inplace=True)
    except:
        pass

# %%
cleaned_games['price'].unique()
# Out:
# array([14.99, 9.99, 19.99, 0.99, 1.99, 2.99, 0.0, 4.99, 8.99, 6.99, 3.99,
#        5.99, 12.99, 39.99, 7.99, 29.99, 10.99, 2.49, 15.99, 54.99, 89.99,
#        4.49, 18.99, 15.0, 11.99, 13.99, 0.98, 24.99, 99.99, 74.48, 160.91,
#        49.99, 19.98, 34.99, 59.95, 17.99, 59.99, 9.53, 0.74, 16.99, 689.75,
#        189.96, 13.37, 79.99, 23.99, 129.99, 12.0, 44.99, 15.98, 0.5, 72.49,
#        1.0, 0.59, 4.05, 1.47, 0.49, 31.99, 11.66, 4.79, 20.0, 9.98, 9.69,
#        3.98, 9.0, 2.0, 1.9500000000000002, 1.79, 1.5, 2.66, 11.15, 1.48,
#        254.72, 6.66, 6.48, 3.34, 26.99, 399.99, 149.99, 10.97, 10.96, 2.47,
#        40.0, 199.99, 9.08, 3.33, 289.97, 202.76, 44.98, 20.99, 1.29, 11.96,
#        16.06, 5.35, 5.98, 1.5899999999999999, 2.3, 0.9500000000000001,
#        1.98, 172.24, 1.49, 0.79, 6.27, 24.94, 19.95, 10.74, 0.66, 7.12,
#        64.99, 5.83, 3.49, 69.99, 2.89, 4.0, 87.94, 8.98, 9.95, 19.12, 3.0,
#        25.0, 13.47, 36.67, 3.29, 299.99, 9.9, 12.89, 21.99, 1.87, 20.94,
#        7.49, 0.89, 10.0, 17.88, 2.48, 10.98, 139.92, 23.96, 13.52, 5.65,
#        119.99, 0.64, 139.95, 43.96, 8.13, 13.98, 14.95, 32.99, 61.99], dtype=object)

# %%
print(len(cleaned_games.loc[cleaned_games['sentiment'] == 'Overwhelmingly Positive']))
print(len(cleaned_games.loc[cleaned_games['sentiment'] == 'Very Positive']))
print(len(cleaned_games.loc[cleaned_games['sentiment'] == 'Positive']))
print(len(cleaned_games.loc[cleaned_games['sentiment'] == 'Mostly Positive']))

print(len(cleaned_games.loc[cleaned_games['sentiment'] == 'Mixed']))

print(len(cleaned_games.loc[cleaned_games['sentiment'] == 'Mostly Negative']))
print(len(cleaned_games.loc[cleaned_games['sentiment'] == 'Negative']))
print(len(cleaned_games.loc[cleaned_games['sentiment'] == 'Very Negative']))
print(len(cleaned_games.loc[cleaned_games['sentiment'] == 'Overwhelmingly Negative']))

sentiment_mapping = {'Mixed': 0, 'Mostly Positive': 1, 'Positive': 2, 'Very Positive': 3, 'Overwhelmingly Positive': 4, 'Mostly Negative': -1, 'Negative': -2, 'Very Negative': -3, 'Overwhelmingly Negative': -4 }
cleaned_games.sentiment.unique()
# Out:
# 278
# 3249
# 1967
# 2216
# 3363
# 647
# 112
# 25
# 6
# array([nan, 'Positive', '4 user reviews', 'Mixed', '1 user reviews',
#        '3 user reviews', '5 user reviews', 'Overwhelmingly Positive',
#        'Very Positive', 'Mostly Positive', '8 user reviews',
#        '2 user reviews', '7 user reviews', '6 user reviews', 'Negative',
#        'Mostly Negative', '9 user reviews', 'Overwhelmingly Negative',
#        'Very Negative'], dtype=object)

# %%
def parse_sentiment(row):
    """This function mapps the sentiments into numerical values"""
    sentiment_mapping = {'Mixed': 0, 'Mostly Positive': 1, 'Positive': 2, 'Very Positive': 3, 'Overwhelmingly Positive': 4, 'Mostly Negative': -1, 'Negative': -2, 'Very Negative': -3, 'Overwhelmingly Negative': -4 }
    if row['sentiment'] in sentiment_mapping:
        return sentiment_mapping[row['sentiment']]
    else:
        return 0
cleaned_games['sentiment_num'] = cleaned_games.apply(parse_sentiment, axis=1)

# %%
cleaned_games = cleaned_games.drop(columns='sentiment')

# %%
cleaned_games.head()
# Out:
#                                          description  \
# 0  [, About This Game, Do you love puzzles? What ...
# 3  [, About This Game, In Global Soccer Manager 2...
# 6  [, About This Game, Experience the pureness an...
# 7  [, About This Game, See how a game created by ...
# 8  [, About This Game, From the creators of Rogue...
#
#                                         developer  \
# 0                                        ChillFun
# 3  gsmpcgame,globalsoccermanager,Andrea Hochstein
# 6                                       Media Art
# 7                                           AIREM
# 8                               Cellar Door Games
#
#                                           genres      id  price  \
# 0                                     [Strategy]  773510  14.99
# 3  [Casual, Indie, Simulation, Sports, Strategy]  625700   9.99
# 6                            [Adventure, Casual]  770880   9.99
# 7                             [Adventure, Indie]  725780   9.99
# 8                [Action, Adventure, Indie, RPG]  416600  19.99
#
#            publisher release_date  \
# 0           ChillFun   2018-01-17
# 3          gsmpcgame   2017-05-24
# 6     Big Fish Games   2018-01-17
# 7      IQ Publishing   2018-01-17
# 8  Cellar Door Games   2018-01-17
#
#                                                specs  \
# 0  [Single-player, Partial Controller Support, St...
# 3  [Single-player, Steam Achievements, Steam Trad...
# 6                                    [Single-player]
# 7           [Single-player, Full controller support]
# 8  [Single-player, Co-op, Online Co-op, Local Co-...
#
#                                                 tags  \
# 0  [Strategy, Cartoon, Puzzle, First-Person, Phys...
# 3  [Sports, Strategy, Simulation, Indie, Casual, ...
# 6                                [Adventure, Casual]
# 7                         [Adventure, Indie, Horror]
# 8  [Indie, Action, Adventure, RPG, Co-op, Beat 'e...
#
#                            title  sentiment_num
# 0              The Hardest Thing              0
# 3     Global Soccer Manager 2017              2
# 6  Love Story: The Beach Cottage              0
# 7                   PLAY WITH ME              0
# 8              Full Metal Furies              0

# %%
print(len(cleaned_games))
# Out:
# 17098

# %%
# check for missing data
check_df(cleaned_games)
# Out:
# description: object    (has NaN)
# developer: object    (has NaN)
# genres: object
# id: int64
# price: object
# publisher: object    (has NaN)
# release_date: object
# specs: object
# tags: object
# title: object
# sentiment_num: int64

# %%
cleaned_games['description'].fillna('', inplace=True)

# %%
cleaned_games[pd.isnull(cleaned_games['developer'])]
# Out:
#                                              description developer  \
# 278    [, About This Game, Get the Shot. Get the Game...       NaN
# 657    [, About This Game, Welcome to the new Wild We...       NaN
# 1429   [, Reviews, , “Somewhere during the journey yo...       NaN
# 1476   [, Reviews, , “If you can endure a half hour’s...       NaN
# 1493   [, About This Game, Cast down from power by a ...       NaN
# 1506   [, Reviews, , “If you're not the diehard RPGer...       NaN
# 1507   [, Reviews, , “Players who engage in get a won...       NaN
# 1513   [, About This Game, In 2455 AD, Kage Mishima u...       NaN
# 1517   [, About This Game, , 20 years after the origi...       NaN
# 1525   [, Reviews, , “The flow overall is excellent, ...       NaN
# 1531   [, About This Game, Urban Chaos throws you int...       NaN
# 1577   [, About This Game, ** Please note: a remaster...       NaN
# 1613   [, Reviews, , “The Shivah fits a compelling mo...       NaN
# 2367   [, About This Game, The colony ship, Maximus, ...       NaN
# 2545   [, Reviews, , “...just think of your typical r...       NaN
# 3241   [, GET HATE FREE HEROES, , http://store.steamp...       NaN
# 3726   [, About This Game, Forge Quest is a dungeon c...       NaN
# 4165   [, About This Game, Secret of Magia is an acti...       NaN
# 6679   [, About This Game, , About This Game, Streame...       NaN
# 7112   [, Steam Greenlight, , Thank you!, , , About T...       NaN
# 7217   [, About This Game, Old School Tower Defence g...       NaN
# 8202   [, About This Game, Santa Claus lost his prese...       NaN
# 8487   [, About This Game, You've lost your job, wife...       NaN
# 8614   [, About This Game, Cheerful game with the dra...       NaN
# 8616   [, About This Game, In the far-away cold count...       NaN
# 10497  [, About This Game, If you like cars, do you l...       NaN
# 10699  [, About This Game, Space beckons us with its ...       NaN
# 14516  [, About This Game, Tournament of the Mages. A...       NaN
# 15350  [, About This Game, In the marvelous Japanese ...       NaN
# 15971  [, About This Game, Mad Arkanoid is a classic ...       NaN
# ...                                                  ...       ...
# 20404  [, About This Game, , Melon Simulator™ is a ch...       NaN
# 21247  [, About This Game, , Berserk: The Cataclysm, ...       NaN
# 22643  [, About This Game, Deathwave is a arcade shoo...       NaN
# 23631  [, About This Game, SAMOLIOTIK is a stylish sh...       NaN
# 24848  [, About This Game, Battle Zombies, save your ...       NaN
# 27360  [, About This Game, , gravilon, is an inventiv...       NaN
# 28048  [, Reviews, , “The offline game is one of the ...       NaN
# 28807  [, About This Game, , Join in a quest to chang...       NaN
# 29867  [, Reviews, , “If this had been released on Am...       NaN
# 29911  [, About This Game, Vector is an exciting, arc...       NaN
# 29925  [, About This Game, Dead Sky takes place admis...       NaN
# 29935  [, Reviews, , “Beast Boxing Turbo is a stellar...       NaN
# 29981  [, Reviews, , 4/5 –, Corrupted Cartridge, 6/10...       NaN
# 29988  [, Reviews, , “The stark beauty of A Walk in t...       NaN
# 29998  [, About This Game, Told as a “Wuxia” story, w...       NaN
# 30013  [, About This Game, Vox is a voxel based, acti...       NaN
# 30058  [, Steam Greenlight, , , , About This Game, As...       NaN
# 30065  [, Reviews, , “Sparkle 2 Evo is probably one o...       NaN
# 30124  [, About This Game, Join Sylvester "Sly" Boots...       NaN
# 30138  [, About This Game, A once thriving network of...       NaN
# 30148  [, About This Game, Built by a mad baron to br...       NaN
# 30168  [, Reviews, , “Odium it's an example of what a...       NaN
# 30187  [, Reviews, , “Quite absorbing, very atmospher...       NaN
# 30198  [, Reviews, , “Artemis isn’t an official Star ...       NaN
# 30252  [, About This Game, Michel Ancel, the celebrat...       NaN
# 31190  [, Just Updated, , All SEGA MegaDrive/Genesis ...       NaN
# 31911  [, About This Game, You ‘da Boss! Move it bett...       NaN
# 31918  [, About This Game, Solve exciting criminal ca...       NaN
# 31948  [, Reviews, , "A challenge worth taking on. On...       NaN
# 32209  [, Special Offer, , Officially Licensed Tycoon...       NaN
#
#                                                   genres      id  price  \
# 278                                 [Simulation, Sports]   12690   9.99
# 657                                  [Action, Adventure]   33420   9.99
# 1429                                             [Indie]  239350  14.99
# 1476   [Action, Adventure, Indie, Simulation, Early A...  246300   9.99
# 1493                                            [Action]  242960   6.99
# 1506                                               [RPG]  253940   4.99
# 1507                              [Simulation, Strategy]  227020  19.99
# 1513                                            [Action]  242980   6.99
# 1517                            [Action, Adventure, RPG]  245730   9.99
# 1525                                [Action, Indie, RPG]  248710   4.99
# 1531                                            [Action]  243060   6.99
# 1577                                 [Action, Adventure]  247910  14.99
# 1613                                  [Adventure, Indie]  252370   4.99
# 2367                                [Action, Indie, RPG]  315260   4.99
# 2545                [Action, Adventure, Indie, Strategy]  230860  14.99
# 3241   [Adventure, Indie, Massively Multiplayer, RPG,...  398970  15.98
# 3726          ['Action', ' Adventure', ' Indie', ' RPG']  249950   9.99
# 4165                     [Action, Adventure, Indie, RPG]  396160   1.99
# 6679    ['Casual', ' Indie', ' Simulation', ' Strategy']  519180   0.99
# 7112                          [Adventure, Casual, Indie]  533640   0.99
# 7217                   ['Action', ' Indie', ' Strategy']  537860   0.99
# 8202                     ['Action', ' Indie', ' Sports']  586090   0.99
# 8487                 ['Action', ' Indie', ' Simulation']  596170   0.99
# 8614                 ['Casual', ' Indie', ' Simulation']  603570   0.99
# 8616       ['Action', ' Adventure', ' Casual', ' Indie']  604810   0.99
# 10497       ['Casual', ' Indie', ' Racing', ' Strategy']  619730   0.99
# 10699                    ['Action', ' Casual', ' Indie']  673760   0.99
# 14516                 ['Adventure', ' Casual', ' Indie']  661080   0.99
# 15350                    ['Action', ' Casual', ' Indie']  695350   0.99
# 15971                   ['Action', ' Casual', ' Sports']  673780   0.99
# ...                                                  ...     ...    ...
# 20404          [Action, Indie, Simulation, Early Access]  437550   4.99
# 21247  [Free to Play, Massively Multiplayer, RPG, Str...  486160      0
# 22643              ['Action', ' Indie', ' Early Access']  463870   4.99
# 23631                    ['Action', ' Casual', ' Indie']  449680   0.99
# 24848                         [Indie, RPG, Early Access]  412860   3.99
# 27360               ['Adventure', ' Indie', ' Strategy']  355150   1.99
# 28048                  [Adventure, Indie, RPG, Strategy]  335900   4.99
# 28807                  ['Action', ' Indie', ' Strategy']  306260   4.99
# 29867                    ['Action', ' Casual', ' Indie']  259780   4.99
# 29911                                    [Action, Indie]  248970   6.99
# 29925                               ['Action', ' Indie']  259700   1.99
# 29935                    ['Action', ' Indie', ' Sports']  259490   4.99
# 29981                                       [Simulation]  260510   2.99
# 29988                               ['Action', ' Indie']  248730   6.99
# 29998                         [Action, Adventure, Indie]  240660   9.99
# 30013  ['Action', ' Adventure', ' Indie', ' RPG', ' E...  252770   9.99
# 30058                               [Action, Indie, RPG]  252030  14.99
# 30065                [Action, Casual, Indie, Simulation]  253650   4.99
# 30124                                              [RPG]  242940   6.99
# 30138                                       [Simulation]  243040   6.99
# 30148                                [Action, Adventure]  245010   6.99
# 30168                                    [RPG, Strategy]  253920   4.99
# 30187                                        [Adventure]  248490   5.99
# 30198                ['Action', ' Indie', ' Simulation']  247350   6.99
# 30252                                [Action, Adventure]  242550  29.99
# 31190                                           [Action]  211206   2.99
# 31911                                       [Simulation]   33730   9.99
# 31918                                   [Action, Racing]   11390   9.99
# 31948                                 [Adventure, Indie]   11370   4.99
# 32209                                       [Simulation]    9730   9.99
#
#                                    publisher release_date  \
# 278                       ValuSoft, Retroism   2009-07-07
# 657                                  Ubisoft   2011-09-13
# 1429                               Mossmouth   2013-08-08
# 1476                         Matthew C Cohen   2012-10-19
# 1493                             Square Enix   2002-03-29
# 1506                     Topware Interactive   1999-10-31
# 1507                   Kalypso Media Digital   2013-09-27
# 1513                             Square Enix   2000-05-23
# 1517                                 Ubisoft   2013-10-01
# 1525             Forever Entertainment S. A.   2013-07-07
# 1531          Square Enix, Eidos Interactive   1999-11-30
# 1577                               Rebellion   2013-10-31
# 1613                        Wadjet Eye Games   2013-11-21
# 2367                               Meridian4   2005-11-15
# 2545                          Turtle Sandbox   2014-09-19
# 3241                             NSE CIRCUIT   2015-11-05
# 3726                                     NaN   2015-05-22
# 4165                                EQ-Games   2015-08-21
# 6679                                     NaN   2016-08-23
# 7112                              Atriagames   2016-09-30
# 7217                                     NaN   2016-10-12
# 8202                                     NaN   2017-01-27
# 8487                                     NaN   2017-02-24
# 8614                                     NaN   2017-03-08
# 8616                                     NaN   2017-03-08
# 10497                                    NaN   2017-08-27
# 10699                                    NaN   2017-09-12
# 14516                                    NaN   2017-10-05
# 15350                                    NaN   2017-08-31
# 15971                                    NaN   2017-08-03
# ...                                      ...          ...
# 20404                    Delirious &amp; Co.   2016-11-03
# 21247                              IDC/Games   2016-09-22
# 22643                                    NaN   2016-06-09
# 23631                                    NaN   2016-03-25
# 24848                         Gateside Games   2015-12-03
# 27360                                    NaN   2015-03-30
# 28048                            NSE CIRCUIT   2014-12-09
# 28807                                    NaN   2014-07-25
# 29867                                    NaN   2013-12-06
# 29911                             Nekki GmbH   2013-12-04
# 29925                                    NaN   2013-11-22
# 29935                                    NaN   2013-11-19
# 29981                         Strategy First   2013-11-18
# 29988                                    NaN   2013-11-07
# 29998                            Origo Games   2013-11-11
# 30013                                    NaN   2013-11-12
# 30058                     Endlessfluff Games   2013-09-08
# 30065            Forever Entertainment S. A.   2011-11-20
# 30124                            Square Enix   2001-06-27
# 30138                            Square Enix   2001-06-19
# 30148                            Square Enix   1998-06-25
# 30168                Topware Interactive ACE   1999-12-31
# 30187  United Independent Entertainment GmbH   2013-09-20
# 30198                                    NaN   2013-09-16
# 30252                                Ubisoft   2013-09-03
# 31190                                   SEGA   2012-05-02
# 31911                     ValuSoft, Retroism   2009-09-23
# 31918                              Meridian4   2009-08-27
# 31948                              Meridian4   2008-09-07
# 32209                               Retroism   2006-02-21
#
#                                                    specs  \
# 278                                      [Single-player]
# 657    [Single-player, Multi-player, Co-op, Steam Ach...
# 1429   [Single-player, Shared/Split Screen, Steam Ach...
# 1476   [Single-player, Steam Trading Cards, Partial C...
# 1493                                     [Single-player]
# 1506   [Single-player, Steam Trading Cards, Steam Cloud]
# 1507   [Single-player, Multi-player, Steam Achievemen...
# 1513                                     [Single-player]
# 1517                                     [Single-player]
# 1525                                     [Single-player]
# 1531                                     [Single-player]
# 1577   [Single-player, Co-op, Steam Achievements, Ste...
# 1613   [Single-player, Steam Achievements, Steam Trad...
# 2367                                     [Single-player]
# 2545   [Single-player, Multi-player, Steam Achievemen...
# 3241   [Single-player, Multi-player, Online Multi-Pla...
# 3726   [Single-player, Multi-player, Co-op, Cross-Pla...
# 4165   [Single-player, Steam Achievements, Full contr...
# 6679                                     [Single-player]
# 7112                [Single-player, Steam Trading Cards]
# 7217   [Single-player, Steam Achievements, Steam Trad...
# 8202   [Single-player, Steam Achievements, Steam Trad...
# 8487   [Single-player, Steam Achievements, Steam Trad...
# 8614   [Single-player, Steam Achievements, Steam Trad...
# 8616   [Single-player, Steam Achievements, Steam Trad...
# 10497  [Single-player, Steam Achievements, Steam Trad...
# 10699  [Single-player, Steam Achievements, Steam Trad...
# 14516                                    [Single-player]
# 15350                [Single-player, Steam Achievements]
# 15971                [Single-player, Steam Achievements]
# ...                                                  ...
# 20404  [Single-player, Multi-player, Online Multi-Pla...
# 21247  [Single-player, Multi-player, Online Multi-Pla...
# 22643  [Single-player, Steam Achievements, Steam Trad...
# 23631  [Single-player, Steam Achievements, Steam Trad...
# 24848  [Single-player, Steam Achievements, Partial Co...
# 27360  [Single-player, Steam Trading Cards, Partial C...
# 28048  [Single-player, Steam Achievements, Steam Trad...
# 28807  [Single-player, Steam Achievements, Full contr...
# 29867  [Single-player, Full controller support, Steam...
# 29911  [Single-player, Steam Achievements, Full contr...
# 29925  [Single-player, Multi-player, Co-op, Cross-Pla...
# 29935  [Single-player, Steam Achievements, Partial Co...
# 29981                                    [Single-player]
# 29988  [Single-player, Steam Achievements, Full contr...
# 29998  [Single-player, Shared/Split Screen, Steam Ach...
# 30013  [Single-player, Multi-player, Co-op, Full cont...
# 30058  [Single-player, Steam Achievements, Steam Trad...
# 30065  [Single-player, Steam Achievements, Full contr...
# 30124                                    [Single-player]
# 30138                                    [Single-player]
# 30148                                    [Single-player]
# 30168  [Single-player, Steam Trading Cards, Steam Cloud]
# 30187                       [Single-player, Steam Cloud]
# 30198         [Multi-player, Co-op, Shared/Split Screen]
# 30252               [Single-player, Shared/Split Screen]
# 31190               [Single-player, Shared/Split Screen]
# 31911                                    [Single-player]
# 31918                                    [Single-player]
# 31948                                    [Single-player]
# 32209                                    [Single-player]
#
#                                                     tags  \
# 278               [Simulation, Hunting, Sports, America]
# 657    [Action, Adventure, FPS, Co-op, Western, Shoot...
# 1429   [Rogue-like, Platformer, Indie, Difficult, 2D,...
# 1476   [Early Access, Horror, Indie, Adventure, Simul...
# 1493   [Action, Vampire, Adventure, Dark Fantasy, Fan...
# 1506   [RPG, JRPG, Turn-Based, Singleplayer, Isometri...
# 1507   [Strategy, Simulation, Trading, Historical, Ec...
# 1513   [Action, FPS, Classic, Time Travel, Singleplay...
# 1517   [Action, Adventure, RPG, Platformer, Cyberpunk...
# 1525   [RPG, Action, Indie, Hack and Slash, Action RP...
# 1531   [Action, Female Protagonist, Classic, Third Pe...
# 1577   [Zombies, Action, Co-op, Adventure, Third-Pers...
# 1613   [Adventure, Point & Click, Indie, Noir, Single...
# 2367   [RPG, Action, Indie, Sci-fi, Action RPG, Hack ...
# 2545   [Indie, Local Multiplayer, 2D, Multiplayer, St...
# 3241   [Massively Multiplayer, Indie, Strategy, RPG, ...
# 3726   [RPG, Adventure, Action, Indie, Voxel, Co-op, ...
# 4165   [RPGMaker, Anime, RPG, Indie, Adventure, Actio...
# 6679   [Casual, Simulation, Indie, Strategy, Management]
# 7112                          [Indie, Casual, Adventure]
# 7217            [Strategy, Action, Indie, Tower Defense]
# 8202       [Indie, Action, Sports, Psychological Horror]
# 8487                         [Simulation, Indie, Action]
# 8614                         [Indie, Casual, Simulation]
# 8616                  [Indie, Casual, Action, Adventure]
# 10497                  [Strategy, Indie, Casual, Racing]
# 10699  [Action, Indie, Casual, Shoot 'Em Up, Side Scr...
# 14516                         [Adventure, Indie, Casual]
# 15350                            [Action, Indie, Casual]
# 15971                           [Casual, Sports, Action]
# ...                                                  ...
# 20404          [Early Access, Simulation, Action, Indie]
# 21247  [Free to Play, Strategy, Massively Multiplayer...
# 22643                 [Early Access, Indie, Action, FPS]
# 23631  [Illuminati, Casual, Indie, Action, Memes, Pix...
# 24848  [Early Access, Indie, RPG, Zombies, Funny, Sto...
# 27360  [Indie, Platformer, Adventure, Strategy, Puzzl...
# 28048  [RPG, Adventure, Indie, RPGMaker, Strategy, Fa...
# 28807  [Strategy, Tower Defense, Indie, Action, Adven...
# 29867    [Casual, Indie, Action, Pixel Graphics, Arcade]
# 29911  [Parkour, Action, Indie, Platformer, Singlepla...
# 29925                           [Indie, Action, Zombies]
# 29935  [Sports, Action, Indie, Female Protagonist, Fi...
# 29981       [Simulation, Management, Sports, Basketball]
# 29988  [Indie, Platformer, Action, Difficult, 2D, Gre...
# 29998  [Action, Indie, Adventure, Hack and Slash, 2D,...
# 30013  [Early Access, RPG, Indie, Adventure, Action, ...
# 30058  [Metroidvania, Action, RPG, Platformer, Indie,...
# 30065  [Casual, Indie, Simulation, Action, Singleplay...
# 30124  [RPG, Cyberpunk, Sci-fi, Comedy, Classic, Turn...
# 30138  [Simulation, Management, Sci-fi, Space, City B...
# 30148                                [Action, Adventure]
# 30168  [RPG, Strategy, Turn-Based, Post-apocalyptic, ...
# 30187  [Adventure, Point & Click, Horror, First-Perso...
# 30198  [Simulation, Indie, Action, Space, Co-op, Mult...
# 30252  [Platformer, Great Soundtrack, Local Co-Op, Ad...
# 31190                  [Action, Beat 'em up, 2D, Arcade]
# 31911                              [Simulation, Driving]
# 31918  [Racing, Action, Open World, Singleplayer, Dri...
# 31948  [Adventure, Point & Click, Indie, Sci-fi, Cybe...
# 32209             [Simulation, Management, City Builder]
#
#                                      title  sentiment_num
# 278                 Hunting Unlimited 2010              1
# 657            Call of Juarez®: The Cartel              0
# 1429                              Spelunky              3
# 1476                            Paranormal              0
# 1493          Blood Omen 2: Legacy of Kain              1
# 1506                         Septerra Core              1
# 1507                        Rise of Venice              0
# 1513                             Daikatana              0
# 1517                             Flashback              0
# 1525                               Iesabel             -1
# 1531                           Urban Chaos              3
# 1577      Sniper Elite: Nazi Zombie Army 2              3
# 1613                            The Shivah              3
# 2367                            Space Hack              0
# 2545                          Cannon Brawl              3
# 3241             Fasaria World: Browser MO              0
# 3726                           Forge Quest              3
# 4165                       Secret Of Magia              0
# 6679                    Streamer Simulator             -2
# 7112                                VoxreD              0
# 7217                  Ballistic Protection              0
# 8202                               Snowman              0
# 8487                       Magazime Editor              0
# 8614                         Cowboy zombie              2
# 8616                        Yeti Adventure              0
# 10497                           Mad Driver              0
# 10699                         Air Tactical              2
# 14516                             WarMages              1
# 15350                    Time Ninja Sakura              0
# 15971                         Mad Arkanoid              1
# ...                                    ...            ...
# 20404                     Melon Simulator™              2
# 21247               Berserk: The Cataclysm             -1
# 22643                            Deathwave              0
# 23631                           SAMOLIOTIK              3
# 24848               Zombie Office Politics              0
# 27360                             gravilon              0
# 28048       Angels of Fasaria: Version 2.0              0
# 28807                      Selknam Defense              0
# 29867                         Nimble Quest              3
# 29911                               Vector              3
# 29925                             Dead Sky             -1
# 29935                   Beast Boxing Turbo              3
# 29981              World Basketball Tycoon             -3
# 29988                   A Walk in the Dark              3
# 29998        Rain Blood Chronicles: Mirage              1
# 30013                                  Vox             -1
# 30058           Valdis Story: Abyssal City              3
# 30065                        Sparkle 2 Evo              1
# 30124                           Anachronox              1
# 30138                            Startopia              3
# 30148                    Deathtrap Dungeon              1
# 30168                             Gorky 17              3
# 30187                 1953 - KGB Unleashed              0
# 30198   Artemis Spaceship Bridge Simulator              3
# 30252                      Rayman® Legends              3
# 31190                    Streets of Rage 3              0
# 31911  18 Wheels of Steel: Extreme Trucker              0
# 31918                         Crash Time 2              0
# 31948    Nikopol: Secrets of the Immortals              0
# 32209                Tycoon City: New York             -1
#
# [69 rows x 11 columns]

# %%
# Create variable with TRUE if publisher is missing
missing_pub = pd.isnull(cleaned_games['publisher']) == True
# Create variable with TRUE if developer is missing
missing_dev = pd.isnull(cleaned_games['developer']) == True

len(cleaned_games[missing_pub & missing_dev])
# drop rows that have missing pub and dev
cleaned_games.drop(cleaned_games[missing_pub & missing_dev].index, inplace=True)

# %%
cleaned_games.head()
# Out:
#                                          description  \
# 0  [, About This Game, Do you love puzzles? What ...
# 3  [, About This Game, In Global Soccer Manager 2...
# 6  [, About This Game, Experience the pureness an...
# 7  [, About This Game, See how a game created by ...
# 8  [, About This Game, From the creators of Rogue...
#
#                                         developer  \
# 0                                        ChillFun
# 3  gsmpcgame,globalsoccermanager,Andrea Hochstein
# 6                                       Media Art
# 7                                           AIREM
# 8                               Cellar Door Games
#
#                                           genres      id  price  \
# 0                                     [Strategy]  773510  14.99
# 3  [Casual, Indie, Simulation, Sports, Strategy]  625700   9.99
# 6                            [Adventure, Casual]  770880   9.99
# 7                             [Adventure, Indie]  725780   9.99
# 8                [Action, Adventure, Indie, RPG]  416600  19.99
#
#            publisher release_date  \
# 0           ChillFun   2018-01-17
# 3          gsmpcgame   2017-05-24
# 6     Big Fish Games   2018-01-17
# 7      IQ Publishing   2018-01-17
# 8  Cellar Door Games   2018-01-17
#
#                                                specs  \
# 0  [Single-player, Partial Controller Support, St...
# 3  [Single-player, Steam Achievements, Steam Trad...
# 6                                    [Single-player]
# 7           [Single-player, Full controller support]
# 8  [Single-player, Co-op, Online Co-op, Local Co-...
#
#                                                 tags  \
# 0  [Strategy, Cartoon, Puzzle, First-Person, Phys...
# 3  [Sports, Strategy, Simulation, Indie, Casual, ...
# 6                                [Adventure, Casual]
# 7                         [Adventure, Indie, Horror]
# 8  [Indie, Action, Adventure, RPG, Co-op, Beat 'e...
#
#                            title  sentiment_num
# 0              The Hardest Thing              0
# 3     Global Soccer Manager 2017              2
# 6  Love Story: The Beach Cottage              0
# 7                   PLAY WITH ME              0
# 8              Full Metal Furies              0

# %%
cleaned_games.to_csv('games_cleaned.csv')

# %% [markdown]
# # Summary

# %%
print('Total # of games: ' + str(len(cleaned_games)))
print('Total # of dlcs: ' + str(len(cleaned_dlcs)))
print('Total # of reviews: ' + str(len(cleaned_reviews)))
# Out:
# Total # of games: 17068
# Total # of dlcs: 13884
# Total # of reviews: 73058
